# %% [markdown]
# # merging data into 2 csv

# %%
df=pd.read_csv("demographics.csv",index_col=0)
df.head()
# Out:
#    PCIncome    fip-year   fips  POPESTIMATE   MFratio  POPEST_MALE  \
# 0   28845.0  10001-2019  10001       181492  0.928981        87405
# 1   28911.0  10001-2020  10001       182256  0.937657        88196
# 2   30804.0  10001-2021  10001       184149  0.934846        88974
# 3   37532.0  10003-2019  10003       559941  0.938357       271067
# 4   38965.0  10003-2020  10003       570718  0.949686       277995
#
#    POPEST_FEM  MEDIAN_AGE_TOT  UNDER5_TOT  AGE513_TOT  ...  AGE65PLUS_TOT  \
# 0       94087            38.0       11234       20980  ...          31780
# 1       94060            38.1       10992       21365  ...          31967
# 2       95175            38.3       10775       21574  ...          33033
# 3      288874            38.8       31837       60062  ...          89925
# 4      292723            39.0       31611       62154  ...          92012
#
#    RUCC_2013      WA      BA    IA     AA   NA    TOM      NH      H
# 0        3.0  118674   49734  1342   4358  212   7172  167860  13632
# 1        3.0  118412   50652  1355   4296  220   7321  168174  14082
# 2        3.0  118375   52239  1391   4343  241   7560  169703  14446
# 3        1.0  359883  148161  2766  33418  416  15297  501375  58566
# 4        1.0  364190  153022  2927  34170  431  15978  509191  61527
#
# [5 rows x 22 columns]

# %%
data=df.to_dict(orient='records')

# %%
data
# Out:
# [{'PCIncome': 28845.0,
#   'fip-year': '10001-2019',
#   'fips': 10001,
#   'POPESTIMATE': 181492,
#   'MFratio': 0.9289806243157928,
#   'POPEST_MALE': 87405,
#   'POPEST_FEM': 94087,
#   'MEDIAN_AGE_TOT': 38.0,
#   'UNDER5_TOT': 11234,
#   'AGE513_TOT': 20980,
#   'AGE1544_TOT': 70742,
#   'AGE4564_TOT': 44470,
#   'AGE65PLUS_TOT': 31780,
#   'RUCC_2013': 3.0,
#   'WA': 118674,
#   'BA': 49734,
#   'IA': 1342,
#   'AA': 4358,
#   'NA': 212,
#   'TOM': 7172,
#   'NH': 167860,
#   'H': 13632},
#  {'PCIncome': 28911.0,
#   'fip-year': '10001-2020',
#   'fips': 10001,
#   'POPESTIMATE': 182256,
#   'MFratio': 0.9376568147990644,
#   'POPEST_MALE': 88196,
#   'POPEST_FEM': 94060,
#   'MEDIAN_AGE_TOT': 38.1,
#   'UNDER5_TOT': 10992,
#   'AGE513_TOT': 21365,
#   'AGE1544_TOT': 70984,
#   'AGE4564_TOT': 44511,
#   'AGE65PLUS_TOT': 31967,
#   'RUCC_2013': 3.0,
#   'WA': 118412,
#   'BA': 50652,
#   'IA': 1355,
#   'AA': 4296,
#   'NA': 220,
#   'TOM': 7321,
#   'NH': 168174,
#   'H': 14082},
#  {'PCIncome': 30804.0,
#   'fip-year': '10001-2021',
#   'fips': 10001,
#   'POPESTIMATE': 184149,
#   'MFratio': 0.9348463356973996,
#   'POPEST_MALE': 88974,
#   'POPEST_FEM': 95175,
#   'MEDIAN_AGE_TOT': 38.3,
#   'UNDER5_TOT': 10775,
#   'AGE513_TOT': 21574,
#   'AGE1544_TOT': 71934,
#   'AGE4564_TOT': 44386,
#   'AGE65PLUS_TOT': 33033,
#   'RUCC_2013': 3.0,
#   'WA': 118375,
#   'BA': 52239,
#   'IA': 1391,
#   'AA': 4343,
#   'NA': 241,
#   'TOM': 7560,
#   'NH': 169703,
#   'H': 14446},
#  {'PCIncome': 37532.0,
#   'fip-year': '10003-2019',
#   'fips': 10003,
#   'POPESTIMATE': 559941,
#   'MFratio': 0.9383572076407016,
#   'POPEST_MALE': 271067,
#   'POPEST_FEM': 288874,
#   'MEDIAN_AGE_TOT': 38.8,
#   'UNDER5_TOT': 31837,
#   'AGE513_TOT': 60062,
#   'AGE1544_TOT': 223145,
#   'AGE4564_TOT': 148224,
#   'AGE65PLUS_TOT': 89925,
#   'RUCC_2013': 1.0,
#   'WA': 359883,
#   'BA': 148161,
#   'IA': 2766,
#   'AA': 33418,
#   'NA': 416,
#   'TOM': 15297,
#   'NH': 501375,
#   'H': 58566},
#  {'PCIncome': 38965.0,
#   'fip-year': '10003-2020',
#   'fips': 10003,
#   'POPESTIMATE': 570718,
#   'MFratio': 0.949686222128087,
#   'POPEST_MALE': 277995,
#   'POPEST_FEM': 292723,
#   'MEDIAN_AGE_TOT': 39.0,
#   'UNDER5_TOT': 31611,
#   'AGE513_TOT': 62154,
#   'AGE1544_TOT': 227046,
#   'AGE4564_TOT': 150771,
#   'AGE65PLUS_TOT': 92012,
#   'RUCC_2013': 1.0,
#   'WA': 364190,
#   'BA': 153022,
#   'IA': 2927,
#   'AA': 34170,
#   'NA': 431,
#   'TOM': 15978,
#   'NH': 509191,
#   'H': 61527},
#  {'PCIncome': 41428.0,
#   'fip-year': '10003-2021',
#   'fips': 10003,
#   'POPESTIMATE': 571708,
#   'MFratio': 0.9483491916355408,
#   'POPEST_MALE': 278276,
#   'POPEST_FEM': 293432,
#   'MEDIAN_AGE_TOT': 39.2,
#   'UNDER5_TOT': 30924,
#   'AGE513_TOT': 61541,
#   'AGE1544_TOT': 228044,
#   'AGE4564_TOT': 148945,
#   'AGE65PLUS_TOT': 94971,
#   'RUCC_2013': 1.0,
#   'WA': 362239,
#   'BA': 155269,
#   'IA': 3001,
#   'AA': 34573,
#   'NA': 442,
#   'TOM': 16184,
#   'NH': 508731,
#   'H': 62977},
#  {'PCIncome': 35491.0,
#   'fip-year': '10005-2019',
#   'fips': 10005,
#   'POPESTIMATE': 235235,
#   'MFratio': 0.9343392813091028,
#   'POPEST_MALE': 113625,
#   'POPEST_FEM': 121610,
#   'MEDIAN_AGE_TOT': 51.0,
#   'UNDER5_TOT': 11780,
#   'AGE513_TOT': 21855,
#   'AGE1544_TOT': 67061,
#   'AGE4564_TOT': 64267,
#   'AGE65PLUS_TOT': 67750,
#   'RUCC_2013': 2.0,
#   'WA': 194892,
#   'BA': 28671,
#   'IA': 2588,
#   'AA': 3226,
#   'NA': 461,
#   'TOM': 5397,
#   'NH': 213279,
#   'H': 21956},
#  {'PCIncome': 36739.0,
#   'fip-year': '10005-2020',
#   'fips': 10005,
#   'POPESTIMATE': 238912,
#   'MFratio': 0.944049343336534,
#   'POPEST_MALE': 116018,
#   'POPEST_FEM': 122894,
#   'MEDIAN_AGE_TOT': 51.4,
#   'UNDER5_TOT': 11621,
#   'AGE513_TOT': 22184,
#   'AGE1544_TOT': 67657,
#   'AGE4564_TOT': 65130,
#   'AGE65PLUS_TOT': 69718,
#   'RUCC_2013': 2.0,
#   'WA': 198150,
#   'BA': 28791,
#   'IA': 2668,
#   'AA': 3267,
#   'NA': 489,
#   'TOM': 5547,
#   'NH': 216232,
#   'H': 22680},
#  {'PCIncome': 39066.0,
#   'fip-year': '10005-2021',
#   'fips': 10005,
#   'POPESTIMATE': 247527,
#   'MFratio': 0.9422870190911872,
#   'POPEST_MALE': 120086,
#   'POPEST_FEM': 127441,
#   'MEDIAN_AGE_TOT': 52.0,
#   'UNDER5_TOT': 11802,
#   'AGE513_TOT': 22419,
#   'AGE1544_TOT': 70007,
#   'AGE4564_TOT': 66994,
#   'AGE65PLUS_TOT': 73642,
#   'RUCC_2013': 2.0,
#   'WA': 205985,
#   'BA': 29113,
#   'IA': 2732,
#   'AA': 3503,
#   'NA': 480,
#   'TOM': 5714,
#   'NH': 223737,
#   'H': 23790},
#  {'PCIncome': 56147.0,
#   'fip-year': '11001-2019',
#   'fips': 11001,
#   'POPESTIMATE': 708253,
#   'MFratio': 0.9018966521927104,
#   'POPEST_MALE': 335860,
#   'POPEST_FEM': 372393,
#   'MEDIAN_AGE_TOT': 34.2,
#   'UNDER5_TOT': 45015,
#   'AGE513_TOT': 62268,
#   'AGE1544_TOT': 362533,
#   'AGE4564_TOT': 144996,
#   'AGE65PLUS_TOT': 88132,
#   'RUCC_2013': 1.0,
#   'WA': 324529,
#   'BA': 326019,
#   'IA': 4318,
#   'AA': 31697,
#   'NA': 1100,
#   'TOM': 20590,
#   'NH': 628415,
#   'H': 79838},
#  {'PCIncome': 58659.0,
#   'fip-year': '11001-2020',
#   'fips': 11001,
#   'POPESTIMATE': 690093,
#   'MFratio': 0.9106464036236478,
#   'POPEST_MALE': 328910,
#   'POPEST_FEM': 361183,
#   'MEDIAN_AGE_TOT': 34.4,
#   'UNDER5_TOT': 42654,
#   'AGE513_TOT': 63239,
#   'AGE1544_TOT': 353106,
#   'AGE4564_TOT': 140947,
#   'AGE65PLUS_TOT': 84624,
#   'RUCC_2013': 1.0,
#   'WA': 319126,
#   'BA': 313838,
#   'IA': 4138,
#   'AA': 31308,
#   'NA': 1086,
#   'TOM': 20597,
#   'NH': 611239,
#   'H': 78854},
#  {'PCIncome': 63793.0,
#   'fip-year': '11001-2021',
#   'fips': 11001,
#   'POPESTIMATE': 670050,
#   'MFratio': 0.9081806428095436,
#   'POPEST_MALE': 318904,
#   'POPEST_FEM': 351146,
#   'MEDIAN_AGE_TOT': 34.9,
#   'UNDER5_TOT': 40759,
#   'AGE513_TOT': 63458,
#   'AGE1544_TOT': 337260,
#   'AGE4564_TOT': 136905,
#   'AGE65PLUS_TOT': 85838,
#   'RUCC_2013': 1.0,
#   'WA': 307274,
#   'BA': 306925,
#   'IA': 4067,
#   'AA': 30342,
#   'NA': 1063,
#   'TOM': 20379,
#   'NH': 593131,
#   'H': 76919},
#  {'PCIncome': 28646.0,
#   'fip-year': '12001-2019',
#   'fips': 12001,
#   'POPESTIMATE': 269489,
#   'MFratio': 0.9309072410185862,
#   'POPEST_MALE': 129923,
#   'POPEST_FEM': 139566,
#   'MEDIAN_AGE_TOT': 32.1,
#   'UNDER5_TOT': 13796,
#   'AGE513_TOT': 24563,
#   'AGE1544_TOT': 134277,
#   'AGE4564_TOT': 54571,
#   'AGE65PLUS_TOT': 39682,
#   'RUCC_2013': 2.0,
#   'WA': 188393,
#   'BA': 55757,
#   'IA': 1025,
#   'AA': 16460,
#   'NA': 194,
#   'TOM': 7660,
#   'NH': 241308,
#   'H': 28181},
#  {'PCIncome': 29821.0,
#   'fip-year': '12001-2020',
#   'fips': 12001,
#   'POPESTIMATE': 278684,
#   'MFratio': 0.9378085582766628,
#   'POPEST_MALE': 134870,
#   'POPEST_FEM': 143814,
#   'MEDIAN_AGE_TOT': 32.4,
#   'UNDER5_TOT': 13887,
#   'AGE513_TOT': 25949,
#   'AGE1544_TOT': 138284,
#   'AGE4564_TOT': 56486,
#   'AGE65PLUS_TOT': 41336,
#   'RUCC_2013': 2.0,
#   'WA': 194832,
#   'BA': 57533,
#   'IA': 1016,
#   'AA': 17049,
#   'NA': 207,
#   'TOM': 8047,
#   'NH': 248639,
#   'H': 30045},
#  {'PCIncome': 32323.0,
#   'fip-year': '12001-2021',
#   'fips': 12001,
#   'POPESTIMATE': 279238,
#   'MFratio': 0.9348933251106938,
#   'POPEST_MALE': 134921,
#   'POPEST_FEM': 144317,
#   'MEDIAN_AGE_TOT': 32.8,
#   'UNDER5_TOT': 13524,
#   'AGE513_TOT': 25965,
#   'AGE1544_TOT': 138232,
#   'AGE4564_TOT': 56138,
#   'AGE65PLUS_TOT': 42493,
#   'RUCC_2013': 2.0,
#   'WA': 194722,
#   'BA': 57696,
#   'IA': 1034,
#   'AA': 17315,
#   'NA': 214,
#   'TOM': 8257,
#   'NH': 248450,
#   'H': 30788},
#  {'PCIncome': 24686.0,
#   'fip-year': '12003-2019',
#   'fips': 12003,
#   'POPESTIMATE': 29288,
#   'MFratio': 1.114199090449722,
#   'POPEST_MALE': 15435,
#   'POPEST_FEM': 13853,
#   'MEDIAN_AGE_TOT': 37.2,
#   'UNDER5_TOT': 1837,
#   'AGE513_TOT': 3593,
#   'AGE1544_TOT': 11816,
#   'AGE4564_TOT': 7501,
#   'AGE65PLUS_TOT': 4171,
#   'RUCC_2013': 1.0,
#   'WA': 24223,
#   'BA': 4167,
#   'IA': 144,
#   'AA': 199,
#   'NA': 10,
#   'TOM': 545,
#   'NH': 28453,
#   'H': 835},
#  {'PCIncome': 24051.0,
#   'fip-year': '12003-2020',
#   'fips': 12003,
#   'POPESTIMATE': 28309,
#   'MFratio': 1.1254598693595614,
#   'POPEST_MALE': 14990,
#   'POPEST_FEM': 13319,
#   'MEDIAN_AGE_TOT': 37.5,
#   'UNDER5_TOT': 1713,
#   'AGE513_TOT': 3475,
#   'AGE1544_TOT': 11377,
#   'AGE4564_TOT': 7293,
#   'AGE65PLUS_TOT': 4046,
#   'RUCC_2013': 1.0,
#   'WA': 23269,
#   'BA': 4051,
#   'IA': 150,
#   'AA': 225,
#   'NA': 13,
#   'TOM': 601,
#   'NH': 27467,
#   'H': 842},
#  {'PCIncome': 25689.0,
#   'fip-year': '12003-2021',
#   'fips': 12003,
#   'POPESTIMATE': 28715,
#   'MFratio': 1.1335166059885575,
#   'POPEST_MALE': 15256,
#   'POPEST_FEM': 13459,
#   'MEDIAN_AGE_TOT': 37.5,
#   'UNDER5_TOT': 1746,
#   'AGE513_TOT': 3490,
#   'AGE1544_TOT': 11575,
#   'AGE4564_TOT': 7318,
#   'AGE65PLUS_TOT': 4179,
#   'RUCC_2013': 1.0,
#   'WA': 23489,
#   'BA': 4203,
#   'IA': 149,
#   'AA': 237,
#   'NA': 21,
#   'TOM': 616,
#   'NH': 27763,
#   'H': 952},
#  {'PCIncome': 29290.0,
#   'fip-year': '12005-2019',
#   'fips': 12005,
#   'POPESTIMATE': 173895,
#   'MFratio': 0.9824097401931168,
#   'POPEST_MALE': 86176,
#   'POPEST_FEM': 87719,
#   'MEDIAN_AGE_TOT': 41.8,
#   'UNDER5_TOT': 9841,
#   'AGE513_TOT': 18163,
#   'AGE1544_TOT': 63389,
#   'AGE4564_TOT': 48335,
#   'AGE65PLUS_TOT': 32145,
#   'RUCC_2013': 3.0,
#   'WA': 142763,
#   'BA': 19624,
#   'IA': 1420,
#   'AA': 4027,
#   'NA': 297,
#   'TOM': 5764,
#   'NH': 162383,
#   'H': 11512},
#  {'PCIncome': 30774.0,
#   'fip-year': '12005-2020',
#   'fips': 12005,
#   'POPESTIMATE': 174461,
#   'MFratio': 0.9953907036325372,
#   'POPEST_MALE': 87029,
#   'POPEST_FEM': 87432,
#   'MEDIAN_AGE_TOT': 41.9,
#   'UNDER5_TOT': 9491,
#   'AGE513_TOT': 18339,
#   'AGE1544_TOT': 63514,
#   'AGE4564_TOT': 48795,
#   'AGE65PLUS_TOT': 32202,
#   'RUCC_2013': 3.0,
#   'WA': 143130,
#   'BA': 19592,
#   'IA': 1457,
#   'AA': 4109,
#   'NA': 313,
#   'TOM': 5860,
#   'NH': 162339,
#   'H': 12122},
#  {'PCIncome': 32312.0,
#   'fip-year': '12005-2021',
#   'fips': 12005,
#   'POPESTIMATE': 179168,
#   'MFratio': 0.992371590289902,
#   'POPEST_MALE': 89241,
#   'POPEST_FEM': 89927,
#   'MEDIAN_AGE_TOT': 41.6,
#   'UNDER5_TOT': 9835,
#   'AGE513_TOT': 18847,
#   'AGE1544_TOT': 66023,
#   'AGE4564_TOT': 49205,
#   'AGE65PLUS_TOT': 33098,
#   'RUCC_2013': 3.0,
#   'WA': 146215,
#   'BA': 20637,
#   'IA': 1478,
#   'AA': 4358,
#   'NA': 333,
#   'TOM': 6147,
#   'NH': 165943,
#   'H': 13225},
#  {'PCIncome': 20529.0,
#   'fip-year': '12007-2019',
#   'fips': 12007,
#   'POPESTIMATE': 28348,
#   'MFratio': 1.2480570975416336,
#   'POPEST_MALE': 15738,
#   'POPEST_FEM': 12610,
#   'MEDIAN_AGE_TOT': 40.0,
#   'UNDER5_TOT': 1491,
#   'AGE513_TOT': 2769,
#   'AGE1544_TOT': 11382,
#   'AGE4564_TOT': 7225,
#   'AGE65PLUS_TOT': 5168,
#   'RUCC_2013': 6.0,
#   'WA': 21576,
#   'BA': 5810,
#   'IA': 167,
#   'AA': 182,
#   'NA': 13,
#   'TOM': 600,
#   'NH': 27016,
#   'H': 1332},
#  {'PCIncome': 21003.0,
#   'fip-year': '12007-2020',
#   'fips': 12007,
#   'POPESTIMATE': 28364,
#   'MFratio': 1.2611607142857142,
#   'POPEST_MALE': 15820,
#   'POPEST_FEM': 12544,
#   'MEDIAN_AGE_TOT': 40.1,
#   'UNDER5_TOT': 1478,
#   'AGE513_TOT': 2807,
#   'AGE1544_TOT': 11394,
#   'AGE4564_TOT': 7295,
#   'AGE65PLUS_TOT': 5072,
#   'RUCC_2013': 6.0,
#   'WA': 21634,
#   'BA': 5755,
#   'IA': 180,
#   'AA': 191,
#   'NA': 13,
#   'TOM': 591,
#   'NH': 27028,
#   'H': 1336},
#  {'PCIncome': 22656.0,
#   'fip-year': '12007-2021',
#   'fips': 12007,
#   'POPESTIMATE': 28540,
#   'MFratio': 1.2605940594059406,
#   'POPEST_MALE': 15915,
#   'POPEST_FEM': 12625,
#   'MEDIAN_AGE_TOT': 40.1,
#   'UNDER5_TOT': 1468,
#   'AGE513_TOT': 2840,
#   'AGE1544_TOT': 11497,
#   'AGE4564_TOT': 7242,
#   'AGE65PLUS_TOT': 5152,
#   'RUCC_2013': 6.0,
#   'WA': 21765,
#   'BA': 5784,
#   'IA': 185,
#   'AA': 191,
#   'NA': 14,
#   'TOM': 601,
#   'NH': 27141,
#   'H': 1399},
#  {'PCIncome': 32176.0,
#   'fip-year': '12009-2019',
#   'fips': 12009,
#   'POPESTIMATE': 601024,
#   'MFratio': 0.9565220222012436,
#   'POPEST_MALE': 293834,
#   'POPEST_FEM': 307190,
#   'MEDIAN_AGE_TOT': 47.6,
#   'UNDER5_TOT': 27428,
#   'AGE513_TOT': 55566,
#   'AGE1544_TOT': 194390,
#   'AGE4564_TOT': 172472,
#   'AGE65PLUS_TOT': 144638,
#   'RUCC_2013': 2.0,
#   'WA': 499412,
#   'BA': 65132,
#   'IA': 2807,
#   'AA': 15729,
#   'NA': 759,
#   'TOM': 17185,
#   'NH': 535399,
#   'H': 65625},
#  {'PCIncome': 33662.0,
#   'fip-year': '12009-2020',
#   'fips': 12009,
#   'POPESTIMATE': 608007,
#   'MFratio': 0.9696553466780268,
#   'POPEST_MALE': 299320,
#   'POPEST_FEM': 308687,
#   'MEDIAN_AGE_TOT': 47.4,
#   'UNDER5_TOT': 27256,
#   'AGE513_TOT': 57122,
#   'AGE1544_TOT': 197821,
#   'AGE4564_TOT': 173962,
#   'AGE65PLUS_TOT': 145039,
#   'RUCC_2013': 2.0,
#   'WA': 504300,
#   'BA': 66123,
#   'IA': 2897,
#   'AA': 16110,
#   'NA': 772,
#   'TOM': 17805,
#   'NH': 539328,
#   'H': 68679},
#  {'PCIncome': 36278.0,
#   'fip-year': '12009-2021',
#   'fips': 12009,
#   'POPESTIMATE': 616628,
#   'MFratio': 0.9721367576038636,
#   'POPEST_MALE': 303958,
#   'POPEST_FEM': 312670,
#   'MEDIAN_AGE_TOT': 47.2,
#   'UNDER5_TOT': 26930,
#   'AGE513_TOT': 57379,
#   'AGE1544_TOT': 202855,
#   'AGE4564_TOT': 173062,
#   'AGE65PLUS_TOT': 149343,
#   'RUCC_2013': 2.0,
#   'WA': 510290,
#   'BA': 67532,
#   'IA': 2974,
#   'AA': 16629,
#   'NA': 801,
#   'TOM': 18402,
#   'NH': 544952,
#   'H': 71676},
#  {'PCIncome': 32909.0,
#   'fip-year': '12011-2019',
#   'fips': 12011,
#   'POPESTIMATE': 1955475,
#   'MFratio': 0.9505498615994612,
#   'POPEST_MALE': 952950,
#   'POPEST_FEM': 1002525,
#   'MEDIAN_AGE_TOT': 40.7,
#   'UNDER5_TOT': 112399,
#   'AGE513_TOT': 206329,
#   'AGE1544_TOT': 744851,
#   'AGE4564_TOT': 534398,
#   'AGE65PLUS_TOT': 333996,
#   'RUCC_2013': 1.0,
#   'WA': 1232477,
#   'BA': 592142,
#   'IA': 8183,
#   'AA': 75903,
#   'NA': 2358,
#   'TOM': 44412,
#   'NH': 1353115,
#   'H': 602360},
#  {'PCIncome': 34063.0,
#   'fip-year': '12011-2020',
#   'fips': 12011,
#   'POPESTIMATE': 1941516,
#   'MFratio': 0.9636006161296096,
#   'POPEST_MALE': 952763,
#   'POPEST_FEM': 988753,
#   'MEDIAN_AGE_TOT': 40.9,
#   'UNDER5_TOT': 108768,
#   'AGE513_TOT': 207010,
#   'AGE1544_TOT': 735986,
#   'AGE4564_TOT': 534448,
#   'AGE65PLUS_TOT': 330941,
#   'RUCC_2013': 1.0,
#   'WA': 1218715,
#   'BA': 591529,
#   'IA': 8392,
#   'AA': 75535,
#   'NA': 2416,
#   'TOM': 44929,
#   'NH': 1329760,
#   'H': 611756},
#  {'PCIncome': 36451.0,
#   'fip-year': '12011-2021',
#   'fips': 12011,
#   'POPESTIMATE': 1930983,
#   'MFratio': 0.9632629697486066,
#   'POPEST_MALE': 947425,
#   'POPEST_FEM': 983558,
#   'MEDIAN_AGE_TOT': 41.3,
#   'UNDER5_TOT': 105615,
#   'AGE513_TOT': 203536,
#   'AGE1544_TOT': 729122,
#   'AGE4564_TOT': 529937,
#   'AGE65PLUS_TOT': 338380,
#   'RUCC_2013': 1.0,
#   'WA': 1207686,
#   'BA': 591169,
#   'IA': 8463,
#   'AA': 75703,
#   'NA': 2455,
#   'TOM': 45507,
#   'NH': 1312540,
#   'H': 618443},
#  {'PCIncome': 19304.0,
#   'fip-year': '12013-2019',
#   'fips': 12013,
#   'POPESTIMATE': 14140,
#   'MFratio': 1.181425485961123,
#   'POPEST_MALE': 7658,
#   'POPEST_FEM': 6482,
#   'MEDIAN_AGE_TOT': 41.9,
#   'UNDER5_TOT': 679,
#   'AGE513_TOT': 1471,
#   'AGE1544_TOT': 5309,
#   'AGE4564_TOT': 3839,
#   'AGE65PLUS_TOT': 2662,
#   'RUCC_2013': 6.0,
#   'WA': 11712,
#   'BA': 1748,
#   'IA': 191,
#   'AA': 124,
#   'NA': 20,
#   'TOM': 345,
#   'NH': 13300,
#   'H': 840},
#  {'PCIncome': 19512.0,
#   'fip-year': '12013-2020',
#   'fips': 12013,
#   'POPESTIMATE': 13615,
#   'MFratio': 1.183991017003529,
#   'POPEST_MALE': 7381,
#   'POPEST_FEM': 6234,
#   'MEDIAN_AGE_TOT': 41.6,
#   'UNDER5_TOT': 653,
#   'AGE513_TOT': 1423,
#   'AGE1544_TOT': 5133,
#   'AGE4564_TOT': 3693,
#   'AGE65PLUS_TOT': 2524,
#   'RUCC_2013': 6.0,
#   'WA': 11217,
#   'BA': 1725,
#   'IA': 198,
#   'AA': 123,
#   'NA': 22,
#   'TOM': 330,
#   'NH': 12786,
#   'H': 829},
#  {'PCIncome': 19982.0,
#   'fip-year': '12013-2021',
#   'fips': 12013,
#   'POPESTIMATE': 13641,
#   'MFratio': 1.192029567732605,
#   'POPEST_MALE': 7418,
#   'POPEST_FEM': 6223,
#   'MEDIAN_AGE_TOT': 41.8,
#   'UNDER5_TOT': 654,
#   'AGE513_TOT': 1370,
#   'AGE1544_TOT': 5165,
#   'AGE4564_TOT': 3674,
#   'AGE65PLUS_TOT': 2586,
#   'RUCC_2013': 6.0,
#   'WA': 11198,
#   'BA': 1744,
#   'IA': 210,
#   'AA': 124,
#   'NA': 24,
#   'TOM': 341,
#   'NH': 12782,
#   'H': 859},
#  {'PCIncome': 32144.0,
#   'fip-year': '12015-2019',
#   'fips': 12015,
#   'POPESTIMATE': 189669,
#   'MFratio': 0.9517287507717638,
#   'POPEST_MALE': 92489,
#   'POPEST_FEM': 97180,
#   'MEDIAN_AGE_TOT': 60.1,
#   'UNDER5_TOT': 5450,
#   'AGE513_TOT': 11336,
#   'AGE1544_TOT': 42311,
#   'AGE4564_TOT': 51767,
#   'AGE65PLUS_TOT': 77428,
#   'RUCC_2013': 3.0,
#   'WA': 171606,
#   'BA': 11346,
#   'IA': 759,
#   'AA': 2725,
#   'NA': 117,
#   'TOM': 3116,
#   'NH': 174966,
#   'H': 14703},
#  {'PCIncome': 33275.0,
#   'fip-year': '12015-2020',
#   'fips': 12015,
#   'POPESTIMATE': 187960,
#   'MFratio': 0.9651426599893358,
#   'POPEST_MALE': 92313,
#   'POPEST_FEM': 95647,
#   'MEDIAN_AGE_TOT': 60.0,
#   'UNDER5_TOT': 5380,
#   'AGE513_TOT': 11490,
#   'AGE1544_TOT': 42091,
#   'AGE4564_TOT': 51677,
#   'AGE65PLUS_TOT': 75936,
#   'RUCC_2013': 3.0,
#   'WA': 169894,
#   'BA': 11243,
#   'IA': 790,
#   'AA': 2681,
#   'NA': 135,
#   'TOM': 3217,
#   'NH': 172790,
#   'H': 15170},
#  {'PCIncome': 35656.0,
#   'fip-year': '12015-2021',
#   'fips': 12015,
#   'POPESTIMATE': 194843,
#   'MFratio': 0.9637274367321434,
#   'POPEST_MALE': 95622,
#   'POPEST_FEM': 99221,
#   'MEDIAN_AGE_TOT': 60.2,
#   'UNDER5_TOT': 5459,
#   'AGE513_TOT': 11767,
#   'AGE1544_TOT': 44081,
#   'AGE4564_TOT': 53072,
#   'AGE65PLUS_TOT': 78993,
#   'RUCC_2013': 3.0,
#   'WA': 175989,
#   'BA': 11616,
#   'IA': 784,
#   'AA': 2835,
#   'NA': 145,
#   'TOM': 3474,
#   'NH': 178923,
#   'H': 15920},
#  {'PCIncome': 26989.0,
#   'fip-year': '12017-2019',
#   'fips': 12017,
#   'POPESTIMATE': 150153,
#   'MFratio': 0.93951019142835,
#   'POPEST_MALE': 72735,
#   'POPEST_FEM': 77418,
#   'MEDIAN_AGE_TOT': 57.2,
#   'UNDER5_TOT': 5475,
#   'AGE513_TOT': 11222,
#   'AGE1544_TOT': 36502,
#   'AGE4564_TOT': 40281,
#   'AGE65PLUS_TOT': 55415,
#   'RUCC_2013': 3.0,
#   'WA': 139538,
#   'BA': 4771,
#   'IA': 651,
#   'AA': 2533,
#   'NA': 66,
#   'TOM': 2594,
#   'NH': 141066,
#   'H': 9087},
#  {'PCIncome': 28174.0,
#   'fip-year': '12017-2020',
#   'fips': 12017,
#   'POPESTIMATE': 154403,
#   'MFratio': 0.9501730366029252,
#   'POPEST_MALE': 75229,
#   'POPEST_FEM': 79174,
#   'MEDIAN_AGE_TOT': 56.9,
#   'UNDER5_TOT': 5611,
#   'AGE513_TOT': 11793,
#   'AGE1544_TOT': 37947,
#   'AGE4564_TOT': 41561,
#   'AGE65PLUS_TOT': 56047,
#   'RUCC_2013': 3.0,
#   'WA': 143199,
#   'BA': 4978,
#   'IA': 720,
#   'AA': 2630,
#   'NA': 89,
#   'TOM': 2787,
#   'NH': 144577,
#   'H': 9826},
#  {'PCIncome': 29948.0,
#   'fip-year': '12017-2021',
#   'fips': 12017,
#   'POPESTIMATE': 158083,
#   'MFratio': 0.9528956861194842,
#   'POPEST_MALE': 77135,
#   'POPEST_FEM': 80948,
#   'MEDIAN_AGE_TOT': 57.0,
#   'UNDER5_TOT': 5652,
#   'AGE513_TOT': 12041,
#   'AGE1544_TOT': 39539,
#   'AGE4564_TOT': 42020,
#   'AGE65PLUS_TOT': 57364,
#   'RUCC_2013': 3.0,
#   'WA': 146411,
#   'BA': 5249,
#   'IA': 758,
#   'AA': 2637,
#   'NA': 101,
#   'TOM': 2927,
#   'NH': 147529,
#   'H': 10554},
#  {'PCIncome': 30483.0,
#   'fip-year': '12019-2019',
#   'fips': 12019,
#   'POPESTIMATE': 219014,
#   'MFratio': 0.9716248210797332,
#   'POPEST_MALE': 107931,
#   'POPEST_FEM': 111083,
#   'MEDIAN_AGE_TOT': 39.9,
#   'UNDER5_TOT': 11936,
#   'AGE513_TOT': 26022,
#   'AGE1544_TOT': 82507,
#   'AGE4564_TOT': 59993,
#   'AGE65PLUS_TOT': 35426,
#   'RUCC_2013': 1.0,
#   'WA': 175518,
#   'BA': 27858,
#   'IA': 1199,
#   'AA': 6918,
#   'NA': 350,
#   'TOM': 7171,
#   'NH': 196203,
#   'H': 22811},
#  {'PCIncome': 32037.0,
#   'fip-year': '12019-2020',
#   'fips': 12019,
#   'POPESTIMATE': 218797,
#   'MFratio': 0.9805293553234246,
#   'POPEST_MALE': 108323,
#   'POPEST_FEM': 110474,
#   'MEDIAN_AGE_TOT': 40.1,
#   'UNDER5_TOT': 11744,
#   'AGE513_TOT': 26254,
#   'AGE1544_TOT': 81990,
#   'AGE4564_TOT': 59886,
#   'AGE65PLUS_TOT': 35643,
#   'RUCC_2013': 1.0,
#   'WA': 174156,
#   'BA': 28746,
#   'IA': 1245,
#   'AA': 6867,
#   'NA': 392,
#   'TOM': 7391,
#   'NH': 195251,
#   'H': 23546},
#  {'PCIncome': 33670.0,
#   'fip-year': '12019-2021',
#   'fips': 12019,
#   'POPESTIMATE': 222361,
#   'MFratio': 0.9788288689151908,
#   'POPEST_MALE': 109991,
#   'POPEST_FEM': 112370,
#   'MEDIAN_AGE_TOT': 40.2,
#   'UNDER5_TOT': 11624,
#   'AGE513_TOT': 26441,
#   'AGE1544_TOT': 83871,
#   'AGE4564_TOT': 60116,
#   'AGE65PLUS_TOT': 36961,
#   'RUCC_2013': 1.0,
#   'WA': 175805,
#   'BA': 30139,
#   'IA': 1252,
#   'AA': 7072,
#   'NA': 397,
#   'TOM': 7696,
#   'NH': 197733,
#   'H': 24628},
#  {'PCIncome': 45567.0,
#   'fip-year': '12021-2019',
#   'fips': 12021,
#   'POPESTIMATE': 385917,
#   'MFratio': 0.970874827639038,
#   'POPEST_MALE': 190107,
#   'POPEST_FEM': 195810,
#   'MEDIAN_AGE_TOT': 52.0,
#   'UNDER5_TOT': 16718,
#   'AGE513_TOT': 32880,
#   'AGE1544_TOT': 110278,
#   'AGE4564_TOT': 95438,
#   'AGE65PLUS_TOT': 126809,
#   'RUCC_2013': 2.0,
#   'WA': 344284,
#   'BA': 28527,
#   'IA': 1863,
#   'AA': 6107,
#   'NA': 357,
#   'TOM': 4779,
#   'NH': 276703,
#   'H': 109214},
#  {'PCIncome': 46785.0,
#   'fip-year': '12021-2020',
#   'fips': 12021,
#   'POPESTIMATE': 377079,
#   'MFratio': 0.9816642492274704,
#   'POPEST_MALE': 186795,
#   'POPEST_FEM': 190284,
#   'MEDIAN_AGE_TOT': 52.1,
#   'UNDER5_TOT': 15914,
#   'AGE513_TOT': 32256,
#   'AGE1544_TOT': 107488,
#   'AGE4564_TOT': 94517,
#   'AGE65PLUS_TOT': 122922,
#   'RUCC_2013': 2.0,
#   'WA': 336251,
#   'BA': 27775,
#   'IA': 1863,
#   'AA': 6008,
#   'NA': 385,
#   'TOM': 4797,
#   'NH': 267992,
#   'H': 109087},
#  {'PCIncome': 51296.0,
#   'fip-year': '12021-2021',
#   'fips': 12021,
#   'POPESTIMATE': 385980,
#   'MFratio': 0.9824446966856532,
#   'POPEST_MALE': 191281,
#   'POPEST_FEM': 194699,
#   'MEDIAN_AGE_TOT': 52.6,
#   'UNDER5_TOT': 15764,
#   'AGE513_TOT': 32207,
#   'AGE1544_TOT': 109726,
#   'AGE4564_TOT': 96529,
#   'AGE65PLUS_TOT': 127681,
#   'RUCC_2013': 2.0,
#   'WA': 344142,
#   'BA': 28145,
#   'IA': 1936,
#   'AA': 6314,
#   'NA': 398,
#   'TOM': 5045,
#   'NH': 274217,
#   'H': 111763},
#  {'PCIncome': 24275.0,
#   'fip-year': '12023-2019',
#   'fips': 12023,
#   'POPESTIMATE': 71766,
#   'MFratio': 1.075001445671659,
#   'POPEST_MALE': 37180,
#   'POPEST_FEM': 34586,
#   'MEDIAN_AGE_TOT': 40.5,
#   'UNDER5_TOT': 4109,
#   'AGE513_TOT': 7965,
#   'AGE1544_TOT': 26644,
#   'AGE4564_TOT': 18338,
#   'AGE65PLUS_TOT': 13843,
#   'RUCC_2013': 4.0,
#   'WA': 55662,
#   'BA': 13403,
#   'IA': 429,
#   'AA': 720,
#   'NA': 63,
#   'TOM': 1489,
#   'NH': 67002,
#   'H': 4764},
#  {'PCIncome': 24569.0,
#   'fip-year': '12023-2020',
#   'fips': 12023,
#   'POPESTIMATE': 69889,
#   'MFratio': 1.0802154954311396,
#   'POPEST_MALE': 36292,
#   'POPEST_FEM': 33597,
#   'MEDIAN_AGE_TOT': 40.5,
#   'UNDER5_TOT': 3913,
#   'AGE513_TOT': 7831,
#   'AGE1544_TOT': 25927,
#   'AGE4564_TOT': 17813,
#   'AGE65PLUS_TOT': 13500,
#   'RUCC_2013': 4.0,
#   'WA': 54122,
#   'BA': 12977,
#   'IA': 460,
#   'AA': 739,
#   'NA': 69,
#   'TOM': 1522,
#   'NH': 65142,
#   'H': 4747},
#  {'PCIncome': 25912.0,
#   'fip-year': '12023-2021',
#   'fips': 12023,
#   'POPESTIMATE': 70385,
#   'MFratio': 1.0854814814814815,
#   'POPEST_MALE': 36635,
#   'POPEST_FEM': 33750,
#   'MEDIAN_AGE_TOT': 40.7,
#   'UNDER5_TOT': 3860,
#   'AGE513_TOT': 7871,
#   'AGE1544_TOT': 26175,
#   'AGE4564_TOT': 17699,
#   'AGE65PLUS_TOT': 13850,
#   'RUCC_2013': 4.0,
#   'WA': 54415,
#   'BA': 13152,
#   'IA': 471,
#   'AA': 766,
#   'NA': 71,
#   'TOM': 1510,
#   'NH': 65527,
#   'H': 4858},
#  {'PCIncome': 18503.0,
#   'fip-year': '12027-2019',
#   'fips': 12027,
#   'POPESTIMATE': 37821,
#   'MFratio': 1.2791973002289985,
#   'POPEST_MALE': 21227,
#   'POPEST_FEM': 16594,
#   'MEDIAN_AGE_TOT': 41.3,
#   'UNDER5_TOT': 1889,
#   'AGE513_TOT': 3554,
#   'AGE1544_TOT': 14548,
#   'AGE4564_TOT': 8931,
#   'AGE65PLUS_TOT': 8513,
#   'RUCC_2013': 6.0,
#   'WA': 31805,
#   'BA': 4818,
#   'IA': 404,
#   'AA': 210,
#   'NA': 65,
#   'TOM': 519,
#   'NH': 25834,
#   'H': 11987},
#  {'PCIncome': 18193.0,
#   'fip-year': '12027-2020',
#   'fips': 12027,
#   'POPESTIMATE': 34080,
#   'MFratio': 1.2826523777628935,
#   'POPEST_MALE': 19150,
#   'POPEST_FEM': 14930,
#   'MEDIAN_AGE_TOT': 41.5,
#   'UNDER5_TOT': 1697,
#   'AGE513_TOT': 3180,
#   'AGE1544_TOT': 13151,
#   'AGE4564_TOT': 8101,
#   'AGE65PLUS_TOT': 7580,
#   'RUCC_2013': 6.0,
#   'WA': 28586,
#   'BA': 4271,
#   'IA': 396,
#   'AA': 239,
#   'NA': 80,
#   'TOM': 508,
#   'NH': 23114,
#   'H': 10966},
#  {'PCIncome': 19673.0,
#   'fip-year': '12027-2021',
#   'fips': 12027,
#   'POPESTIMATE': 34408,
#   'MFratio': 1.2723550389644698,
#   'POPEST_MALE': 19266,
#   'POPEST_FEM': 15142,
#   'MEDIAN_AGE_TOT': 42.1,
#   'UNDER5_TOT': 1691,
#   'AGE513_TOT': 3104,
#   'AGE1544_TOT': 13231,
#   'AGE4564_TOT': 8227,
#   'AGE65PLUS_TOT': 7779,
#   'RUCC_2013': 6.0,
#   'WA': 28853,
#   'BA': 4295,
#   'IA': 413,
#   'AA': 233,
#   'NA': 83,
#   'TOM': 531,
#   'NH': 23352,
#   'H': 11056},
#  {'PCIncome': 21144.0,
#   'fip-year': '12029-2019',
#   'fips': 12029,
#   'POPESTIMATE': 16887,
#   'MFratio': 1.219053876478318,
#   'POPEST_MALE': 9277,
#   'POPEST_FEM': 7610,
#   'MEDIAN_AGE_TOT': 46.4,
#   'UNDER5_TOT': 776,
#   'AGE513_TOT': 1612,
#   'AGE1544_TOT': 5619,
#   'AGE4564_TOT': 4663,
#   'AGE65PLUS_TOT': 4029,
#   'RUCC_2013': 6.0,
#   'WA': 14732,
#   'BA': 1657,
#   'IA': 109,
#   'AA': 71,
#   'NA': 3,
#   'TOM': 315,
#   'NH': 16166,
#   'H': 721},
#  {'PCIncome': 19911.0,
#   'fip-year': '12029-2020',
#   'fips': 12029,
#   'POPESTIMATE': 16805,
#   'MFratio': 1.2341132677479394,
#   'POPEST_MALE': 9283,
#   'POPEST_FEM': 7522,
#   'MEDIAN_AGE_TOT': 46.4,
#   'UNDER5_TOT': 761,
#   'AGE513_TOT': 1604,
#   'AGE1544_TOT': 5612,
#   'AGE4564_TOT': 4626,
#   'AGE65PLUS_TOT': 4013,
#   'RUCC_2013': 6.0,
#   'WA': 14649,
#   'BA': 1627,
#   'IA': 121,
#   'AA': 85,
#   'NA': 5,
#   'TOM': 318,
#   'NH': 16090,
#   'H': 715},
#  {'PCIncome': 20320.0,
#   'fip-year': '12029-2021',
#   'fips': 12029,
#   'POPESTIMATE': 17102,
#   'MFratio': 1.23059866962306,
#   'POPEST_MALE': 9435,
#   'POPEST_FEM': 7667,
#   'MEDIAN_AGE_TOT': 45.9,
#   'UNDER5_TOT': 787,
#   'AGE513_TOT': 1624,
#   'AGE1544_TOT': 5788,
#   'AGE4564_TOT': 4603,
#   'AGE65PLUS_TOT': 4104,
#   'RUCC_2013': 6.0,
#   'WA': 14851,
#   'BA': 1664,
#   'IA': 126,
#   'AA': 88,
#   'NA': 7,
#   'TOM': 366,
#   'NH': 16339,
#   'H': 763},
#  {'PCIncome': 31327.0,
#   'fip-year': '12031-2019',
#   'fips': 12031,
#   'POPESTIMATE': 959853,
#   'MFratio': 0.9402885812701134,
#   'POPEST_MALE': 465157,
#   'POPEST_FEM': 494696,
#   'MEDIAN_AGE_TOT': 36.5,
#   'UNDER5_TOT': 64750,
#   'AGE513_TOT': 107675,
#   'AGE1544_TOT': 398527,
#   'AGE4564_TOT': 239246,
#   'AGE65PLUS_TOT': 138474,
#   'RUCC_2013': 1.0,
#   'WA': 580811,
#   'BA': 296161,
#   'IA': 4440,
#   'AA': 48034,
#   'NA': 1167,
#   'TOM': 29240,
#   'NH': 857878,
#   'H': 101975},
#  {'PCIncome': 32233.0,
#   'fip-year': '12031-2020',
#   'fips': 12031,
#   'POPESTIMATE': 996373,
#   'MFratio': 0.950158439987552,
#   'POPEST_MALE': 485454,
#   'POPEST_FEM': 510919,
#   'MEDIAN_AGE_TOT': 36.7,
#   'UNDER5_TOT': 65557,
#   'AGE513_TOT': 113623,
#   'AGE1544_TOT': 413128,
#   'AGE4564_TOT': 247424,
#   'AGE65PLUS_TOT': 144437,
#   'RUCC_2013': 1.0,
#   'WA': 600577,
#   'BA': 308908,
#   'IA': 4631,
#   'AA': 50169,
#   'NA': 1211,
#   'TOM': 30877,
#   'NH': 886330,
#   'H': 110043},
#  {'PCIncome': 34077.0,
#   'fip-year': '12031-2021',
#   'fips': 12031,
#   'POPESTIMATE': 999935,
#   'MFratio': 0.9476609992539974,
#   'POPEST_MALE': 486532,
#   'POPEST_FEM': 513403,
#   'MEDIAN_AGE_TOT': 36.9,
#   'UNDER5_TOT': 64203,
#   'AGE513_TOT': 113518,
#   'AGE1544_TOT': 415588,
#   'AGE4564_TOT': 245113,
#   'AGE65PLUS_TOT': 149041,
#   'RUCC_2013': 1.0,
#   'WA': 600177,
#   'BA': 311439,
#   'IA': 4770,
#   'AA': 50605,
#   'NA': 1207,
#   'TOM': 31737,
#   'NH': 886481,
#   'H': 113454},
#  {'PCIncome': 28022.0,
#   'fip-year': '12033-2019',
#   'fips': 12033,
#   'POPESTIMATE': 319379,
#   'MFratio': 0.9756827812316352,
#   'POPEST_MALE': 157724,
#   'POPEST_FEM': 161655,
#   'MEDIAN_AGE_TOT': 37.4,
#   'UNDER5_TOT': 19187,
#   'AGE513_TOT': 33480,
#   'AGE1544_TOT': 129517,
#   'AGE4564_TOT': 78967,
#   'AGE65PLUS_TOT': 54724,
#   'RUCC_2013': 2.0,
#   'WA': 219629,
#   'BA': 74305,
#   'IA': 2835,
#   'AA': 10701,
#   'NA': 606,
#   'TOM': 11303,
#   'NH': 300436,
#   'H': 18943},
#  {'PCIncome': 29166.0,
#   'fip-year': '12033-2020',
#   'fips': 12033,
#   'POPESTIMATE': 322424,
#   'MFratio': 0.9828054855174958,
#   'POPEST_MALE': 159814,
#   'POPEST_FEM': 162610,
#   'MEDIAN_AGE_TOT': 37.5,
#   'UNDER5_TOT': 19018,
#   'AGE513_TOT': 34238,
#   'AGE1544_TOT': 130973,
#   'AGE4564_TOT': 79422,
#   'AGE65PLUS_TOT': 54942,
#   'RUCC_2013': 2.0,
#   'WA': 221848,
#   'BA': 74659,
#   'IA': 2844,
#   'AA': 10698,
#   'NA': 618,
#   'TOM': 11757,
#   'NH': 302567,
#   'H': 19857},
#  {'PCIncome': 31085.0,
#   'fip-year': '12033-2021',
#   'fips': 12033,
#   'POPESTIMATE': 322390,
#   'MFratio': 0.9807692307692308,
#   'POPEST_MALE': 159630,
#   'POPEST_FEM': 162760,
#   'MEDIAN_AGE_TOT': 37.6,
#   'UNDER5_TOT': 18566,
#   'AGE513_TOT': 34134,
#   'AGE1544_TOT': 131679,
#   'AGE4564_TOT': 78139,
#   'AGE65PLUS_TOT': 56000,
#   'RUCC_2013': 2.0,
#   'WA': 221931,
#   'BA': 74297,
#   'IA': 2857,
#   'AA': 10740,
#   'NA': 638,
#   'TOM': 11927,
#   'NH': 301892,
#   'H': 20498},
#  {'PCIncome': 29383.0,
#   'fip-year': '12035-2019',
#   'fips': 12035,
#   'POPESTIMATE': 115481,
#   'MFratio': 0.9261600560429664,
#   'POPEST_MALE': 55527,
#   'POPEST_FEM': 59954,
#   'MEDIAN_AGE_TOT': 52.4,
#   'UNDER5_TOT': 4469,
#   'AGE513_TOT': 9870,
#   'AGE1544_TOT': 32378,
#   'AGE4564_TOT': 31705,
#   'AGE65PLUS_TOT': 35827,
#   'RUCC_2013': 2.0,
#   'WA': 96766,
#   'BA': 12620,
#   'IA': 472,
#   'AA': 2926,
#   'NA': 106,
#   'TOM': 2591,
#   'NH': 102941,
#   'H': 12540},
#  {'PCIncome': 32722.0,
#   'fip-year': '12035-2020',
#   'fips': 12035,
#   'POPESTIMATE': 115968,
#   'MFratio': 0.9396534421623068,
#   'POPEST_MALE': 56180,
#   'POPEST_FEM': 59788,
#   'MEDIAN_AGE_TOT': 52.7,
#   'UNDER5_TOT': 4343,
#   'AGE513_TOT': 9960,
#   'AGE1544_TOT': 32276,
#   'AGE4564_TOT': 32231,
#   'AGE65PLUS_TOT': 35931,
#   'RUCC_2013': 2.0,
#   'WA': 97274,
#   'BA': 12463,
#   'IA': 520,
#   'AA': 2911,
#   'NA': 113,
#   'TOM': 2687,
#   'NH': 103043,
#   'H': 12925},
#  {'PCIncome': 35568.0,
#   'fip-year': '12035-2021',
#   'fips': 12035,
#   'POPESTIMATE': 120932,
#   'MFratio': 0.9378575434660684,
#   'POPEST_MALE': 58527,
#   'POPEST_FEM': 62405,
#   'MEDIAN_AGE_TOT': 52.9,
#   'UNDER5_TOT': 4408,
#   'AGE513_TOT': 10188,
#   'AGE1544_TOT': 33736,
#   'AGE4564_TOT': 33628,
#   'AGE65PLUS_TOT': 37642,
#   'RUCC_2013': 2.0,
#   'WA': 101366,
#   'BA': 13009,
#   'IA': 555,
#   'AA': 3069,
#   'NA': 124,
#   'TOM': 2809,
#   'NH': 107167,
#   'H': 13765},
#  {'PCIncome': 26574.0,
#   'fip-year': '12037-2019',
#   'fips': 12037,
#   'POPESTIMATE': 12113,
#   'MFratio': 1.3165041116848346,
#   'POPEST_MALE': 6884,
#   'POPEST_FEM': 5229,
#   'MEDIAN_AGE_TOT': 46.2,
#   'UNDER5_TOT': 506,
#   'AGE513_TOT': 934,
#   'AGE1544_TOT': 4342,
#   'AGE4564_TOT': 3302,
#   'AGE65PLUS_TOT': 2923,
#   'RUCC_2013': 6.0,
#   'WA': 10101,
#   'BA': 1592,
#   'IA': 114,
#   'AA': 54,
#   'NA': 9,
#   'TOM': 243,
#   'NH': 11407,
#   'H': 706},
#  {'PCIncome': 26211.0,
#   'fip-year': '12037-2020',
#   'fips': 12037,
#   'POPESTIMATE': 12456,
#   'MFratio': 1.316533382927283,
#   'POPEST_MALE': 7079,
#   'POPEST_FEM': 5377,
#   'MEDIAN_AGE_TOT': 46.2,
#   'UNDER5_TOT': 505,
#   'AGE513_TOT': 979,
#   'AGE1544_TOT': 4455,
#   'AGE4564_TOT': 3398,
#   'AGE65PLUS_TOT': 3001,
#   'RUCC_2013': 6.0,
#   'WA': 10410,
#   'BA': 1616,
#   'IA': 118,
#   'AA': 57,
#   'NA': 12,
#   'TOM': 243,
#   'NH': 11712,
#   'H': 744},
#  {'PCIncome': 26933.0,
#   'fip-year': '12037-2021',
#   'fips': 12037,
#   'POPESTIMATE': 12572,
#   'MFratio': 1.3268554506755506,
#   'POPEST_MALE': 7169,
#   'POPEST_FEM': 5403,
#   'MEDIAN_AGE_TOT': 46.7,
#   'UNDER5_TOT': 473,
#   'AGE513_TOT': 946,
#   'AGE1544_TOT': 4512,
#   'AGE4564_TOT': 3437,
#   'AGE65PLUS_TOT': 3088,
#   'RUCC_2013': 6.0,
#   'WA': 10483,
#   'BA': 1639,
#   'IA': 119,
#   'AA': 58,
#   'NA': 15,
#   'TOM': 258,
#   'NH': 11813,
#   'H': 759},
#  {'PCIncome': 20734.0,
#   'fip-year': '12039-2019',
#   'fips': 12039,
#   'POPESTIMATE': 45670,
#   'MFratio': 0.9019656838247544,
#   'POPEST_MALE': 21658,
#   'POPEST_FEM': 24012,
#   'MEDIAN_AGE_TOT': 41.8,
#   'UNDER5_TOT': 2723,
#   'AGE513_TOT': 5000,
#   'AGE1544_TOT': 16450,
#   'AGE4564_TOT': 12387,
#   'AGE65PLUS_TOT': 8556,
#   'RUCC_2013': 2.0,
#   'WA': 19033,
#   'BA': 25451,
#   'IA': 283,
#   'AA': 308,
#   'NA': 63,
#   'TOM': 532,
#   'NH': 40782,
#   'H': 4888},
#  {'PCIncome': 21087.0,
#   'fip-year': '12039-2020',
#   'fips': 12039,
#   'POPESTIMATE': 43701,
#   'MFratio': 0.9168786735678568,
#   'POPEST_MALE': 20903,
#   'POPEST_FEM': 22798,
#   'MEDIAN_AGE_TOT': 42.1,
#   'UNDER5_TOT': 2530,
#   'AGE513_TOT': 4791,
#   'AGE1544_TOT': 15568,
#   'AGE4564_TOT': 11979,
#   'AGE65PLUS_TOT': 8260,
#   'RUCC_2013': 2.0,
#   'WA': 18185,
#   'BA': 24300,
#   'IA': 285,
#   'AA': 310,
#   'NA': 67,
#   'TOM': 554,
#   'NH': 38916,
#   'H': 4785},
#  {'PCIncome': 21651.0,
#   'fip-year': '12039-2021',
#   'fips': 12039,
#   'POPESTIMATE': 43714,
#   'MFratio': 0.9050814956855224,
#   'POPEST_MALE': 20768,
#   'POPEST_FEM': 22946,
#   'MEDIAN_AGE_TOT': 42.3,
#   'UNDER5_TOT': 2457,
#   'AGE513_TOT': 4687,
#   'AGE1544_TOT': 15618,
#   'AGE4564_TOT': 11924,
#   'AGE65PLUS_TOT': 8456,
#   'RUCC_2013': 2.0,
#   'WA': 18425,
#   'BA': 24049,
#   'IA': 281,
#   'AA': 304,
#   'NA': 75,
#   'TOM': 580,
#   'NH': 38828,
#   'H': 4886},
#  {'PCIncome': 21578.0,
#   'fip-year': '12041-2019',
#   'fips': 12041,
#   'POPESTIMATE': 18572,
#   'MFratio': 1.0720740823385029,
#   'POPEST_MALE': 9609,
#   'POPEST_FEM': 8963,
#   'MEDIAN_AGE_TOT': 42.6,
#   'UNDER5_TOT': 1003,
#   'AGE513_TOT': 1849,
#   'AGE1544_TOT': 6671,
#   'AGE4564_TOT': 5020,
#   'AGE65PLUS_TOT': 3827,
#   'RUCC_2013': 2.0,
#   'WA': 16976,
#   'BA': 1038,
#   'IA': 135,
#   'AA': 104,
#   'NA': 18,
#   'TOM': 301,
#   'NH': 17460,
#   'H': 1112},
#  {'PCIncome': 22775.0,
#   'fip-year': '12041-2020',
#   'fips': 12041,
#   'POPESTIMATE': 17928,
#   'MFratio': 1.0836820083682008,
#   'POPEST_MALE': 9324,
#   'POPEST_FEM': 8604,
#   'MEDIAN_AGE_TOT': 42.1,
#   'UNDER5_TOT': 950,
#   'AGE513_TOT': 1849,
#   'AGE1544_TOT': 6453,
#   'AGE4564_TOT': 4774,
#   'AGE65PLUS_TOT': 3691,
#   'RUCC_2013': 2.0,
#   'WA': 16335,
#   'BA': 1023,
#   'IA': 154,
#   'AA': 103,
#   'NA': 19,
#   'TOM': 294,
#   'NH': 16758,
#   'H': 1170},
#  {'PCIncome': 24959.0,
#   'fip-year': '12041-2021',
#   'fips': 12041,
#   'POPESTIMATE': 18360,
#   'MFratio': 1.0759837177747626,
#   'POPEST_MALE': 9516,
#   'POPEST_FEM': 8844,
#   'MEDIAN_AGE_TOT': 42.1,
#   'UNDER5_TOT': 985,
#   'AGE513_TOT': 1889,
#   'AGE1544_TOT': 6630,
#   'AGE4564_TOT': 4770,
#   'AGE65PLUS_TOT': 3868,
#   'RUCC_2013': 2.0,
#   'WA': 16705,
#   'BA': 1076,
#   'IA': 144,
#   'AA': 109,
#   'NA': 19,
#   'TOM': 307,
#   'NH': 17129,
#   'H': 1231},
#  {'PCIncome': 21953.0,
#   'fip-year': '12043-2019',
#   'fips': 12043,
#   'POPESTIMATE': 13914,
#   'MFratio': 1.2583996104528483,
#   'POPEST_MALE': 7753,
#   'POPEST_FEM': 6161,
#   'MEDIAN_AGE_TOT': 47.9,
#   'UNDER5_TOT': 410,
#   'AGE513_TOT': 1082,
#   'AGE1544_TOT': 4811,
#   'AGE4564_TOT': 3547,
#   'AGE65PLUS_TOT': 3928,
#   'RUCC_2013': 6.0,
#   'WA': 10994,
#   'BA': 1883,
#   'IA': 725,
#   'AA': 93,
#   'NA': 14,
#   'TOM': 205,
#   'NH': 10934,
#   'H': 2980},
#  {'PCIncome': 22128.0,
#   'fip-year': '12043-2020',
#   'fips': 12043,
#   'POPESTIMATE': 12179,
#   'MFratio': 1.2696608274319792,
#   'POPEST_MALE': 6813,
#   'POPEST_FEM': 5366,
#   'MEDIAN_AGE_TOT': 48.3,
#   'UNDER5_TOT': 356,
#   'AGE513_TOT': 947,
#   'AGE1544_TOT': 4172,
#   'AGE4564_TOT': 3144,
#   'AGE65PLUS_TOT': 3445,
#   'RUCC_2013': 6.0,
#   'WA': 9572,
#   'BA': 1653,
#   'IA': 633,
#   'AA': 88,
#   'NA': 16,
#   'TOM': 217,
#   'NH': 9486,
#   'H': 2693},
#  {'PCIncome': 21645.0,
#   'fip-year': '12043-2021',
#   'fips': 12043,
#   'POPESTIMATE': 12234,
#   'MFratio': 1.2735551012822894,
#   'POPEST_MALE': 6853,
#   'POPEST_FEM': 5381,
#   'MEDIAN_AGE_TOT': 48.3,
#   'UNDER5_TOT': 340,
#   'AGE513_TOT': 918,
#   'AGE1544_TOT': 4255,
#   'AGE4564_TOT': 3159,
#   'AGE65PLUS_TOT': 3439,
#   'RUCC_2013': 6.0,
#   'WA': 9573,
#   'BA': 1704,
#   'IA': 642,
#   'AA': 93,
#   'NA': 11,
#   'TOM': 211,
#   'NH': 9516,
#   'H': 2718},
#  {'PCIncome': 23252.0,
#   'fip-year': '12045-2019',
#   'fips': 12045,
#   'POPESTIMATE': 13498,
#   'MFratio': 1.010126582278481,
#   'POPEST_MALE': 6783,
#   'POPEST_FEM': 6715,
#   'MEDIAN_AGE_TOT': 49.3,
#   'UNDER5_TOT': 649,
#   'AGE513_TOT': 1304,
#   'AGE1544_TOT': 3988,
#   'AGE4564_TOT': 3924,
#   'AGE65PLUS_TOT': 3480,
#   'RUCC_2013': 3.0,
#   'WA': 11471,
#   'BA': 1524,
#   'IA': 100,
#   'AA': 79,
#   'NA': 3,
#   'TOM': 321,
#   'NH': 13096,
#   'H': 402},
#  {'PCIncome': 27626.0,
#   'fip-year': '12045-2020',
#   'fips': 12045,
#   'POPESTIMATE': 14181,
#   'MFratio': 1.0192225544639044,
#   'POPEST_MALE': 7158,
#   'POPEST_FEM': 7023,
#   'MEDIAN_AGE_TOT': 49.3,
#   'UNDER5_TOT': 640,
#   'AGE513_TOT': 1417,
#   'AGE1544_TOT': 4200,
#   'AGE4564_TOT': 4143,
#   'AGE65PLUS_TOT': 3625,
#   'RUCC_2013': 3.0,
#   'WA': 12054,
#   'BA': 1615,
#   'IA': 102,
#   'AA': 79,
#   'NA': 5,
#   'TOM': 326,
#   'NH': 13756,
#   'H': 425},
#  {'PCIncome': 27704.0,
#   'fip-year': '12045-2021',
#   'fips': 12045,
#   'POPESTIMATE': 14363,
#   'MFratio': 1.009092180724577,
#   'POPEST_MALE': 7214,
#   'POPEST_FEM': 7149,
#   'MEDIAN_AGE_TOT': 49.6,
#   'UNDER5_TOT': 592,
#   'AGE513_TOT': 1425,
#   'AGE1544_TOT': 4276,
#   'AGE4564_TOT': 4163,
#   'AGE65PLUS_TOT': 3729,
#   'RUCC_2013': 3.0,
#   'WA': 12156,
#   'BA': 1627,
#   'IA': 112,
#   'AA': 100,
#   'NA': 4,
#   'TOM': 364,
#   'NH': 13880,
#   'H': 483},
#  {'PCIncome': 16136.0,
#   'fip-year': '12047-2019',
#   'fips': 12047,
#   'POPESTIMATE': 14470,
#   'MFratio': 1.3803257114657017,
#   'POPEST_MALE': 8391,
#   'POPEST_FEM': 6079,
#   'MEDIAN_AGE_TOT': 40.0,
#   'UNDER5_TOT': 782,
#   'AGE513_TOT': 1348,
#   'AGE1544_TOT': 5788,
#   'AGE4564_TOT': 3768,
#   'AGE65PLUS_TOT': 2641,
#   'RUCC_2013': 6.0,
#   'WA': 9066,
#   'BA': 4817,
#   'IA': 155,
#   'AA': 111,
#   'NA': 5,
#   'TOM': 316,
#   'NH': 13009,
#   'H': 1461},
#  {'PCIncome': 15532.0,
#   'fip-year': '12047-2020',
#   'fips': 12047,
#   'POPESTIMATE': 13988,
#   'MFratio': 1.3894772804919713,
#   'POPEST_MALE': 8134,
#   'POPEST_FEM': 5854,
#   'MEDIAN_AGE_TOT': 40.0,
#   'UNDER5_TOT': 743,
#   'AGE513_TOT': 1336,
#   'AGE1544_TOT': 5573,
#   'AGE4564_TOT': 3619,
#   'AGE65PLUS_TOT': 2554,
#   'RUCC_2013': 6.0,
#   'WA': 8726,
#   'BA': 4651,
#   'IA': 169,
#   'AA': 109,
#   'NA': 8,
#   'TOM': 325,
#   'NH': 12521,
#   'H': 1467},
#  {'PCIncome': 15624.0,
#   'fip-year': '12047-2021',
#   'fips': 12047,
#   'POPESTIMATE': 13993,
#   'MFratio': 1.4071907792878031,
#   'POPEST_MALE': 8180,
#   'POPEST_FEM': 5813,
#   'MEDIAN_AGE_TOT': 40.3,
#   'UNDER5_TOT': 746,
#   'AGE513_TOT': 1319,
#   'AGE1544_TOT': 5564,
#   'AGE4564_TOT': 3594,
#   'AGE65PLUS_TOT': 2609,
#   'RUCC_2013': 6.0,
#   'WA': 8732,
#   'BA': 4620,
#   'IA': 170,
#   'AA': 114,
#   'NA': 8,
#   'TOM': 349,
#   'NH': 12454,
#   'H': 1539},
#  {'PCIncome': 17754.0,
#   'fip-year': '12049-2019',
#   'fips': 12049,
#   'POPESTIMATE': 26806,
#   'MFratio': 1.1162074682245204,
#   'POPEST_MALE': 14139,
#   'POPEST_FEM': 12667,
#   'MEDIAN_AGE_TOT': 35.6,
#   'UNDER5_TOT': 1839,
#   'AGE513_TOT': 3599,
#   'AGE1544_TOT': 10394,
#   'AGE4564_TOT': 6045,
#   'AGE65PLUS_TOT': 4531,
#   'RUCC_2013': 6.0,
#   'WA': 23654,
#   'BA': 2029,
#   'IA': 312,
#   'AA': 308,
#   'NA': 40,
#   'TOM': 463,
#   'NH': 15052,
#   'H': 11754},
#  {'PCIncome': 20181.0,
#   'fip-year': '12049-2020',
#   'fips': 12049,
#   'POPESTIMATE': 25313,
#   'MFratio': 1.1184199514603732,
#   'POPEST_MALE': 13364,
#   'POPEST_FEM': 11949,
#   'MEDIAN_AGE_TOT': 35.7,
#   'UNDER5_TOT': 1668,
#   'AGE513_TOT': 3436,
#   'AGE1544_TOT': 9858,
#   'AGE4564_TOT': 5755,
#   'AGE65PLUS_TOT': 4201,
#   'RUCC_2013': 6.0,
#   'WA': 22283,
#   'BA': 1884,
#   'IA': 322,
#   'AA': 296,
#   'NA': 51,
#   'TOM': 477,
#   'NH': 14020,
#   'H': 11293},
#  {'PCIncome': 22377.0,
#   'fip-year': '12049-2021',
#   'fips': 12049,
#   'POPESTIMATE': 25425,
#   'MFratio': 1.132969798657718,
#   'POPEST_MALE': 13505,
#   'POPEST_FEM': 11920,
#   'MEDIAN_AGE_TOT': 36.0,
#   'UNDER5_TOT': 1648,
#   'AGE513_TOT': 3365,
#   'AGE1544_TOT': 9935,
#   'AGE4564_TOT': 5776,
#   'AGE65PLUS_TOT': 4286,
#   'RUCC_2013': 6.0,
#   'WA': 22259,
#   'BA': 1977,
#   'IA': 328,
#   'AA': 311,
#   'NA': 52,
#   'TOM': 498,
#   'NH': 14192,
#   'H': 11233},
#  {'PCIncome': 19167.0,
#   'fip-year': '12051-2019',
#   'fips': 12051,
#   'POPESTIMATE': 42069,
#   'MFratio': 1.1227671813502875,
#   'POPEST_MALE': 22251,
#   'POPEST_FEM': 19818,
#   'MEDIAN_AGE_TOT': 35.0,
#   'UNDER5_TOT': 3059,
#   'AGE513_TOT': 5739,
#   'AGE1544_TOT': 16824,
#   'AGE4564_TOT': 10007,
#   'AGE65PLUS_TOT': 5782,
#   'RUCC_2013': 4.0,
#   'WA': 34977,
#   'BA': 5039,
#   'IA': 833,
#   'AA': 417,
#   'NA': 84,
#   'TOM': 719,
#   'NH': 18873,
#   'H': 23196},
#  {'PCIncome': 20122.0,
#   'fip-year': '12051-2020',
#   'fips': 12051,
#   'POPESTIMATE': 39707,
#   'MFratio': 1.1226879076232226,
#   'POPEST_MALE': 21001,
#   'POPEST_FEM': 18706,
#   'MEDIAN_AGE_TOT': 35.2,
#   'UNDER5_TOT': 2801,
#   'AGE513_TOT': 5476,
#   'AGE1544_TOT': 15880,
#   'AGE4564_TOT': 9497,
#   'AGE65PLUS_TOT': 5400,
#   'RUCC_2013': 4.0,
#   'WA': 32788,
#   'BA': 4771,
#   'IA': 836,
#   'AA': 420,
#   'NA': 89,
#   'TOM': 803,
#   'NH': 17535,
#   'H': 22172},
#  {'PCIncome': 20473.0,
#   'fip-year': '12051-2021',
#   'fips': 12051,
#   'POPESTIMATE': 40313,
#   'MFratio': 1.1230777333052455,
#   'POPEST_MALE': 21325,
#   'POPEST_FEM': 18988,
#   'MEDIAN_AGE_TOT': 35.5,
#   'UNDER5_TOT': 2813,
#   'AGE513_TOT': 5420,
#   'AGE1544_TOT': 16137,
#   'AGE4564_TOT': 9726,
#   'AGE65PLUS_TOT': 5530,
#   'RUCC_2013': 4.0,
#   'WA': 33184,
#   'BA': 4868,
#   'IA': 857,
#   'AA': 439,
#   'NA': 92,
#   'TOM': 873,
#   'NH': 17532,
#   'H': 22781},
#  {'PCIncome': 25860.0,
#   'fip-year': '12053-2019',
#   'fips': 12053,
#   'POPESTIMATE': 194290,
#   'MFratio': 0.9320611370213104,
#   'POPEST_MALE': 93729,
#   'POPEST_FEM': 100561,
#   'MEDIAN_AGE_TOT': 48.8,
#   'UNDER5_TOT': 8770,
#   'AGE513_TOT': 18110,
#   'AGE1544_TOT': 59727,
#   'AGE4564_TOT': 51793,
#   'AGE65PLUS_TOT': 53644,
#   'RUCC_2013': 1.0,
#   'WA': 174018,
#   'BA': 11946,
#   'IA': 995,
#   'AA': 2788,
#   'NA': 181,
#   'TOM': 4362,
#   'NH': 165597,
#   'H': 28693},
#  {'PCIncome': 26520.0,
#   'fip-year': '12053-2020',
#   'fips': 12053,
#   'POPESTIMATE': 195508,
#   'MFratio': 0.9454693812565924,
#   'POPEST_MALE': 95014,
#   'POPEST_FEM': 100494,
#   'MEDIAN_AGE_TOT': 48.5,
#   'UNDER5_TOT': 8651,
#   'AGE513_TOT': 18601,
#   'AGE1544_TOT': 60956,
#   'AGE4564_TOT': 52427,
#   'AGE65PLUS_TOT': 52574,
#   'RUCC_2013': 1.0,
#   'WA': 174574,
#   'BA': 12280,
#   'IA': 1067,
#   'AA': 2882,
#   'NA': 202,
#   'TOM': 4503,
#   'NH': 165191,
#   'H': 30317},
#  {'PCIncome': 28400.0,
#   'fip-year': '12053-2021',
#   'fips': 12053,
#   'POPESTIMATE': 200638,
#   'MFratio': 0.9455051440428978,
#   'POPEST_MALE': 97509,
#   'POPEST_FEM': 103129,
#   'MEDIAN_AGE_TOT': 48.0,
#   'UNDER5_TOT': 8845,
#   'AGE513_TOT': 19124,
#   'AGE1544_TOT': 63555,
#   'AGE4564_TOT': 53295,
#   'AGE65PLUS_TOT': 53434,
#   'RUCC_2013': 1.0,
#   'WA': 178420,
#   'BA': 12975,
#   'IA': 1111,
#   'AA': 3057,
#   'NA': 216,
#   'TOM': 4859,
#   'NH': 168146,
#   'H': 32492},
#  {'PCIncome': 25752.0,
#   'fip-year': '12055-2019',
#   'fips': 12055,
#   'POPESTIMATE': 105890,
#   'MFratio': 0.9503794297502396,
#   'POPEST_MALE': 51598,
#   'POPEST_FEM': 54292,
#   'MEDIAN_AGE_TOT': 54.3,
#   'UNDER5_TOT': 4574,
#   'AGE513_TOT': 9179,
#   'AGE1544_TOT': 28807,
#   'AGE4564_TOT': 24169,
#   'AGE65PLUS_TOT': 38125,
#   'RUCC_2013': 3.0,
#   'WA': 90260,
#   'BA': 11308,
#   'IA': 684,
#   'AA': 1690,
#   'NA': 110,
#   'TOM': 1838,
#   'NH': 83728,
#   'H': 22162},
#  {'PCIncome': 27979.0,
#   'fip-year': '12055-2020',
#   'fips': 12055,
#   'POPESTIMATE': 101222,
#   'MFratio': 0.961172572801426,
#   'POPEST_MALE': 49609,
#   'POPEST_FEM': 51613,
#   'MEDIAN_AGE_TOT': 54.1,
#   'UNDER5_TOT': 4233,
#   'AGE513_TOT': 8961,
#   'AGE1544_TOT': 27662,
#   'AGE4564_TOT': 23286,
#   'AGE65PLUS_TOT': 36050,
#   'RUCC_2013': 3.0,
#   'WA': 86036,
#   'BA': 10872,
#   'IA': 703,
#   'AA': 1604,
#   'NA': 109,
#   'TOM': 1898,
#   'NH': 79420,
#   'H': 21802},
#  {'PCIncome': 28519.0,
#   'fip-year': '12055-2021',
#   'fips': 12055,
#   'POPESTIMATE': 103296,
#   'MFratio': 0.9646239872189888,
#   'POPEST_MALE': 50718,
#   'POPEST_FEM': 52578,
#   'MEDIAN_AGE_TOT': 54.0,
#   'UNDER5_TOT': 4205,
#   'AGE513_TOT': 9073,
#   'AGE1544_TOT': 28505,
#   'AGE4564_TOT': 23507,
#   'AGE65PLUS_TOT': 36883,
#   'RUCC_2013': 3.0,
#   'WA': 87670,
#   'BA': 11118,
#   'IA': 752,
#   'AA': 1646,
#   'NA': 107,
#   'TOM': 2003,
#   'NH': 80487,
#   'H': 22809},
#  {'PCIncome': 32343.0,
#   'fip-year': '12057-2019',
#   'fips': 12057,
#   'POPESTIMATE': 1476431,
#   'MFratio': 0.9588197443398542,
#   'POPEST_MALE': 722696,
#   'POPEST_FEM': 753735,
#   'MEDIAN_AGE_TOT': 37.6,
#   'UNDER5_TOT': 89093,
#   'AGE513_TOT': 165174,
#   'AGE1544_TOT': 614511,
#   'AGE4564_TOT': 374525,
#   'AGE65PLUS_TOT': 215071,
#   'RUCC_2013': 1.0,
#   'WA': 1090460,
#   'BA': 266794,
#   'IA': 7836,
#   'AA': 66784,
#   'NA': 1974,
#   'TOM': 42583,
#   'NH': 1040438,
#   'H': 435993},
#  {'PCIncome': 33616.0,
#   'fip-year': '12057-2020',
#   'fips': 12057,
#   'POPESTIMATE': 1463380,
#   'MFratio': 0.9704044810685624,
#   'POPEST_MALE': 720700,
#   'POPEST_FEM': 742680,
#   'MEDIAN_AGE_TOT': 37.8,
#   'UNDER5_TOT': 85982,
#   'AGE513_TOT': 165434,
#   'AGE1544_TOT': 607701,
#   'AGE4564_TOT': 373195,
#   'AGE65PLUS_TOT': 212353,
#   'RUCC_2013': 1.0,
#   'WA': 1077085,
#   'BA': 266736,
#   'IA': 7879,
#   'AA': 66494,
#   'NA': 2005,
#   'TOM': 43181,
#   'NH': 1023776,
#   'H': 439604},
#  {'PCIncome': 35954.0,
#   'fip-year': '12057-2021',
#   'fips': 12057,
#   'POPESTIMATE': 1478194,
#   'MFratio': 0.9697146154163908,
#   'POPEST_MALE': 727733,
#   'POPEST_FEM': 750461,
#   'MEDIAN_AGE_TOT': 38.0,
#   'UNDER5_TOT': 84930,
#   'AGE513_TOT': 165693,
#   'AGE1544_TOT': 614329,
#   'AGE4564_TOT': 374682,
#   'AGE65PLUS_TOT': 219177,
#   'RUCC_2013': 1.0,
#   'WA': 1083063,
#   'BA': 272285,
#   'IA': 8052,
#   'AA': 67802,
#   'NA': 2082,
#   'TOM': 44910,
#   'NH': 1030273,
#   'H': 447921},
#  {'PCIncome': 19201.0,
#   'fip-year': '12059-2019',
#   'fips': 12059,
#   'POPESTIMATE': 19661,
#   'MFratio': 1.1315047701647876,
#   'POPEST_MALE': 10437,
#   'POPEST_FEM': 9224,
#   'MEDIAN_AGE_TOT': 42.5,
#   'UNDER5_TOT': 1082,
#   'AGE513_TOT': 1956,
#   'AGE1544_TOT': 7106,
#   'AGE4564_TOT': 5291,
#   'AGE65PLUS_TOT': 3977,
#   'RUCC_2013': 6.0,
#   'WA': 17489,
#   'BA': 1322,
#   'IA': 214,
#   'AA': 141,
#   'NA': 37,
#   'TOM': 458,
#   'NH': 19055,
#   'H': 606},
#  {'PCIncome': 19028.0,
#   'fip-year': '12059-2020',
#   'fips': 12059,
#   'POPESTIMATE': 19622,
#   'MFratio': 1.1468271334792122,
#   'POPEST_MALE': 10482,
#   'POPEST_FEM': 9140,
#   'MEDIAN_AGE_TOT': 42.4,
#   'UNDER5_TOT': 1023,
#   'AGE513_TOT': 2015,
#   'AGE1544_TOT': 7119,
#   'AGE4564_TOT': 5317,
#   'AGE65PLUS_TOT': 3904,
#   'RUCC_2013': 6.0,
#   'WA': 17435,
#   'BA': 1334,
#   'IA': 230,
#   'AA': 143,
#   'NA': 36,
#   'TOM': 444,
#   'NH': 18989,
#   'H': 633},
#  {'PCIncome': 20993.0,
#   'fip-year': '12059-2021',
#   'fips': 12059,
#   'POPESTIMATE': 19784,
#   'MFratio': 1.1577053113752862,
#   'POPEST_MALE': 10615,
#   'POPEST_FEM': 9169,
#   'MEDIAN_AGE_TOT': 42.1,
#   'UNDER5_TOT': 1016,
#   'AGE513_TOT': 2051,
#   'AGE1544_TOT': 7241,
#   'AGE4564_TOT': 5283,
#   'AGE65PLUS_TOT': 3951,
#   'RUCC_2013': 6.0,
#   'WA': 17445,
#   'BA': 1419,
#   'IA': 233,
#   'AA': 154,
#   'NA': 37,
#   'TOM': 496,
#   'NH': 19128,
#   'H': 656},
#  {'PCIncome': 36516.0,
#   'fip-year': '12061-2019',
#   'fips': 12061,
#   'POPESTIMATE': 159739,
#   'MFratio': 0.922782478905112,
#   'POPEST_MALE': 76662,
#   'POPEST_FEM': 83077,
#   'MEDIAN_AGE_TOT': 54.5,
#   'UNDER5_TOT': 6414,
#   'AGE513_TOT': 12373,
#   'AGE1544_TOT': 43244,
#   'AGE4564_TOT': 42140,
#   'AGE65PLUS_TOT': 54069,
#   'RUCC_2013': 3.0,
#   'WA': 138583,
#   'BA': 15213,
#   'IA': 733,
#   'AA': 2617,
#   'NA': 81,
#   'TOM': 2512,
#   'NH': 139425,
#   'H': 20314},
#  {'PCIncome': 38274.0,
#   'fip-year': '12061-2020',
#   'fips': 12061,
#   'POPESTIMATE': 160345,
#   'MFratio': 0.9350848398542154,
#   'POPEST_MALE': 77483,
#   'POPEST_FEM': 82862,
#   'MEDIAN_AGE_TOT': 54.7,
#   'UNDER5_TOT': 6343,
#   'AGE513_TOT': 12366,
#   'AGE1544_TOT': 43370,
#   'AGE4564_TOT': 42518,
#   'AGE65PLUS_TOT': 54213,
#   'RUCC_2013': 3.0,
#   'WA': 138851,
#   'BA': 15316,
#   'IA': 779,
#   'AA': 2678,
#   'NA': 97,
#   'TOM': 2624,
#   'NH': 139407,
#   'H': 20938},
#  {'PCIncome': 40318.0,
#   'fip-year': '12061-2021',
#   'fips': 12061,
#   'POPESTIMATE': 163662,
#   'MFratio': 0.9354541154210028,
#   'POPEST_MALE': 79102,
#   'POPEST_FEM': 84560,
#   'MEDIAN_AGE_TOT': 55.0,
#   'UNDER5_TOT': 6306,
#   'AGE513_TOT': 12410,
#   'AGE1544_TOT': 44434,
#   'AGE4564_TOT': 42842,
#   'AGE65PLUS_TOT': 56134,
#   'RUCC_2013': 3.0,
#   'WA': 141742,
#   'BA': 15528,
#   'IA': 778,
#   'AA': 2715,
#   'NA': 92,
#   'TOM': 2807,
#   'NH': 141834,
#   'H': 21828},
#  {'PCIncome': 20019.0,
#   'fip-year': '12063-2019',
#   'fips': 12063,
#   'POPESTIMATE': 46257,
#   'MFratio': 1.1725061055795605,
#   'POPEST_MALE': 24965,
#   'POPEST_FEM': 21292,
#   'MEDIAN_AGE_TOT': 42.3,
#   'UNDER5_TOT': 2410,
#   'AGE513_TOT': 4239,
#   'AGE1544_TOT': 17563,
#   'AGE4564_TOT': 12095,
#   'AGE65PLUS_TOT': 9427,
#   'RUCC_2013': 6.0,
#   'WA': 32194,
#   'BA': 12213,
#   'IA': 420,
#   'AA': 312,
#   'NA': 115,
#   'TOM': 1003,
#   'NH': 44000,
#   'H': 2257},
#  {'PCIncome': 21058.0,
#   'fip-year': '12063-2020',
#   'fips': 12063,
#   'POPESTIMATE': 47214,
#   'MFratio': 1.192227329711659,
#   'POPEST_MALE': 25677,
#   'POPEST_FEM': 21537,
#   'MEDIAN_AGE_TOT': 42.2,
#   'UNDER5_TOT': 2404,
#   'AGE513_TOT': 4431,
#   'AGE1544_TOT': 17988,
#   'AGE4564_TOT': 12326,
#   'AGE65PLUS_TOT': 9539,
#   'RUCC_2013': 6.0,
#   'WA': 32892,
#   'BA': 12470,
#   'IA': 420,
#   'AA': 328,
#   'NA': 117,
#   'TOM': 987,
#   'NH': 44804,
#   'H': 2410},
#  {'PCIncome': 21660.0,
#   'fip-year': '12063-2021',
#   'fips': 12063,
#   'POPESTIMATE': 47694,
#   'MFratio': 1.196665438467207,
#   'POPEST_MALE': 25982,
#   'POPEST_FEM': 21712,
#   'MEDIAN_AGE_TOT': 41.9,
#   'UNDER5_TOT': 2463,
#   'AGE513_TOT': 4432,
#   'AGE1544_TOT': 18325,
#   'AGE4564_TOT': 12316,
#   'AGE65PLUS_TOT': 9628,
#   'RUCC_2013': 6.0,
#   'WA': 33183,
#   'BA': 12557,
#   'IA': 425,
#   'AA': 321,
#   'NA': 117,
#   'TOM': 1091,
#   'NH': 45131,
#   'H': 2563},
#  {'PCIncome': 24510.0,
#   'fip-year': '12065-2019',
#   'fips': 12065,
#   'POPESTIMATE': 14280,
#   'MFratio': 1.1071270473660912,
#   'POPEST_MALE': 7503,
#   'POPEST_FEM': 6777,
#   'MEDIAN_AGE_TOT': 48.3,
#   'UNDER5_TOT': 599,
#   'AGE513_TOT': 1226,
#   'AGE1544_TOT': 4537,
#   'AGE4564_TOT': 4319,
#   'AGE65PLUS_TOT': 3455,
#   'RUCC_2013': 2.0,
#   'WA': 9101,
#   'BA': 4778,
#   'IA': 66,
#   'AA': 108,
#   'NA': 5,
#   'TOM': 222,
#   'NH': 13674,
#   'H': 606},
#  {'PCIncome': 25795.0,
#   'fip-year': '12065-2020',
#   'fips': 12065,
#   'POPESTIMATE': 14560,
#   'MFratio': 1.1153566758680808,
# ...
#   'POPEST_MALE': 11131,
#   'POPEST_FEM': 10904,
#   'MEDIAN_AGE_TOT': 50.7,
#   'UNDER5_TOT': 929,
#   'AGE513_TOT': 2155,
#   'AGE1544_TOT': 6298,
#   'AGE4564_TOT': 6057,
#   'AGE65PLUS_TOT': 6332,
#   'RUCC_2013': 6.0,
#   'WA': 21431,
#   'BA': 163,
#   'IA': 76,
#   'AA': 95,
#   'NA': 14,
#   'TOM': 256,
#   'NH': 21326,
#   'H': 709},
#  {'PCIncome': 35722.0,
#   'fip-year': '17085-2021',
#   'fips': 17085,
#   'POPESTIMATE': 21939,
#   'MFratio': 1.0220276497695853,
#   'POPEST_MALE': 11089,
#   'POPEST_FEM': 10850,
#   'MEDIAN_AGE_TOT': 51.1,
#   'UNDER5_TOT': 882,
#   'AGE513_TOT': 2069,
#   'AGE1544_TOT': 6323,
#   'AGE4564_TOT': 5987,
#   'AGE65PLUS_TOT': 6417,
#   'RUCC_2013': 6.0,
#   'WA': 21297,
#   'BA': 182,
#   'IA': 72,
#   'AA': 102,
#   'NA': 13,
#   'TOM': 273,
#   'NH': 21199,
#   'H': 740},
#  {'PCIncome': 23140.0,
#   'fip-year': '17087-2019',
#   'fips': 17087,
#   'POPESTIMATE': 12380,
#   'MFratio': 1.201280227596017,
#   'POPEST_MALE': 6756,
#   'POPEST_FEM': 5624,
#   'MEDIAN_AGE_TOT': 43.9,
#   'UNDER5_TOT': 581,
#   'AGE513_TOT': 1150,
#   'AGE1544_TOT': 4487,
#   'AGE4564_TOT': 3333,
#   'AGE65PLUS_TOT': 2697,
#   'RUCC_2013': 8.0,
#   'WA': 11270,
#   'BA': 882,
#   'IA': 51,
#   'AA': 35,
#   'NA': 4,
#   'TOM': 138,
#   'NH': 12000,
#   'H': 380},
#  {'PCIncome': 23548.0,
#   'fip-year': '17087-2020',
#   'fips': 17087,
#   'POPESTIMATE': 13307,
#   'MFratio': 1.2207943925233644,
#   'POPEST_MALE': 7315,
#   'POPEST_FEM': 5992,
#   'MEDIAN_AGE_TOT': 43.6,
#   'UNDER5_TOT': 610,
#   'AGE513_TOT': 1271,
#   'AGE1544_TOT': 4853,
#   'AGE4564_TOT': 3577,
#   'AGE65PLUS_TOT': 2849,
#   'RUCC_2013': 8.0,
#   'WA': 12119,
#   'BA': 944,
#   'IA': 52,
#   'AA': 38,
#   'NA': 4,
#   'TOM': 150,
#   'NH': 12906,
#   'H': 401},
#  {'PCIncome': 24054.0,
#   'fip-year': '17087-2021',
#   'fips': 17087,
#   'POPESTIMATE': 13463,
#   'MFratio': 1.2741554054054054,
#   'POPEST_MALE': 7543,
#   'POPEST_FEM': 5920,
#   'MEDIAN_AGE_TOT': 43.7,
#   'UNDER5_TOT': 554,
#   'AGE513_TOT': 1254,
#   'AGE1544_TOT': 4995,
#   'AGE4564_TOT': 3633,
#   'AGE65PLUS_TOT': 2882,
#   'RUCC_2013': 8.0,
#   'WA': 12069,
#   'BA': 1139,
#   'IA': 53,
#   'AA': 40,
#   'NA': 4,
#   'TOM': 158,
#   'NH': 13017,
#   'H': 446},
#  {'PCIncome': 36270.0,
#   'fip-year': '17089-2019',
#   'fips': 17089,
#   'POPESTIMATE': 532293,
#   'MFratio': 0.9922487293305686,
#   'POPEST_MALE': 265111,
#   'POPEST_FEM': 267182,
#   'MEDIAN_AGE_TOT': 38.1,
#   'UNDER5_TOT': 32921,
#   'AGE513_TOT': 66855,
#   'AGE1544_TOT': 207258,
#   'AGE4564_TOT': 141234,
#   'AGE65PLUS_TOT': 75759,
#   'RUCC_2013': 1.0,
#   'WA': 460034,
#   'BA': 32228,
#   'IA': 5511,
#   'AA': 23428,
#   'NA': 415,
#   'TOM': 10677,
#   'NH': 361017,
#   'H': 171276},
#  {'PCIncome': 37548.0,
#   'fip-year': '17089-2020',
#   'fips': 17089,
#   'POPESTIMATE': 516155,
#   'MFratio': 1.0044153796566333,
#   'POPEST_MALE': 258646,
#   'POPEST_FEM': 257509,
#   'MEDIAN_AGE_TOT': 38.3,
#   'UNDER5_TOT': 31052,
#   'AGE513_TOT': 64556,
#   'AGE1544_TOT': 200584,
#   'AGE4564_TOT': 137569,
#   'AGE65PLUS_TOT': 74352,
#   'RUCC_2013': 1.0,
#   'WA': 445819,
#   'BA': 30948,
#   'IA': 5449,
#   'AA': 22822,
#   'NA': 461,
#   'TOM': 10656,
#   'NH': 348309,
#   'H': 167846},
#  {'PCIncome': 40661.0,
#   'fip-year': '17089-2021',
#   'fips': 17089,
#   'POPESTIMATE': 515588,
#   'MFratio': 1.0050009527476074,
#   'POPEST_MALE': 258437,
#   'POPEST_FEM': 257151,
#   'MEDIAN_AGE_TOT': 38.6,
#   'UNDER5_TOT': 30293,
#   'AGE513_TOT': 62911,
#   'AGE1544_TOT': 200938,
#   'AGE4564_TOT': 136826,
#   'AGE65PLUS_TOT': 76629,
#   'RUCC_2013': 1.0,
#   'WA': 444400,
#   'BA': 30985,
#   'IA': 5537,
#   'AA': 23455,
#   'NA': 477,
#   'TOM': 10734,
#   'NH': 346879,
#   'H': 168709},
#  {'PCIncome': 27984.0,
#   'fip-year': '17091-2019',
#   'fips': 17091,
#   'POPESTIMATE': 109569,
#   'MFratio': 0.9725102613955496,
#   'POPEST_MALE': 54021,
#   'POPEST_FEM': 55548,
#   'MEDIAN_AGE_TOT': 38.6,
#   'UNDER5_TOT': 6442,
#   'AGE513_TOT': 12321,
#   'AGE1544_TOT': 42766,
#   'AGE4564_TOT': 27751,
#   'AGE65PLUS_TOT': 18824,
#   'RUCC_2013': 3.0,
#   'WA': 89030,
#   'BA': 16532,
#   'IA': 485,
#   'AA': 1159,
#   'NA': 49,
#   'TOM': 2314,
#   'NH': 97696,
#   'H': 11873},
#  {'PCIncome': 28445.0,
#   'fip-year': '17091-2020',
#   'fips': 17091,
#   'POPESTIMATE': 107236,
#   'MFratio': 0.9861093104661716,
#   'POPEST_MALE': 53243,
#   'POPEST_FEM': 53993,
#   'MEDIAN_AGE_TOT': 38.6,
#   'UNDER5_TOT': 6224,
#   'AGE513_TOT': 12077,
#   'AGE1544_TOT': 42008,
#   'AGE4564_TOT': 27181,
#   'AGE65PLUS_TOT': 18227,
#   'RUCC_2013': 3.0,
#   'WA': 87021,
#   'BA': 16229,
#   'IA': 483,
#   'AA': 1138,
#   'NA': 52,
#   'TOM': 2313,
#   'NH': 95222,
#   'H': 12014},
#  {'PCIncome': 30203.0,
#   'fip-year': '17091-2021',
#   'fips': 17091,
#   'POPESTIMATE': 106601,
#   'MFratio': 0.98512104283054,
#   'POPEST_MALE': 52901,
#   'POPEST_FEM': 53700,
#   'MEDIAN_AGE_TOT': 38.6,
#   'UNDER5_TOT': 6136,
#   'AGE513_TOT': 11913,
#   'AGE1544_TOT': 41917,
#   'AGE4564_TOT': 26694,
#   'AGE65PLUS_TOT': 18418,
#   'RUCC_2013': 3.0,
#   'WA': 86340,
#   'BA': 16202,
#   'IA': 507,
#   'AA': 1165,
#   'NA': 56,
#   'TOM': 2331,
#   'NH': 94222,
#   'H': 12379},
#  {'PCIncome': 36382.0,
#   'fip-year': '17093-2019',
#   'fips': 17093,
#   'POPESTIMATE': 128900,
#   'MFratio': 0.9824669332513072,
#   'POPEST_MALE': 63880,
#   'POPEST_FEM': 65020,
#   'MEDIAN_AGE_TOT': 35.8,
#   'UNDER5_TOT': 8362,
#   'AGE513_TOT': 19016,
#   'AGE1544_TOT': 53973,
#   'AGE4564_TOT': 31499,
#   'AGE65PLUS_TOT': 13757,
#   'RUCC_2013': 1.0,
#   'WA': 110661,
#   'BA': 10170,
#   'IA': 717,
#   'AA': 4428,
#   'NA': 96,
#   'TOM': 2828,
#   'NH': 103039,
#   'H': 25861},
#  {'PCIncome': 36504.0,
#   'fip-year': '17093-2020',
#   'fips': 17093,
#   'POPESTIMATE': 132291,
#   'MFratio': 0.9957005792903691,
#   'POPEST_MALE': 66003,
#   'POPEST_FEM': 66288,
#   'MEDIAN_AGE_TOT': 36.0,
#   'UNDER5_TOT': 8272,
#   'AGE513_TOT': 19519,
#   'AGE1544_TOT': 55189,
#   'AGE4564_TOT': 32788,
#   'AGE65PLUS_TOT': 14168,
#   'RUCC_2013': 1.0,
#   'WA': 112752,
#   'BA': 10935,
#   'IA': 834,
#   'AA': 4695,
#   'NA': 110,
#   'TOM': 2965,
#   'NH': 104653,
#   'H': 27638},
#  {'PCIncome': 38343.0,
#   'fip-year': '17093-2021',
#   'fips': 17093,
#   'POPESTIMATE': 134867,
#   'MFratio': 0.9969350134000622,
#   'POPEST_MALE': 67330,
#   'POPEST_FEM': 67537,
#   'MEDIAN_AGE_TOT': 36.1,
#   'UNDER5_TOT': 8285,
#   'AGE513_TOT': 19389,
#   'AGE1544_TOT': 56624,
#   'AGE4564_TOT': 33398,
#   'AGE65PLUS_TOT': 14730,
#   'RUCC_2013': 1.0,
#   'WA': 114074,
#   'BA': 11751,
#   'IA': 878,
#   'AA': 4956,
#   'NA': 108,
#   'TOM': 3100,
#   'NH': 105536,
#   'H': 29331},
#  {'PCIncome': 24545.0,
#   'fip-year': '17095-2019',
#   'fips': 17095,
#   'POPESTIMATE': 49669,
#   'MFratio': 1.0222710801677457,
#   'POPEST_MALE': 25108,
#   'POPEST_FEM': 24561,
#   'MEDIAN_AGE_TOT': 42.4,
#   'UNDER5_TOT': 2865,
#   'AGE513_TOT': 4774,
#   'AGE1544_TOT': 18076,
#   'AGE4564_TOT': 12537,
#   'AGE65PLUS_TOT': 10879,
#   'RUCC_2013': 4.0,
#   'WA': 43335,
#   'BA': 4235,
#   'IA': 206,
#   'AA': 486,
#   'NA': 18,
#   'TOM': 1389,
#   'NH': 46632,
#   'H': 3037},
#  {'PCIncome': 24804.0,
#   'fip-year': '17095-2020',
#   'fips': 17095,
#   'POPESTIMATE': 49736,
#   'MFratio': 1.0371083350399344,
#   'POPEST_MALE': 25321,
#   'POPEST_FEM': 24415,
#   'MEDIAN_AGE_TOT': 42.4,
#   'UNDER5_TOT': 2838,
#   'AGE513_TOT': 4886,
#   'AGE1544_TOT': 18085,
#   'AGE4564_TOT': 12515,
#   'AGE65PLUS_TOT': 10854,
#   'RUCC_2013': 4.0,
#   'WA': 43330,
#   'BA': 4284,
#   'IA': 223,
#   'AA': 458,
#   'NA': 22,
#   'TOM': 1419,
#   'NH': 46648,
#   'H': 3088},
#  {'PCIncome': 25871.0,
#   'fip-year': '17095-2021',
#   'fips': 17095,
#   'POPESTIMATE': 49268,
#   'MFratio': 1.048480312668912,
#   'POPEST_MALE': 25217,
#   'POPEST_FEM': 24051,
#   'MEDIAN_AGE_TOT': 42.6,
#   'UNDER5_TOT': 2703,
#   'AGE513_TOT': 4841,
#   'AGE1544_TOT': 17946,
#   'AGE4564_TOT': 12265,
#   'AGE65PLUS_TOT': 10930,
#   'RUCC_2013': 4.0,
#   'WA': 42763,
#   'BA': 4350,
#   'IA': 218,
#   'AA': 454,
#   'NA': 24,
#   'TOM': 1459,
#   'NH': 46097,
#   'H': 3171},
#  {'PCIncome': 45766.0,
#   'fip-year': '17097-2019',
#   'fips': 17097,
#   'POPESTIMATE': 697134,
#   'MFratio': 0.9985150189492756,
#   'POPEST_MALE': 348308,
#   'POPEST_FEM': 348826,
#   'MEDIAN_AGE_TOT': 38.9,
#   'UNDER5_TOT': 39585,
#   'AGE513_TOT': 84517,
#   'AGE1544_TOT': 268558,
#   'AGE4564_TOT': 190836,
#   'AGE65PLUS_TOT': 103402,
#   'RUCC_2013': 1.0,
#   'WA': 562373,
#   'BA': 52491,
#   'IA': 6119,
#   'AA': 59787,
#   'NA': 669,
#   'TOM': 15695,
#   'NH': 541680,
#   'H': 155454},
#  {'PCIncome': 47223.0,
#   'fip-year': '17097-2020',
#   'fips': 17097,
#   'POPESTIMATE': 713217,
#   'MFratio': 1.01178780262835,
#   'POPEST_MALE': 358698,
#   'POPEST_FEM': 354519,
#   'MEDIAN_AGE_TOT': 39.0,
#   'UNDER5_TOT': 39291,
#   'AGE513_TOT': 87171,
#   'AGE1544_TOT': 274371,
#   'AGE4564_TOT': 195081,
#   'AGE65PLUS_TOT': 106476,
#   'RUCC_2013': 1.0,
#   'WA': 573805,
#   'BA': 53764,
#   'IA': 6464,
#   'AA': 62258,
#   'NA': 727,
#   'TOM': 16199,
#   'NH': 551175,
#   'H': 162042},
#  {'PCIncome': 49440.0,
#   'fip-year': '17097-2021',
#   'fips': 17097,
#   'POPESTIMATE': 711239,
#   'MFratio': 1.0116330045847557,
#   'POPEST_MALE': 357676,
#   'POPEST_FEM': 353563,
#   'MEDIAN_AGE_TOT': 39.2,
#   'UNDER5_TOT': 38104,
#   'AGE513_TOT': 85383,
#   'AGE1544_TOT': 275366,
#   'AGE4564_TOT': 192203,
#   'AGE65PLUS_TOT': 109313,
#   'RUCC_2013': 1.0,
#   'WA': 570224,
#   'BA': 54067,
#   'IA': 6554,
#   'AA': 63347,
#   'NA': 735,
#   'TOM': 16312,
#   'NH': 546849,
#   'H': 164390},
#  {'PCIncome': 30277.0,
#   'fip-year': '17099-2019',
#   'fips': 17099,
#   'POPESTIMATE': 108517,
#   'MFratio': 1.0185078402559475,
#   'POPEST_MALE': 54756,
#   'POPEST_FEM': 53761,
#   'MEDIAN_AGE_TOT': 42.1,
#   'UNDER5_TOT': 5971,
#   'AGE513_TOT': 11433,
#   'AGE1544_TOT': 38984,
#   'AGE4564_TOT': 29820,
#   'AGE65PLUS_TOT': 20980,
#   'RUCC_2013': 4.0,
#   'WA': 102362,
#   'BA': 3118,
#   'IA': 404,
#   'AA': 1078,
#   'NA': 39,
#   'TOM': 1516,
#   'NH': 97518,
#   'H': 10999},
#  {'PCIncome': 31020.0,
#   'fip-year': '17099-2020',
#   'fips': 17099,
#   'POPESTIMATE': 109359,
#   'MFratio': 1.0331486576931657,
#   'POPEST_MALE': 55571,
#   'POPEST_FEM': 53788,
#   'MEDIAN_AGE_TOT': 42.0,
#   'UNDER5_TOT': 5845,
#   'AGE513_TOT': 11735,
#   'AGE1544_TOT': 39397,
#   'AGE4564_TOT': 29941,
#   'AGE65PLUS_TOT': 21034,
#   'RUCC_2013': 4.0,
#   'WA': 103107,
#   'BA': 3124,
#   'IA': 410,
#   'AA': 1100,
#   'NA': 43,
#   'TOM': 1575,
#   'NH': 98016,
#   'H': 11343},
#  {'PCIncome': 33174.0,
#   'fip-year': '17099-2021',
#   'fips': 17099,
#   'POPESTIMATE': 108965,
#   'MFratio': 1.035853745118921,
#   'POPEST_MALE': 55442,
#   'POPEST_FEM': 53523,
#   'MEDIAN_AGE_TOT': 42.0,
#   'UNDER5_TOT': 5637,
#   'AGE513_TOT': 11604,
#   'AGE1544_TOT': 39642,
#   'AGE4564_TOT': 29289,
#   'AGE65PLUS_TOT': 21340,
#   'RUCC_2013': 4.0,
#   'WA': 102456,
#   'BA': 3328,
#   'IA': 412,
#   'AA': 1093,
#   'NA': 45,
#   'TOM': 1631,
#   'NH': 97464,
#   'H': 11501},
#  {'PCIncome': 23613.0,
#   'fip-year': '17101-2019',
#   'fips': 17101,
#   'POPESTIMATE': 15665,
#   'MFratio': 1.2722657383231797,
#   'POPEST_MALE': 8771,
#   'POPEST_FEM': 6894,
#   'MEDIAN_AGE_TOT': 40.1,
#   'UNDER5_TOT': 782,
#   'AGE513_TOT': 1517,
#   'AGE1544_TOT': 6409,
#   'AGE4564_TOT': 3985,
#   'AGE65PLUS_TOT': 2796,
#   'RUCC_2013': 7.0,
#   'WA': 13733,
#   'BA': 1608,
#   'IA': 68,
#   'AA': 73,
#   'NA': 6,
#   'TOM': 177,
#   'NH': 15051,
#   'H': 614},
#  {'PCIncome': 26233.0,
#   'fip-year': '17101-2020',
#   'fips': 17101,
#   'POPESTIMATE': 15234,
#   'MFratio': 1.2805389221556889,
#   'POPEST_MALE': 8554,
#   'POPEST_FEM': 6680,
#   'MEDIAN_AGE_TOT': 40.1,
#   'UNDER5_TOT': 709,
#   'AGE513_TOT': 1528,
#   'AGE1544_TOT': 6242,
#   'AGE4564_TOT': 3868,
#   'AGE65PLUS_TOT': 2714,
#   'RUCC_2013': 7.0,
#   'WA': 13317,
#   'BA': 1584,
#   'IA': 72,
#   'AA': 77,
#   'NA': 6,
#   'TOM': 178,
#   'NH': 14619,
#   'H': 615},
#  {'PCIncome': 27244.0,
#   'fip-year': '17101-2021',
#   'fips': 17101,
#   'POPESTIMATE': 15152,
#   'MFratio': 1.328927144174608,
#   'POPEST_MALE': 8646,
#   'POPEST_FEM': 6506,
#   'MEDIAN_AGE_TOT': 40.2,
#   'UNDER5_TOT': 680,
#   'AGE513_TOT': 1468,
#   'AGE1544_TOT': 6288,
#   'AGE4564_TOT': 3860,
#   'AGE65PLUS_TOT': 2679,
#   'RUCC_2013': 7.0,
#   'WA': 13082,
#   'BA': 1731,
#   'IA': 80,
#   'AA': 83,
#   'NA': 6,
#   'TOM': 170,
#   'NH': 14515,
#   'H': 637},
#  {'PCIncome': 29984.0,
#   'fip-year': '17103-2019',
#   'fips': 17103,
#   'POPESTIMATE': 34061,
#   'MFratio': 1.1280144945645385,
#   'POPEST_MALE': 18055,
#   'POPEST_FEM': 16006,
#   'MEDIAN_AGE_TOT': 43.6,
#   'UNDER5_TOT': 1708,
#   'AGE513_TOT': 3453,
#   'AGE1544_TOT': 12073,
#   'AGE4564_TOT': 9595,
#   'AGE65PLUS_TOT': 6866,
#   'RUCC_2013': 6.0,
#   'WA': 31222,
#   'BA': 1895,
#   'IA': 149,
#   'AA': 271,
#   'NA': 17,
#   'TOM': 507,
#   'NH': 31824,
#   'H': 2237},
#  {'PCIncome': 29343.0,
#   'fip-year': '17103-2020',
#   'fips': 17103,
#   'POPESTIMATE': 34021,
#   'MFratio': 1.147654819771479,
#   'POPEST_MALE': 18180,
#   'POPEST_FEM': 15841,
#   'MEDIAN_AGE_TOT': 43.4,
#   'UNDER5_TOT': 1694,
#   'AGE513_TOT': 3462,
#   'AGE1544_TOT': 12109,
#   'AGE4564_TOT': 9484,
#   'AGE65PLUS_TOT': 6864,
#   'RUCC_2013': 6.0,
#   'WA': 31110,
#   'BA': 1939,
#   'IA': 151,
#   'AA': 270,
#   'NA': 18,
#   'TOM': 533,
#   'NH': 31689,
#   'H': 2332},
#  {'PCIncome': 30461.0,
#   'fip-year': '17103-2021',
#   'fips': 17103,
#   'POPESTIMATE': 34049,
#   'MFratio': 1.1629399059839918,
#   'POPEST_MALE': 18307,
#   'POPEST_FEM': 15742,
#   'MEDIAN_AGE_TOT': 43.2,
#   'UNDER5_TOT': 1639,
#   'AGE513_TOT': 3407,
#   'AGE1544_TOT': 12293,
#   'AGE4564_TOT': 9314,
#   'AGE65PLUS_TOT': 6965,
#   'RUCC_2013': 6.0,
#   'WA': 30836,
#   'BA': 2186,
#   'IA': 158,
#   'AA': 286,
#   'NA': 18,
#   'TOM': 565,
#   'NH': 31611,
#   'H': 2438},
#  {'PCIncome': 27925.0,
#   'fip-year': '17105-2019',
#   'fips': 17105,
#   'POPESTIMATE': 35557,
#   'MFratio': 1.0114838490694122,
#   'POPEST_MALE': 17880,
#   'POPEST_FEM': 17677,
#   'MEDIAN_AGE_TOT': 41.5,
#   'UNDER5_TOT': 2060,
#   'AGE513_TOT': 3786,
#   'AGE1544_TOT': 12934,
#   'AGE4564_TOT': 9457,
#   'AGE65PLUS_TOT': 6907,
#   'RUCC_2013': 4.0,
#   'WA': 33090,
#   'BA': 1492,
#   'IA': 115,
#   'AA': 256,
#   'NA': 5,
#   'TOM': 599,
#   'NH': 33816,
#   'H': 1741},
#  {'PCIncome': 29646.0,
#   'fip-year': '17105-2020',
#   'fips': 17105,
#   'POPESTIMATE': 35752,
#   'MFratio': 1.032287403365166,
#   'POPEST_MALE': 18160,
#   'POPEST_FEM': 17592,
#   'MEDIAN_AGE_TOT': 41.3,
#   'UNDER5_TOT': 2069,
#   'AGE513_TOT': 3872,
#   'AGE1544_TOT': 13014,
#   'AGE4564_TOT': 9460,
#   'AGE65PLUS_TOT': 6886,
#   'RUCC_2013': 4.0,
#   'WA': 33245,
#   'BA': 1533,
#   'IA': 124,
#   'AA': 250,
#   'NA': 8,
#   'TOM': 592,
#   'NH': 33939,
#   'H': 1813},
#  {'PCIncome': 30657.0,
#   'fip-year': '17105-2021',
#   'fips': 17105,
#   'POPESTIMATE': 35664,
#   'MFratio': 1.0374771480804388,
#   'POPEST_MALE': 18160,
#   'POPEST_FEM': 17504,
#   'MEDIAN_AGE_TOT': 41.3,
#   'UNDER5_TOT': 2047,
#   'AGE513_TOT': 3834,
#   'AGE1544_TOT': 13087,
#   'AGE4564_TOT': 9269,
#   'AGE65PLUS_TOT': 6963,
#   'RUCC_2013': 4.0,
#   'WA': 33028,
#   'BA': 1646,
#   'IA': 142,
#   'AA': 261,
#   'NA': 11,
#   'TOM': 576,
#   'NH': 33801,
#   'H': 1863},
#  {'PCIncome': 27546.0,
#   'fip-year': '17107-2019',
#   'fips': 17107,
#   'POPESTIMATE': 28633,
#   'MFratio': 1.0357625311055811,
#   'POPEST_MALE': 14568,
#   'POPEST_FEM': 14065,
#   'MEDIAN_AGE_TOT': 39.8,
#   'UNDER5_TOT': 1513,
#   'AGE513_TOT': 2679,
#   'AGE1544_TOT': 11677,
#   'AGE4564_TOT': 7115,
#   'AGE65PLUS_TOT': 5330,
#   'RUCC_2013': 6.0,
#   'WA': 25408,
#   'BA': 2400,
#   'IA': 107,
#   'AA': 214,
#   'NA': 6,
#   'TOM': 498,
#   'NH': 27633,
#   'H': 1000},
#  {'PCIncome': 29377.0,
#   'fip-year': '17107-2020',
#   'fips': 17107,
#   'POPESTIMATE': 27879,
#   'MFratio': 1.0543069781150984,
#   'POPEST_MALE': 14308,
#   'POPEST_FEM': 13571,
#   'MEDIAN_AGE_TOT': 39.9,
#   'UNDER5_TOT': 1396,
#   'AGE513_TOT': 2714,
#   'AGE1544_TOT': 11392,
#   'AGE4564_TOT': 6928,
#   'AGE65PLUS_TOT': 5143,
#   'RUCC_2013': 6.0,
#   'WA': 24669,
#   'BA': 2402,
#   'IA': 104,
#   'AA': 207,
#   'NA': 6,
#   'TOM': 491,
#   'NH': 26891,
#   'H': 988},
#  {'PCIncome': 30920.0,
#   'fip-year': '17107-2021',
#   'fips': 17107,
#   'POPESTIMATE': 27992,
#   'MFratio': 1.0482950387823795,
#   'POPEST_MALE': 14326,
#   'POPEST_FEM': 13666,
#   'MEDIAN_AGE_TOT': 39.9,
#   'UNDER5_TOT': 1364,
#   'AGE513_TOT': 2691,
#   'AGE1544_TOT': 11602,
#   'AGE4564_TOT': 6831,
#   'AGE65PLUS_TOT': 5182,
#   'RUCC_2013': 6.0,
#   'WA': 24654,
#   'BA': 2517,
#   'IA': 112,
#   'AA': 201,
#   'NA': 6,
#   'TOM': 502,
#   'NH': 26941,
#   'H': 1051},
#  {'PCIncome': 24094.0,
#   'fip-year': '17109-2019',
#   'fips': 17109,
#   'POPESTIMATE': 29792,
#   'MFratio': 0.9611612138766374,
#   'POPEST_MALE': 14601,
#   'POPEST_FEM': 15191,
#   'MEDIAN_AGE_TOT': 34.6,
#   'UNDER5_TOT': 1349,
#   'AGE513_TOT': 2548,
#   'AGE1544_TOT': 13812,
#   'AGE4564_TOT': 6354,
#   'AGE65PLUS_TOT': 5432,
#   'RUCC_2013': 5.0,
#   'WA': 26776,
#   'BA': 1676,
#   'IA': 116,
#   'AA': 714,
#   'NA': 6,
#   'TOM': 504,
#   'NH': 28899,
#   'H': 893},
#  ...]

# %%
db.demographics.insert_many(data)

# %%
dfmerge=df1.merge(df, how='left',on='fip-year-month')
dfmerge
# Out:
#         house-cost fip-year-month fip-year_x   cases fip-year_y    fips
# 0           564461    6037-2017-1  6037-2017     NaN        NaN     NaN
# 1           567795    6037-2017-2  6037-2017     NaN        NaN     NaN
# 2           570658    6037-2017-3  6037-2017     NaN        NaN     NaN
# 3           572179    6037-2017-4  6037-2017     NaN        NaN     NaN
# 4           575524    6037-2017-5  6037-2017     NaN        NaN     NaN
# ...            ...            ...        ...     ...        ...     ...
# 156688      415334    8111-2021-8  8111-2021  2202.0  8111-2021  8111.0
# 156689      423507    8111-2021-9  8111-2021  2603.0  8111-2021  8111.0
# 156690      429720   8111-2021-10  8111-2021  2914.0  8111-2021  8111.0
# 156691      433309   8111-2021-11  8111-2021  3092.0  8111-2021  8111.0
# 156692      438270   8111-2021-12  8111-2021  3400.0  8111-2021  8111.0
#
# [156693 rows x 6 columns]

# %%
import numpy as np
dfmerge['cases'] = dfmerge['cases'].replace(np.nan, 0)
dfmerge
# Out:
#         house-cost fip-year-month fip-year_x   cases fip-year_y    fips
# 0           564461    6037-2017-1  6037-2017     0.0        NaN     NaN
# 1           567795    6037-2017-2  6037-2017     0.0        NaN     NaN
# 2           570658    6037-2017-3  6037-2017     0.0        NaN     NaN
# 3           572179    6037-2017-4  6037-2017     0.0        NaN     NaN
# 4           575524    6037-2017-5  6037-2017     0.0        NaN     NaN
# ...            ...            ...        ...     ...        ...     ...
# 156688      415334    8111-2021-8  8111-2021  2202.0  8111-2021  8111.0
# 156689      423507    8111-2021-9  8111-2021  2603.0  8111-2021  8111.0
# 156690      429720   8111-2021-10  8111-2021  2914.0  8111-2021  8111.0
# 156691      433309   8111-2021-11  8111-2021  3092.0  8111-2021  8111.0
# 156692      438270   8111-2021-12  8111-2021  3400.0  8111-2021  8111.0
#
# [156693 rows x 6 columns]

# %%
housingCOVID=dfmerge.filter(['house-cost','fip-year-month','cases'])

# %%
housingCOVID.dropna()
# Out:
#         house-cost fip-year-month   cases
# 0           564461    6037-2017-1     0.0
# 1           567795    6037-2017-2     0.0
# 2           570658    6037-2017-3     0.0
# 3           572179    6037-2017-4     0.0
# 4           575524    6037-2017-5     0.0
# ...            ...            ...     ...
# 156688      415334    8111-2021-8  2202.0
# 156689      423507    8111-2021-9  2603.0
# 156690      429720   8111-2021-10  2914.0
# 156691      433309   8111-2021-11  3092.0
# 156692      438270   8111-2021-12  3400.0
#
# [156693 rows x 3 columns]

# %%
housingCOVID.to_csv("housingCOVID.csv")

# %%
income= pd.read_csv('incomeclean.csv')
raceeth= pd.read_csv('raceethclean.csv')
RU= pd.read_csv('RUclean.csv')
pop= pd.read_csv('popclean.csv')

# %%
p1=income.merge(pop,on='fip-year')
p1['fips']=p1['fips'].astype(str)
p1.dtypes
p2=p1.merge(RU,on='fips')
p3=p2.merge(raceeth,on='fip-year')
p3
# Out:
# C:\Users\Juhi Aggarwal\anaconda3\envs\mlenv\lib\site-packages\pandas\core\frame.py:9203: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Unnamed: 0_x'} in the result is deprecated and will raise a MergeError in a future version.
#   validate=validate,
#       Unnamed: 0_x  PCIncome    fip-year  Unnamed: 0_y   fips  POPESTIMATE  \
# 0             6758   28845.0  10001-2019          1572  10001       181492
# 1             9980   28911.0  10001-2020          1573  10001       182256
# 2            13202   30804.0  10001-2021          1574  10001       184149
# 3             6759   37532.0  10003-2019          1577  10003       559941
# 4             9981   38965.0  10003-2020          1578  10003       570718
# ...            ...       ...         ...           ...    ...          ...
# 8461         12804   30212.0  56043-2020         15673  56043         7658
# 8462         16026   31032.0  56043-2021         15674  56043         7705
# 8463          9583   28531.0  56045-2019         15677  56045         6880
# 8464         12805   26573.0  56045-2020         15678  56045         6809
# 8465         16027   31190.0  56045-2021         15679  56045         6745
#
#        MFratio  POPEST_MALE  POPEST_FEM  MEDIAN_AGE_TOT  ...  RUCC_2013  \
# 0     0.928981        87405       94087            38.0  ...        3.0
# 1     0.937657        88196       94060            38.1  ...        3.0
# 2     0.934846        88974       95175            38.3  ...        3.0
# 3     0.938357       271067      288874            38.8  ...        1.0
# 4     0.949686       277995      292723            39.0  ...        1.0
# ...        ...          ...         ...             ...  ...        ...
# 8461  1.054185         3930        3728            43.9  ...        7.0
# 8462  1.057959         3961        3744            44.6  ...        7.0
# 8463  1.107198         3615        3265            44.3  ...        7.0
# 8464  1.129143         3611        3198            44.3  ...        7.0
# 8465  1.136522         3588        3157            44.7  ...        7.0
#
#       Unnamed: 0_y      WA      BA    IA     AA   NA    TOM      NH      H
# 0             1572  118674   49734  1342   4358  212   7172  167860  13632
# 1             1573  118412   50652  1355   4296  220   7321  168174  14082
# 2             1574  118375   52239  1391   4343  241   7560  169703  14446
# 3             1577  359883  148161  2766  33418  416  15297  501375  58566
# 4             1578  364190  153022  2927  34170  431  15978  509191  61527
# ...            ...     ...     ...   ...    ...  ...    ...     ...    ...
# 8461         15673    7255      40   129     64    5    165    6564   1094
# 8462         15674    7279      42   134     70    6    174    6606   1099
# 8463         15677    6429      48   132     98    2    171    6598    282
# 8464         15678    6377      48   127     93    1    163    6525    284
# 8465         15679    6310      49   128     96    1    161    6433    312
#
# [8466 rows x 26 columns]

# %%
demo=p3.filter(["fip-year","PCIncome","RUCC",'POPESTIMATE','MFratio','POPEST_MALE','POPEST_FEM','MEDIAN_AGE_TOT','UNDER5_TOT','AGE513_TOT','AGE1544_TOT','AGE4564_TOT','AGE65PLUS_TOT','WA','BA','IA','AA','NA','TOM','NH','H'])
demo
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4480\1652645704.py in <module>
# ----> 1 demo=p3.filter(["fip-year","PCIncome","RUCC",'POPESTIMATE','MFratio','POPEST_MALE','POPEST_FEM','MEDIAN_AGE_TOT','UNDER5_TOT','AGE513_TOT','AGE1544_TOT','AGE4564_TOT','AGE65PLUS_TOT','WA','BA','IA','AA','NA','TOM','NH','H'])
#       2 demo
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\generic.py in filter(self, items, like, regex, axis)
#    4980         if items is not None:
#    4981             name = self._get_axis_name(axis)
# -> 4982             return self.reindex(**{name: [r for r in items if r in labels]})
#    4983         elif like:
#    4984
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     322         @wraps(func)
#     323         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 324             return func(*args, **kwargs)
#     325
#     326         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\frame.py in reindex(self, *args, **kwargs)
#    4770         kwargs.pop("axis", None)
#    4771         kwargs.pop("labels", None)
# -> 4772         return super().reindex(**kwargs)
#    4773
#    4774     @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    4817         # perform the reindex on the axes
#    4818         return self._reindex_axes(
# -> 4819             axes, level, limit, tolerance, method, fill_value, copy
#    4820         ).__finalize__(self, method="reindex")
#    4821
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\frame.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4590         if columns is not None:
#    4591             frame = frame._reindex_columns(
# -> 4592                 columns, method, copy, level, fill_value, limit, tolerance
#    4593             )
#    4594
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\frame.py in _reindex_columns(self, new_columns, method, copy, level, fill_value, limit, tolerance)
#    4638             copy=copy,
#    4639             fill_value=fill_value,
# -> 4640             allow_dups=False,
#    4641         )
#    4642
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4887                 fill_value=fill_value,
#    4888                 allow_dups=allow_dups,
# -> 4889                 copy=copy,
#    4890             )
#    4891             # If we've made a copy once, no need to make another one
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\internals\managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice)
#     668         # some axes don't allow reindexing with dups
#     669         if not allow_dups:
# --> 670             self.axes[axis]._validate_can_reindex(indexer)
#     671
#     672         if axis >= self.ndim:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\indexes\base.py in _validate_can_reindex(self, indexer)
#    3783         # trying to reindex on an axis with duplicates
#    3784         if not self._index_as_unique and len(indexer):
# -> 3785             raise ValueError("cannot reindex from a duplicate axis")
#    3786
#    3787     def reindex(
#
# ValueError: cannot reindex from a duplicate axis

# %%
demo=p3.drop(columns=['Unnamed: 0_x','Unnamed: 0_y'])
demo.to_csv('demographics.csv')

# %% [markdown]
# # Connecting to MongoDb

# %%
import pymongo
import json
import pandas as pd
myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["mydatabase"]

# %%
df=pd.read_csv("housingCOVID.csv",index_col=0)
df.head()
# Out:
#    house-cost fip-year-month  cases
# 0      564461    6037-2017-1    0.0
# 1      567795    6037-2017-2    0.0
# 2      570658    6037-2017-3    0.0
# 3      572179    6037-2017-4    0.0
# 4      575524    6037-2017-5    0.0

# %%
data=df.to_dict(orient='records')

# %%
data
# Out:
# [{'house-cost': 564461, 'fip-year-month': '6037-2017-1', 'cases': 0.0},
#  {'house-cost': 567795, 'fip-year-month': '6037-2017-2', 'cases': 0.0},
#  {'house-cost': 570658, 'fip-year-month': '6037-2017-3', 'cases': 0.0},
#  {'house-cost': 572179, 'fip-year-month': '6037-2017-4', 'cases': 0.0},
#  {'house-cost': 575524, 'fip-year-month': '6037-2017-5', 'cases': 0.0},
#  {'house-cost': 579166, 'fip-year-month': '6037-2017-6', 'cases': 0.0},
#  {'house-cost': 580856, 'fip-year-month': '6037-2017-7', 'cases': 0.0},
#  {'house-cost': 583070, 'fip-year-month': '6037-2017-8', 'cases': 0.0},
#  {'house-cost': 585613, 'fip-year-month': '6037-2017-9', 'cases': 0.0},
#  {'house-cost': 590575, 'fip-year-month': '6037-2017-10', 'cases': 0.0},
#  {'house-cost': 596773, 'fip-year-month': '6037-2017-11', 'cases': 0.0},
#  {'house-cost': 601878, 'fip-year-month': '6037-2017-12', 'cases': 0.0},
#  {'house-cost': 607155, 'fip-year-month': '6037-2018-1', 'cases': 0.0},
#  {'house-cost': 612917, 'fip-year-month': '6037-2018-2', 'cases': 0.0},
#  {'house-cost': 618703, 'fip-year-month': '6037-2018-3', 'cases': 0.0},
#  {'house-cost': 623243, 'fip-year-month': '6037-2018-4', 'cases': 0.0},
#  {'house-cost': 625227, 'fip-year-month': '6037-2018-5', 'cases': 0.0},
#  {'house-cost': 627653, 'fip-year-month': '6037-2018-6', 'cases': 0.0},
#  {'house-cost': 628168, 'fip-year-month': '6037-2018-7', 'cases': 0.0},
#  {'house-cost': 629201, 'fip-year-month': '6037-2018-8', 'cases': 0.0},
#  {'house-cost': 630364, 'fip-year-month': '6037-2018-9', 'cases': 0.0},
#  {'house-cost': 633817, 'fip-year-month': '6037-2018-10', 'cases': 0.0},
#  {'house-cost': 636129, 'fip-year-month': '6037-2018-11', 'cases': 0.0},
#  {'house-cost': 635854, 'fip-year-month': '6037-2018-12', 'cases': 0.0},
#  {'house-cost': 635279, 'fip-year-month': '6037-2019-1', 'cases': 0.0},
#  {'house-cost': 633105, 'fip-year-month': '6037-2019-2', 'cases': 0.0},
#  {'house-cost': 631271, 'fip-year-month': '6037-2019-3', 'cases': 0.0},
#  {'house-cost': 630818, 'fip-year-month': '6037-2019-4', 'cases': 0.0},
#  {'house-cost': 631688, 'fip-year-month': '6037-2019-5', 'cases': 0.0},
#  {'house-cost': 633482, 'fip-year-month': '6037-2019-6', 'cases': 0.0},
#  {'house-cost': 631409, 'fip-year-month': '6037-2019-7', 'cases': 0.0},
#  {'house-cost': 631367, 'fip-year-month': '6037-2019-8', 'cases': 0.0},
#  {'house-cost': 632638, 'fip-year-month': '6037-2019-9', 'cases': 0.0},
#  {'house-cost': 637348, 'fip-year-month': '6037-2019-10', 'cases': 0.0},
#  {'house-cost': 640082, 'fip-year-month': '6037-2019-11', 'cases': 0.0},
#  {'house-cost': 643287, 'fip-year-month': '6037-2019-12', 'cases': 0.0},
#  {'house-cost': 646414, 'fip-year-month': '6037-2020-1', 'cases': 6.0},
#  {'house-cost': 652995, 'fip-year-month': '6037-2020-2', 'cases': 29.0},
#  {'house-cost': 659827, 'fip-year-month': '6037-2020-3', 'cases': 16149.0},
#  {'house-cost': 665371, 'fip-year-month': '6037-2020-4', 'cases': 362305.0},
#  {'house-cost': 663189, 'fip-year-month': '6037-2020-5', 'cases': 1172311.0},
#  {'house-cost': 660450, 'fip-year-month': '6037-2020-6', 'cases': 2295011.0},
#  {'house-cost': 663031, 'fip-year-month': '6037-2020-7', 'cases': 4534053.0},
#  {'house-cost': 672122, 'fip-year-month': '6037-2020-8', 'cases': 6796228.0},
#  {'house-cost': 683282, 'fip-year-month': '6037-2020-9', 'cases': 7694092.0},
#  {'house-cost': 693285, 'fip-year-month': '6037-2020-10', 'cases': 8928603.0},
#  {'house-cost': 701027, 'fip-year-month': '6037-2020-11', 'cases': 10393607.0},
#  {'house-cost': 706470, 'fip-year-month': '6037-2020-12', 'cases': 17784563.0},
#  {'house-cost': 710277, 'fip-year-month': '6037-2021-1', 'cases': 30373784.0},
#  {'house-cost': 717292, 'fip-year-month': '6037-2021-2', 'cases': 32591439.0},
#  {'house-cost': 724304, 'fip-year-month': '6037-2021-3', 'cases': 37517367.0},
#  {'house-cost': 734737, 'fip-year-month': '6037-2021-4', 'cases': 36839800.0},
#  {'house-cost': 748675, 'fip-year-month': '6037-2021-5', 'cases': 38390260.0},
#  {'house-cost': 766484, 'fip-year-month': '6037-2021-6', 'cases': 37426033.0},
#  {'house-cost': 786445, 'fip-year-month': '6037-2021-7', 'cases': 39342765.0},
#  {'house-cost': 798469, 'fip-year-month': '6037-2021-8', 'cases': 42054897.0},
#  {'house-cost': 807117, 'fip-year-month': '6037-2021-9', 'cases': 43117608.0},
#  {'house-cost': 809652, 'fip-year-month': '6037-2021-10', 'cases': 45799402.0},
#  {'house-cost': 814209, 'fip-year-month': '6037-2021-11', 'cases': 45387792.0},
#  {'house-cost': 819573, 'fip-year-month': '6037-2021-12', 'cases': 48739437.0},
#  {'house-cost': 233341, 'fip-year-month': '17031-2017-1', 'cases': 0.0},
#  {'house-cost': 235168, 'fip-year-month': '17031-2017-2', 'cases': 0.0},
#  {'house-cost': 237553, 'fip-year-month': '17031-2017-3', 'cases': 0.0},
#  {'house-cost': 238976, 'fip-year-month': '17031-2017-4', 'cases': 0.0},
#  {'house-cost': 239723, 'fip-year-month': '17031-2017-5', 'cases': 0.0},
#  {'house-cost': 239413, 'fip-year-month': '17031-2017-6', 'cases': 0.0},
#  {'house-cost': 239179, 'fip-year-month': '17031-2017-7', 'cases': 0.0},
#  {'house-cost': 239223, 'fip-year-month': '17031-2017-8', 'cases': 0.0},
#  {'house-cost': 240163, 'fip-year-month': '17031-2017-9', 'cases': 0.0},
#  {'house-cost': 240801, 'fip-year-month': '17031-2017-10', 'cases': 0.0},
#  {'house-cost': 241552, 'fip-year-month': '17031-2017-11', 'cases': 0.0},
#  {'house-cost': 242943, 'fip-year-month': '17031-2017-12', 'cases': 0.0},
#  {'house-cost': 245459, 'fip-year-month': '17031-2018-1', 'cases': 0.0},
#  {'house-cost': 247857, 'fip-year-month': '17031-2018-2', 'cases': 0.0},
#  {'house-cost': 248699, 'fip-year-month': '17031-2018-3', 'cases': 0.0},
#  {'house-cost': 248840, 'fip-year-month': '17031-2018-4', 'cases': 0.0},
#  {'house-cost': 248913, 'fip-year-month': '17031-2018-5', 'cases': 0.0},
#  {'house-cost': 249166, 'fip-year-month': '17031-2018-6', 'cases': 0.0},
#  {'house-cost': 249282, 'fip-year-month': '17031-2018-7', 'cases': 0.0},
#  {'house-cost': 249208, 'fip-year-month': '17031-2018-8', 'cases': 0.0},
#  {'house-cost': 249792, 'fip-year-month': '17031-2018-9', 'cases': 0.0},
#  {'house-cost': 250182, 'fip-year-month': '17031-2018-10', 'cases': 0.0},
#  {'house-cost': 251097, 'fip-year-month': '17031-2018-11', 'cases': 0.0},
#  {'house-cost': 251855, 'fip-year-month': '17031-2018-12', 'cases': 0.0},
#  {'house-cost': 252286, 'fip-year-month': '17031-2019-1', 'cases': 0.0},
#  {'house-cost': 252901, 'fip-year-month': '17031-2019-2', 'cases': 0.0},
#  {'house-cost': 253201, 'fip-year-month': '17031-2019-3', 'cases': 0.0},
#  {'house-cost': 253595, 'fip-year-month': '17031-2019-4', 'cases': 0.0},
#  {'house-cost': 253269, 'fip-year-month': '17031-2019-5', 'cases': 0.0},
#  {'house-cost': 252812, 'fip-year-month': '17031-2019-6', 'cases': 0.0},
#  {'house-cost': 252588, 'fip-year-month': '17031-2019-7', 'cases': 0.0},
#  {'house-cost': 252224, 'fip-year-month': '17031-2019-8', 'cases': 0.0},
#  {'house-cost': 252010, 'fip-year-month': '17031-2019-9', 'cases': 0.0},
#  {'house-cost': 251497, 'fip-year-month': '17031-2019-10', 'cases': 0.0},
#  {'house-cost': 251268, 'fip-year-month': '17031-2019-11', 'cases': 0.0},
#  {'house-cost': 251157, 'fip-year-month': '17031-2019-12', 'cases': 0.0},
#  {'house-cost': 251586, 'fip-year-month': '17031-2020-1', 'cases': 10.0},
#  {'house-cost': 252148, 'fip-year-month': '17031-2020-2', 'cases': 59.0},
#  {'house-cost': 252418, 'fip-year-month': '17031-2020-3', 'cases': 24647.0},
#  {'house-cost': 252189, 'fip-year-month': '17031-2020-4', 'cases': 561258.0},
#  {'house-cost': 251875, 'fip-year-month': '17031-2020-5', 'cases': 1868375.0},
#  {'house-cost': 251903, 'fip-year-month': '17031-2020-6', 'cases': 2556425.0},
#  {'house-cost': 253337, 'fip-year-month': '17031-2020-7', 'cases': 3024198.0},
#  {'house-cost': 255197, 'fip-year-month': '17031-2020-8', 'cases': 3600562.0},
#  {'house-cost': 258935, 'fip-year-month': '17031-2020-9', 'cases': 4090348.0},
#  {'house-cost': 262272, 'fip-year-month': '17031-2020-10', 'cases': 5050515.0},
#  {'house-cost': 265071, 'fip-year-month': '17031-2020-11', 'cases': 7542703.0},
#  {'house-cost': 266731,
#   'fip-year-month': '17031-2020-12',
#   'cases': 11075658.0},
#  {'house-cost': 267364, 'fip-year-month': '17031-2021-1', 'cases': 13273805.0},
#  {'house-cost': 269636, 'fip-year-month': '17031-2021-2', 'cases': 13030353.0},
#  {'house-cost': 271379, 'fip-year-month': '17031-2021-3', 'cases': 15039412.0},
#  {'house-cost': 274385, 'fip-year-month': '17031-2021-4', 'cases': 15531684.0},
#  {'house-cost': 276166, 'fip-year-month': '17031-2021-5', 'cases': 16931127.0},
#  {'house-cost': 279190, 'fip-year-month': '17031-2021-6', 'cases': 16674986.0},
#  {'house-cost': 282732, 'fip-year-month': '17031-2021-7', 'cases': 17346677.0},
#  {'house-cost': 286479, 'fip-year-month': '17031-2021-8', 'cases': 17893999.0},
#  {'house-cost': 289068, 'fip-year-month': '17031-2021-9', 'cases': 18206620.0},
#  {'house-cost': 291559,
#   'fip-year-month': '17031-2021-10',
#   'cases': 19574278.0},
#  {'house-cost': 294460,
#   'fip-year-month': '17031-2021-11',
#   'cases': 19745187.0},
#  {'house-cost': 297191,
#   'fip-year-month': '17031-2021-12',
#   'cases': 22602152.0},
#  {'house-cost': 183745, 'fip-year-month': '48201-2017-1', 'cases': 0.0},
#  {'house-cost': 184165, 'fip-year-month': '48201-2017-2', 'cases': 0.0},
#  {'house-cost': 184612, 'fip-year-month': '48201-2017-3', 'cases': 0.0},
#  {'house-cost': 185447, 'fip-year-month': '48201-2017-4', 'cases': 0.0},
#  {'house-cost': 185949, 'fip-year-month': '48201-2017-5', 'cases': 0.0},
#  {'house-cost': 186405, 'fip-year-month': '48201-2017-6', 'cases': 0.0},
#  {'house-cost': 186451, 'fip-year-month': '48201-2017-7', 'cases': 0.0},
#  {'house-cost': 186571, 'fip-year-month': '48201-2017-8', 'cases': 0.0},
#  {'house-cost': 186778, 'fip-year-month': '48201-2017-9', 'cases': 0.0},
#  {'house-cost': 187380, 'fip-year-month': '48201-2017-10', 'cases': 0.0},
#  {'house-cost': 188035, 'fip-year-month': '48201-2017-11', 'cases': 0.0},
#  {'house-cost': 188604, 'fip-year-month': '48201-2017-12', 'cases': 0.0},
#  {'house-cost': 189288, 'fip-year-month': '48201-2018-1', 'cases': 0.0},
#  {'house-cost': 189877, 'fip-year-month': '48201-2018-2', 'cases': 0.0},
#  {'house-cost': 190514, 'fip-year-month': '48201-2018-3', 'cases': 0.0},
#  {'house-cost': 191555, 'fip-year-month': '48201-2018-4', 'cases': 0.0},
#  {'house-cost': 192597, 'fip-year-month': '48201-2018-5', 'cases': 0.0},
#  {'house-cost': 193590, 'fip-year-month': '48201-2018-6', 'cases': 0.0},
#  {'house-cost': 194241, 'fip-year-month': '48201-2018-7', 'cases': 0.0},
#  {'house-cost': 195166, 'fip-year-month': '48201-2018-8', 'cases': 0.0},
#  {'house-cost': 196112, 'fip-year-month': '48201-2018-9', 'cases': 0.0},
#  {'house-cost': 197110, 'fip-year-month': '48201-2018-10', 'cases': 0.0},
#  {'house-cost': 198035, 'fip-year-month': '48201-2018-11', 'cases': 0.0},
#  {'house-cost': 198896, 'fip-year-month': '48201-2018-12', 'cases': 0.0},
#  {'house-cost': 199943, 'fip-year-month': '48201-2019-1', 'cases': 0.0},
#  {'house-cost': 200780, 'fip-year-month': '48201-2019-2', 'cases': 0.0},
#  {'house-cost': 201171, 'fip-year-month': '48201-2019-3', 'cases': 0.0},
#  {'house-cost': 201156, 'fip-year-month': '48201-2019-4', 'cases': 0.0},
#  {'house-cost': 201247, 'fip-year-month': '48201-2019-5', 'cases': 0.0},
#  {'house-cost': 201750, 'fip-year-month': '48201-2019-6', 'cases': 0.0},
#  {'house-cost': 202237, 'fip-year-month': '48201-2019-7', 'cases': 0.0},
#  {'house-cost': 202754, 'fip-year-month': '48201-2019-8', 'cases': 0.0},
#  {'house-cost': 202949, 'fip-year-month': '48201-2019-9', 'cases': 0.0},
#  {'house-cost': 203791, 'fip-year-month': '48201-2019-10', 'cases': 0.0},
#  {'house-cost': 204479, 'fip-year-month': '48201-2019-11', 'cases': 0.0},
#  {'house-cost': 205122, 'fip-year-month': '48201-2019-12', 'cases': 0.0},
#  {'house-cost': 204815, 'fip-year-month': '48201-2020-1', 'cases': 0.0},
#  {'house-cost': 204986, 'fip-year-month': '48201-2020-2', 'cases': 0.0},
#  {'house-cost': 205936, 'fip-year-month': '48201-2020-3', 'cases': 3415.0},
#  {'house-cost': 207353, 'fip-year-month': '48201-2020-4', 'cases': 117074.0},
#  {'house-cost': 208233, 'fip-year-month': '48201-2020-5', 'cases': 287867.0},
#  {'house-cost': 208595, 'fip-year-month': '48201-2020-6', 'cases': 589097.0},
#  {'house-cost': 209054, 'fip-year-month': '48201-2020-7', 'cases': 1602774.0},
#  {'house-cost': 210023, 'fip-year-month': '48201-2020-8', 'cases': 2844388.0},
#  {'house-cost': 212226, 'fip-year-month': '48201-2020-9', 'cases': 3706829.0},
#  {'house-cost': 214571, 'fip-year-month': '48201-2020-10', 'cases': 4765425.0},
#  {'house-cost': 217130, 'fip-year-month': '48201-2020-11', 'cases': 5272159.0},
#  {'house-cost': 219272, 'fip-year-month': '48201-2020-12', 'cases': 6611041.0},
#  {'house-cost': 221362, 'fip-year-month': '48201-2021-1', 'cases': 8641880.0},
#  {'house-cost': 223926, 'fip-year-month': '48201-2021-2', 'cases': 9399519.0},
#  {'house-cost': 225167, 'fip-year-month': '48201-2021-3', 'cases': 11342855.0},
#  {'house-cost': 226995, 'fip-year-month': '48201-2021-4', 'cases': 11552674.0},
#  {'house-cost': 229258, 'fip-year-month': '48201-2021-5', 'cases': 12298384.0},
#  {'house-cost': 234176, 'fip-year-month': '48201-2021-6', 'cases': 12081487.0},
#  {'house-cost': 239565, 'fip-year-month': '48201-2021-7', 'cases': 12677134.0},
#  {'house-cost': 245372, 'fip-year-month': '48201-2021-8', 'cases': 14234234.0},
#  {'house-cost': 249810, 'fip-year-month': '48201-2021-9', 'cases': 15931290.0},
#  {'house-cost': 253619,
#   'fip-year-month': '48201-2021-10',
#   'cases': 17610052.0},
#  {'house-cost': 256223,
#   'fip-year-month': '48201-2021-11',
#   'cases': 17451491.0},
#  {'house-cost': 259306,
#   'fip-year-month': '48201-2021-12',
#   'cases': 18757355.0},
#  {'house-cost': 237000, 'fip-year-month': '4013-2017-1', 'cases': 0.0},
#  {'house-cost': 238452, 'fip-year-month': '4013-2017-2', 'cases': 0.0},
#  {'house-cost': 240268, 'fip-year-month': '4013-2017-3', 'cases': 0.0},
#  {'house-cost': 241526, 'fip-year-month': '4013-2017-4', 'cases': 0.0},
#  {'house-cost': 242525, 'fip-year-month': '4013-2017-5', 'cases': 0.0},
#  {'house-cost': 243610, 'fip-year-month': '4013-2017-6', 'cases': 0.0},
#  {'house-cost': 245341, 'fip-year-month': '4013-2017-7', 'cases': 0.0},
#  {'house-cost': 246310, 'fip-year-month': '4013-2017-8', 'cases': 0.0},
#  {'house-cost': 247843, 'fip-year-month': '4013-2017-9', 'cases': 0.0},
#  {'house-cost': 249187, 'fip-year-month': '4013-2017-10', 'cases': 0.0},
#  {'house-cost': 250560, 'fip-year-month': '4013-2017-11', 'cases': 0.0},
#  {'house-cost': 251318, 'fip-year-month': '4013-2017-12', 'cases': 0.0},
#  {'house-cost': 252799, 'fip-year-month': '4013-2018-1', 'cases': 0.0},
#  {'house-cost': 255128, 'fip-year-month': '4013-2018-2', 'cases': 0.0},
#  {'house-cost': 257436, 'fip-year-month': '4013-2018-3', 'cases': 0.0},
#  {'house-cost': 259306, 'fip-year-month': '4013-2018-4', 'cases': 0.0},
#  {'house-cost': 260861, 'fip-year-month': '4013-2018-5', 'cases': 0.0},
#  {'house-cost': 262160, 'fip-year-month': '4013-2018-6', 'cases': 0.0},
#  {'house-cost': 263651, 'fip-year-month': '4013-2018-7', 'cases': 0.0},
#  {'house-cost': 265162, 'fip-year-month': '4013-2018-8', 'cases': 0.0},
#  {'house-cost': 267103, 'fip-year-month': '4013-2018-9', 'cases': 0.0},
#  {'house-cost': 268298, 'fip-year-month': '4013-2018-10', 'cases': 0.0},
#  {'house-cost': 269193, 'fip-year-month': '4013-2018-11', 'cases': 0.0},
#  {'house-cost': 270032, 'fip-year-month': '4013-2018-12', 'cases': 0.0},
#  {'house-cost': 271181, 'fip-year-month': '4013-2019-1', 'cases': 0.0},
#  {'house-cost': 272433, 'fip-year-month': '4013-2019-2', 'cases': 0.0},
#  {'house-cost': 273866, 'fip-year-month': '4013-2019-3', 'cases': 0.0},
#  {'house-cost': 274712, 'fip-year-month': '4013-2019-4', 'cases': 0.0},
#  {'house-cost': 275457, 'fip-year-month': '4013-2019-5', 'cases': 0.0},
#  {'house-cost': 276179, 'fip-year-month': '4013-2019-6', 'cases': 0.0},
#  {'house-cost': 277350, 'fip-year-month': '4013-2019-7', 'cases': 0.0},
#  {'house-cost': 279277, 'fip-year-month': '4013-2019-8', 'cases': 0.0},
#  {'house-cost': 280968, 'fip-year-month': '4013-2019-9', 'cases': 0.0},
#  {'house-cost': 282651, 'fip-year-month': '4013-2019-10', 'cases': 0.0},
#  {'house-cost': 284304, 'fip-year-month': '4013-2019-11', 'cases': 0.0},
#  {'house-cost': 286401, 'fip-year-month': '4013-2019-12', 'cases': 0.0},
#  {'house-cost': 288509, 'fip-year-month': '4013-2020-1', 'cases': 6.0},
#  {'house-cost': 290603, 'fip-year-month': '4013-2020-2', 'cases': 29.0},
#  {'house-cost': 293668, 'fip-year-month': '4013-2020-3', 'cases': 4017.0},
#  {'house-cost': 297951, 'fip-year-month': '4013-2020-4', 'cases': 68745.0},
#  {'house-cost': 300779, 'fip-year-month': '4013-2020-5', 'cases': 214115.0},
#  {'house-cost': 302492, 'fip-year-month': '4013-2020-6', 'cases': 723691.0},
#  {'house-cost': 304383, 'fip-year-month': '4013-2020-7', 'cases': 2705670.0},
#  {'house-cost': 308815, 'fip-year-month': '4013-2020-8', 'cases': 3979145.0},
#  {'house-cost': 314143, 'fip-year-month': '4013-2020-9', 'cases': 4148676.0},
#  {'house-cost': 319502, 'fip-year-month': '4013-2020-10', 'cases': 4626339.0},
#  {'house-cost': 324838, 'fip-year-month': '4013-2020-11', 'cases': 5395879.0},
#  {'house-cost': 331099, 'fip-year-month': '4013-2020-12', 'cases': 8277933.0},
#  {'house-cost': 338520, 'fip-year-month': '4013-2021-1', 'cases': 12696251.0},
#  {'house-cost': 344920, 'fip-year-month': '4013-2021-2', 'cases': 13910633.0},
#  {'house-cost': 353650, 'fip-year-month': '4013-2021-3', 'cases': 16102557.0},
#  {'house-cost': 360262, 'fip-year-month': '4013-2021-4', 'cases': 15911356.0},
#  {'house-cost': 372458, 'fip-year-month': '4013-2021-5', 'cases': 16877500.0},
#  {'house-cost': 383871, 'fip-year-month': '4013-2021-6', 'cases': 16661922.0},
#  {'house-cost': 397135, 'fip-year-month': '4013-2021-7', 'cases': 17632696.0},
#  {'house-cost': 407112, 'fip-year-month': '4013-2021-8', 'cases': 18947662.0},
#  {'house-cost': 415319, 'fip-year-month': '4013-2021-9', 'cases': 20107974.0},
#  {'house-cost': 422809, 'fip-year-month': '4013-2021-10', 'cases': 22265640.0},
#  {'house-cost': 428902, 'fip-year-month': '4013-2021-11', 'cases': 23128692.0},
#  {'house-cost': 434638, 'fip-year-month': '4013-2021-12', 'cases': 25896706.0},
#  {'house-cost': 518024, 'fip-year-month': '6073-2017-1', 'cases': 0.0},
#  {'house-cost': 521096, 'fip-year-month': '6073-2017-2', 'cases': 0.0},
#  {'house-cost': 525041, 'fip-year-month': '6073-2017-3', 'cases': 0.0},
#  {'house-cost': 530309, 'fip-year-month': '6073-2017-4', 'cases': 0.0},
#  {'house-cost': 535393, 'fip-year-month': '6073-2017-5', 'cases': 0.0},
#  {'house-cost': 539166, 'fip-year-month': '6073-2017-6', 'cases': 0.0},
#  {'house-cost': 540648, 'fip-year-month': '6073-2017-7', 'cases': 0.0},
#  {'house-cost': 541612, 'fip-year-month': '6073-2017-8', 'cases': 0.0},
#  {'house-cost': 544003, 'fip-year-month': '6073-2017-9', 'cases': 0.0},
#  {'house-cost': 549270, 'fip-year-month': '6073-2017-10', 'cases': 0.0},
#  {'house-cost': 552671, 'fip-year-month': '6073-2017-11', 'cases': 0.0},
#  {'house-cost': 556518, 'fip-year-month': '6073-2017-12', 'cases': 0.0},
#  {'house-cost': 562505, 'fip-year-month': '6073-2018-1', 'cases': 0.0},
#  {'house-cost': 568955, 'fip-year-month': '6073-2018-2', 'cases': 0.0},
#  {'house-cost': 573093, 'fip-year-month': '6073-2018-3', 'cases': 0.0},
#  {'house-cost': 572891, 'fip-year-month': '6073-2018-4', 'cases': 0.0},
#  {'house-cost': 572319, 'fip-year-month': '6073-2018-5', 'cases': 0.0},
#  {'house-cost': 573382, 'fip-year-month': '6073-2018-6', 'cases': 0.0},
#  {'house-cost': 575423, 'fip-year-month': '6073-2018-7', 'cases': 0.0},
#  {'house-cost': 578473, 'fip-year-month': '6073-2018-8', 'cases': 0.0},
#  {'house-cost': 579641, 'fip-year-month': '6073-2018-9', 'cases': 0.0},
#  {'house-cost': 581882, 'fip-year-month': '6073-2018-10', 'cases': 0.0},
#  {'house-cost': 582800, 'fip-year-month': '6073-2018-11', 'cases': 0.0},
#  {'house-cost': 582456, 'fip-year-month': '6073-2018-12', 'cases': 0.0},
#  {'house-cost': 578759, 'fip-year-month': '6073-2019-1', 'cases': 0.0},
#  {'house-cost': 576445, 'fip-year-month': '6073-2019-2', 'cases': 0.0},
#  {'house-cost': 576089, 'fip-year-month': '6073-2019-3', 'cases': 0.0},
#  {'house-cost': 579081, 'fip-year-month': '6073-2019-4', 'cases': 0.0},
#  {'house-cost': 580687, 'fip-year-month': '6073-2019-5', 'cases': 0.0},
#  {'house-cost': 582534, 'fip-year-month': '6073-2019-6', 'cases': 0.0},
#  {'house-cost': 584773, 'fip-year-month': '6073-2019-7', 'cases': 0.0},
#  {'house-cost': 586733, 'fip-year-month': '6073-2019-8', 'cases': 0.0},
#  {'house-cost': 587296, 'fip-year-month': '6073-2019-9', 'cases': 0.0},
#  {'house-cost': 587847, 'fip-year-month': '6073-2019-10', 'cases': 0.0},
#  {'house-cost': 589840, 'fip-year-month': '6073-2019-11', 'cases': 0.0},
#  {'house-cost': 592322, 'fip-year-month': '6073-2019-12', 'cases': 0.0},
#  {'house-cost': 595231, 'fip-year-month': '6073-2020-1', 'cases': 0.0},
#  {'house-cost': 598425, 'fip-year-month': '6073-2020-2', 'cases': 20.0},
#  {'house-cost': 603992, 'fip-year-month': '6073-2020-3', 'cases': 4747.0},
#  {'house-cost': 607873, 'fip-year-month': '6073-2020-4', 'cases': 63537.0},
#  {'house-cost': 610751, 'fip-year-month': '6073-2020-5', 'cases': 176630.0},
#  {'house-cost': 610988, 'fip-year-month': '6073-2020-6', 'cases': 304368.0},
#  {'house-cost': 614516, 'fip-year-month': '6073-2020-7', 'cases': 683843.0},
#  {'house-cost': 621101, 'fip-year-month': '6073-2020-8', 'cases': 1068211.0},
#  {'house-cost': 631063, 'fip-year-month': '6073-2020-9', 'cases': 1298885.0},
#  {'house-cost': 641944, 'fip-year-month': '6073-2020-10', 'cases': 1611218.0},
#  {'house-cost': 653853, 'fip-year-month': '6073-2020-11', 'cases': 2003139.0},
#  {'house-cost': 664341, 'fip-year-month': '6073-2020-12', 'cases': 3612609.0},
#  {'house-cost': 673644, 'fip-year-month': '6073-2021-1', 'cases': 6358933.0},
#  {'house-cost': 681917, 'fip-year-month': '6073-2021-2', 'cases': 7046729.0},
#  {'house-cost': 692024, 'fip-year-month': '6073-2021-3', 'cases': 8243681.0},
#  {'house-cost': 705885, 'fip-year-month': '6073-2021-4', 'cases': 8217917.0},
#  {'house-cost': 726619, 'fip-year-month': '6073-2021-5', 'cases': 8638480.0},
#  {'house-cost': 750501, 'fip-year-month': '6073-2021-6', 'cases': 8442542.0},
#  {'house-cost': 774050, 'fip-year-month': '6073-2021-7', 'cases': 9384398.0},
#  {'house-cost': 788507, 'fip-year-month': '6073-2021-8', 'cases': 10275693.0},
#  {'house-cost': 798103, 'fip-year-month': '6073-2021-9', 'cases': 10883911.0},
#  {'house-cost': 802781, 'fip-year-month': '6073-2021-10', 'cases': 11804051.0},
#  {'house-cost': 810221, 'fip-year-month': '6073-2021-11', 'cases': 12001832.0},
#  {'house-cost': 821411, 'fip-year-month': '6073-2021-12', 'cases': 13068122.0},
#  {'house-cost': 675077, 'fip-year-month': '6059-2017-1', 'cases': 0.0},
#  {'house-cost': 677231, 'fip-year-month': '6059-2017-2', 'cases': 0.0},
#  {'house-cost': 681805, 'fip-year-month': '6059-2017-3', 'cases': 0.0},
#  {'house-cost': 683185, 'fip-year-month': '6059-2017-4', 'cases': 0.0},
#  {'house-cost': 685725, 'fip-year-month': '6059-2017-5', 'cases': 0.0},
#  {'house-cost': 689193, 'fip-year-month': '6059-2017-6', 'cases': 0.0},
#  {'house-cost': 690552, 'fip-year-month': '6059-2017-7', 'cases': 0.0},
#  {'house-cost': 691364, 'fip-year-month': '6059-2017-8', 'cases': 0.0},
#  {'house-cost': 693232, 'fip-year-month': '6059-2017-9', 'cases': 0.0},
#  {'house-cost': 697425, 'fip-year-month': '6059-2017-10', 'cases': 0.0},
#  {'house-cost': 702609, 'fip-year-month': '6059-2017-11', 'cases': 0.0},
#  {'house-cost': 707814, 'fip-year-month': '6059-2017-12', 'cases': 0.0},
#  {'house-cost': 712032, 'fip-year-month': '6059-2018-1', 'cases': 0.0},
#  {'house-cost': 715856, 'fip-year-month': '6059-2018-2', 'cases': 0.0},
#  {'house-cost': 719258, 'fip-year-month': '6059-2018-3', 'cases': 0.0},
#  {'house-cost': 723535, 'fip-year-month': '6059-2018-4', 'cases': 0.0},
#  {'house-cost': 727182, 'fip-year-month': '6059-2018-5', 'cases': 0.0},
#  {'house-cost': 730692, 'fip-year-month': '6059-2018-6', 'cases': 0.0},
#  {'house-cost': 731178, 'fip-year-month': '6059-2018-7', 'cases': 0.0},
#  {'house-cost': 732086, 'fip-year-month': '6059-2018-8', 'cases': 0.0},
#  {'house-cost': 731431, 'fip-year-month': '6059-2018-9', 'cases': 0.0},
#  {'house-cost': 734263, 'fip-year-month': '6059-2018-10', 'cases': 0.0},
#  {'house-cost': 734985, 'fip-year-month': '6059-2018-11', 'cases': 0.0},
#  {'house-cost': 733891, 'fip-year-month': '6059-2018-12', 'cases': 0.0},
#  {'house-cost': 731479, 'fip-year-month': '6059-2019-1', 'cases': 0.0},
#  {'house-cost': 729307, 'fip-year-month': '6059-2019-2', 'cases': 0.0},
#  {'house-cost': 728870, 'fip-year-month': '6059-2019-3', 'cases': 0.0},
#  {'house-cost': 728338, 'fip-year-month': '6059-2019-4', 'cases': 0.0},
#  {'house-cost': 729320, 'fip-year-month': '6059-2019-5', 'cases': 0.0},
#  {'house-cost': 728424, 'fip-year-month': '6059-2019-6', 'cases': 0.0},
#  {'house-cost': 729243, 'fip-year-month': '6059-2019-7', 'cases': 0.0},
#  {'house-cost': 731054, 'fip-year-month': '6059-2019-8', 'cases': 0.0},
#  {'house-cost': 736382, 'fip-year-month': '6059-2019-9', 'cases': 0.0},
#  {'house-cost': 739714, 'fip-year-month': '6059-2019-10', 'cases': 0.0},
#  {'house-cost': 739735, 'fip-year-month': '6059-2019-11', 'cases': 0.0},
#  {'house-cost': 738132, 'fip-year-month': '6059-2019-12', 'cases': 0.0},
#  {'house-cost': 740413, 'fip-year-month': '6059-2020-1', 'cases': 7.0},
#  {'house-cost': 745315, 'fip-year-month': '6059-2020-2', 'cases': 29.0},
#  {'house-cost': 752405, 'fip-year-month': '6059-2020-3', 'cases': 3229.0},
#  {'house-cost': 756447, 'fip-year-month': '6059-2020-4', 'cases': 43117.0},
#  {'house-cost': 755059, 'fip-year-month': '6059-2020-5', 'cases': 133479.0},
#  {'house-cost': 751734, 'fip-year-month': '6059-2020-6', 'cases': 281375.0},
#  {'house-cost': 751912, 'fip-year-month': '6059-2020-7', 'cases': 837060.0},
#  {'house-cost': 761659, 'fip-year-month': '6059-2020-8', 'cases': 1335540.0},
#  {'house-cost': 771652, 'fip-year-month': '6059-2020-9', 'cases': 1572747.0},
#  {'house-cost': 781953, 'fip-year-month': '6059-2020-10', 'cases': 1813259.0},
#  {'house-cost': 788856, 'fip-year-month': '6059-2020-11', 'cases': 2069168.0},
#  {'house-cost': 796777, 'fip-year-month': '6059-2020-12', 'cases': 3642913.0},
#  {'house-cost': 804294, 'fip-year-month': '6059-2021-1', 'cases': 6634066.0},
#  {'house-cost': 812571, 'fip-year-month': '6059-2021-2', 'cases': 7162074.0},
#  {'house-cost': 822059, 'fip-year-month': '6059-2021-3', 'cases': 8183418.0},
#  {'house-cost': 834096, 'fip-year-month': '6059-2021-4', 'cases': 8054270.0},
#  {'house-cost': 853073, 'fip-year-month': '6059-2021-5', 'cases': 8407137.0},
#  {'house-cost': 876598, 'fip-year-month': '6059-2021-6', 'cases': 8184370.0},
#  {'house-cost': 899636, 'fip-year-month': '6059-2021-7', 'cases': 8575162.0},
#  {'house-cost': 916572, 'fip-year-month': '6059-2021-8', 'cases': 9138401.0},
#  {'house-cost': 927432, 'fip-year-month': '6059-2021-9', 'cases': 9373443.0},
#  {'house-cost': 937178, 'fip-year-month': '6059-2021-10', 'cases': 10008501.0},
#  {'house-cost': 949907, 'fip-year-month': '6059-2021-11', 'cases': 9921119.0},
#  {'house-cost': 967565, 'fip-year-month': '6059-2021-12', 'cases': 10593849.0},
#  {'house-cost': 280981, 'fip-year-month': '12086-2017-1', 'cases': 0.0},
#  {'house-cost': 282812, 'fip-year-month': '12086-2017-2', 'cases': 0.0},
#  {'house-cost': 283621, 'fip-year-month': '12086-2017-3', 'cases': 0.0},
#  {'house-cost': 284382, 'fip-year-month': '12086-2017-4', 'cases': 0.0},
#  {'house-cost': 285746, 'fip-year-month': '12086-2017-5', 'cases': 0.0},
#  {'house-cost': 287190, 'fip-year-month': '12086-2017-6', 'cases': 0.0},
#  {'house-cost': 288463, 'fip-year-month': '12086-2017-7', 'cases': 0.0},
#  {'house-cost': 289986, 'fip-year-month': '12086-2017-8', 'cases': 0.0},
#  {'house-cost': 290951, 'fip-year-month': '12086-2017-9', 'cases': 0.0},
#  {'house-cost': 292594, 'fip-year-month': '12086-2017-10', 'cases': 0.0},
#  {'house-cost': 292999, 'fip-year-month': '12086-2017-11', 'cases': 0.0},
#  {'house-cost': 294682, 'fip-year-month': '12086-2017-12', 'cases': 0.0},
#  {'house-cost': 295551, 'fip-year-month': '12086-2018-1', 'cases': 0.0},
#  {'house-cost': 297956, 'fip-year-month': '12086-2018-2', 'cases': 0.0},
#  {'house-cost': 299882, 'fip-year-month': '12086-2018-3', 'cases': 0.0},
#  {'house-cost': 302135, 'fip-year-month': '12086-2018-4', 'cases': 0.0},
#  {'house-cost': 303761, 'fip-year-month': '12086-2018-5', 'cases': 0.0},
#  {'house-cost': 305236, 'fip-year-month': '12086-2018-6', 'cases': 0.0},
#  {'house-cost': 306709, 'fip-year-month': '12086-2018-7', 'cases': 0.0},
#  {'house-cost': 307454, 'fip-year-month': '12086-2018-8', 'cases': 0.0},
#  {'house-cost': 308425, 'fip-year-month': '12086-2018-9', 'cases': 0.0},
#  {'house-cost': 308906, 'fip-year-month': '12086-2018-10', 'cases': 0.0},
#  {'house-cost': 311516, 'fip-year-month': '12086-2018-11', 'cases': 0.0},
#  {'house-cost': 313134, 'fip-year-month': '12086-2018-12', 'cases': 0.0},
#  {'house-cost': 315159, 'fip-year-month': '12086-2019-1', 'cases': 0.0},
#  {'house-cost': 315472, 'fip-year-month': '12086-2019-2', 'cases': 0.0},
#  {'house-cost': 316379, 'fip-year-month': '12086-2019-3', 'cases': 0.0},
#  {'house-cost': 317208, 'fip-year-month': '12086-2019-4', 'cases': 0.0},
#  {'house-cost': 317319, 'fip-year-month': '12086-2019-5', 'cases': 0.0},
#  {'house-cost': 317882, 'fip-year-month': '12086-2019-6', 'cases': 0.0},
#  {'house-cost': 318185, 'fip-year-month': '12086-2019-7', 'cases': 0.0},
#  {'house-cost': 318244, 'fip-year-month': '12086-2019-8', 'cases': 0.0},
#  {'house-cost': 317973, 'fip-year-month': '12086-2019-9', 'cases': 0.0},
#  {'house-cost': 318341, 'fip-year-month': '12086-2019-10', 'cases': 0.0},
#  {'house-cost': 318685, 'fip-year-month': '12086-2019-11', 'cases': 0.0},
#  {'house-cost': 318868, 'fip-year-month': '12086-2019-12', 'cases': 0.0},
#  {'house-cost': 318896, 'fip-year-month': '12086-2020-1', 'cases': 0.0},
#  {'house-cost': 321586, 'fip-year-month': '12086-2020-2', 'cases': 0.0},
#  {'house-cost': 323903, 'fip-year-month': '12086-2020-3', 'cases': 9866.0},
#  {'house-cost': 325686, 'fip-year-month': '12086-2020-4', 'cases': 237859.0},
#  {'house-cost': 326698, 'fip-year-month': '12086-2020-5', 'cases': 472911.0},
#  {'house-cost': 327434, 'fip-year-month': '12086-2020-6', 'cases': 720782.0},
#  {'house-cost': 328673, 'fip-year-month': '12086-2020-7', 'cases': 2368505.0},
#  {'house-cost': 329879, 'fip-year-month': '12086-2020-8', 'cases': 4403956.0},
#  {'house-cost': 331823, 'fip-year-month': '12086-2020-9', 'cases': 4948721.0},
#  {'house-cost': 333602, 'fip-year-month': '12086-2020-10', 'cases': 5508439.0},
#  {'house-cost': 334902, 'fip-year-month': '12086-2020-11', 'cases': 6154996.0},
#  {'house-cost': 337558, 'fip-year-month': '12086-2020-12', 'cases': 8210361.0},
#  {'house-cost': 341605, 'fip-year-month': '12086-2021-1', 'cases': 10522581.0},
#  {'house-cost': 345509, 'fip-year-month': '12086-2021-2', 'cases': 11013522.0},
#  {'house-cost': 350171, 'fip-year-month': '12086-2021-3', 'cases': 13297597.0},
#  {'house-cost': 352866, 'fip-year-month': '12086-2021-4', 'cases': 13986048.0},
#  {'house-cost': 357786, 'fip-year-month': '12086-2021-5', 'cases': 15316392.0},
#  {'house-cost': 362576, 'fip-year-month': '12086-2021-6', 'cases': 14964203.0},
#  {'house-cost': 368802, 'fip-year-month': '12086-2021-7', 'cases': 15978628.0},
#  {'house-cost': 375238, 'fip-year-month': '12086-2021-8', 'cases': 18064291.0},
#  {'house-cost': 383128, 'fip-year-month': '12086-2021-9', 'cases': 19309090.0},
#  {'house-cost': 391514,
#   'fip-year-month': '12086-2021-10',
#   'cases': 20669505.0},
#  {'house-cost': 399269,
#   'fip-year-month': '12086-2021-11',
#   'cases': 20268507.0},
#  {'house-cost': 407091,
#   'fip-year-month': '12086-2021-12',
#   'cases': 21863770.0},
#  {'house-cost': 179267, 'fip-year-month': '48113-2017-1', 'cases': 0.0},
#  {'house-cost': 180774, 'fip-year-month': '48113-2017-2', 'cases': 0.0},
#  {'house-cost': 182281, 'fip-year-month': '48113-2017-3', 'cases': 0.0},
#  {'house-cost': 183837, 'fip-year-month': '48113-2017-4', 'cases': 0.0},
#  {'house-cost': 185289, 'fip-year-month': '48113-2017-5', 'cases': 0.0},
#  {'house-cost': 186249, 'fip-year-month': '48113-2017-6', 'cases': 0.0},
#  {'house-cost': 187169, 'fip-year-month': '48113-2017-7', 'cases': 0.0},
#  {'house-cost': 187145, 'fip-year-month': '48113-2017-8', 'cases': 0.0},
#  {'house-cost': 187670, 'fip-year-month': '48113-2017-9', 'cases': 0.0},
#  {'house-cost': 188175, 'fip-year-month': '48113-2017-10', 'cases': 0.0},
#  {'house-cost': 189639, 'fip-year-month': '48113-2017-11', 'cases': 0.0},
#  {'house-cost': 191516, 'fip-year-month': '48113-2017-12', 'cases': 0.0},
#  {'house-cost': 194854, 'fip-year-month': '48113-2018-1', 'cases': 0.0},
#  {'house-cost': 198284, 'fip-year-month': '48113-2018-2', 'cases': 0.0},
#  {'house-cost': 201220, 'fip-year-month': '48113-2018-3', 'cases': 0.0},
#  {'house-cost': 202672, 'fip-year-month': '48113-2018-4', 'cases': 0.0},
#  {'house-cost': 204067, 'fip-year-month': '48113-2018-5', 'cases': 0.0},
#  {'house-cost': 205458, 'fip-year-month': '48113-2018-6', 'cases': 0.0},
#  {'house-cost': 207237, 'fip-year-month': '48113-2018-7', 'cases': 0.0},
#  {'house-cost': 209860, 'fip-year-month': '48113-2018-8', 'cases': 0.0},
#  {'house-cost': 210999, 'fip-year-month': '48113-2018-9', 'cases': 0.0},
#  {'house-cost': 211614, 'fip-year-month': '48113-2018-10', 'cases': 0.0},
#  {'house-cost': 211386, 'fip-year-month': '48113-2018-11', 'cases': 0.0},
#  {'house-cost': 212555, 'fip-year-month': '48113-2018-12', 'cases': 0.0},
#  {'house-cost': 215393, 'fip-year-month': '48113-2019-1', 'cases': 0.0},
#  {'house-cost': 218026, 'fip-year-month': '48113-2019-2', 'cases': 0.0},
#  {'house-cost': 220349, 'fip-year-month': '48113-2019-3', 'cases': 0.0},
#  {'house-cost': 220531, 'fip-year-month': '48113-2019-4', 'cases': 0.0},
#  {'house-cost': 220106, 'fip-year-month': '48113-2019-5', 'cases': 0.0},
#  {'house-cost': 219572, 'fip-year-month': '48113-2019-6', 'cases': 0.0},
#  {'house-cost': 219506, 'fip-year-month': '48113-2019-7', 'cases': 0.0},
#  {'house-cost': 220687, 'fip-year-month': '48113-2019-8', 'cases': 0.0},
#  {'house-cost': 222286, 'fip-year-month': '48113-2019-9', 'cases': 0.0},
#  {'house-cost': 222054, 'fip-year-month': '48113-2019-10', 'cases': 0.0},
#  {'house-cost': 221230, 'fip-year-month': '48113-2019-11', 'cases': 0.0},
#  {'house-cost': 219952, 'fip-year-month': '48113-2019-12', 'cases': 0.0},
#  {'house-cost': 222233, 'fip-year-month': '48113-2020-1', 'cases': 0.0},
#  {'house-cost': 224281, 'fip-year-month': '48113-2020-2', 'cases': 0.0},
#  {'house-cost': 226641, 'fip-year-month': '48113-2020-3', 'cases': 3704.0},
#  {'house-cost': 226734, 'fip-year-month': '48113-2020-4', 'cases': 61894.0},
#  {'house-cost': 226526, 'fip-year-month': '48113-2020-5', 'cases': 220336.0},
#  {'house-cost': 226332, 'fip-year-month': '48113-2020-6', 'cases': 453980.0},
#  {'house-cost': 226812, 'fip-year-month': '48113-2020-7', 'cases': 1152877.0},
#  {'house-cost': 228826, 'fip-year-month': '48113-2020-8', 'cases': 1977055.0},
#  {'house-cost': 231255, 'fip-year-month': '48113-2020-9', 'cases': 2403352.0},
#  {'house-cost': 234138, 'fip-year-month': '48113-2020-10', 'cases': 2906327.0},
#  {'house-cost': 235848, 'fip-year-month': '48113-2020-11', 'cases': 3610248.0},
#  {'house-cost': 237802, 'fip-year-month': '48113-2020-12', 'cases': 5127468.0},
#  {'house-cost': 240730, 'fip-year-month': '48113-2021-1', 'cases': 7112803.0},
#  {'house-cost': 244352, 'fip-year-month': '48113-2021-2', 'cases': 7632523.0},
#  {'house-cost': 247698, 'fip-year-month': '48113-2021-3', 'cases': 8891602.0},
#  {'house-cost': 250552, 'fip-year-month': '48113-2021-4', 'cases': 8850573.0},
#  {'house-cost': 253816, 'fip-year-month': '48113-2021-5', 'cases': 9341225.0},
#  {'house-cost': 258244, 'fip-year-month': '48113-2021-6', 'cases': 9144366.0},
#  {'house-cost': 262851, 'fip-year-month': '48113-2021-7', 'cases': 9605394.0},
#  {'house-cost': 269777, 'fip-year-month': '48113-2021-8', 'cases': 10306545.0},
#  {'house-cost': 276607, 'fip-year-month': '48113-2021-9', 'cases': 11103141.0},
#  {'house-cost': 282163,
#   'fip-year-month': '48113-2021-10',
#   'cases': 12326506.0},
#  {'house-cost': 285386,
#   'fip-year-month': '48113-2021-11',
#   'cases': 12285347.0},
#  {'house-cost': 288263,
#   'fip-year-month': '48113-2021-12',
#   'cases': 13113551.0},
#  {'house-cost': 697038, 'fip-year-month': '36047-2017-1', 'cases': 0.0},
#  {'house-cost': 701251, 'fip-year-month': '36047-2017-2', 'cases': 0.0},
#  {'house-cost': 704945, 'fip-year-month': '36047-2017-3', 'cases': 0.0},
#  {'house-cost': 708970, 'fip-year-month': '36047-2017-4', 'cases': 0.0},
#  {'house-cost': 712794, 'fip-year-month': '36047-2017-5', 'cases': 0.0},
#  {'house-cost': 715177, 'fip-year-month': '36047-2017-6', 'cases': 0.0},
#  {'house-cost': 717853, 'fip-year-month': '36047-2017-7', 'cases': 0.0},
#  {'house-cost': 721039, 'fip-year-month': '36047-2017-8', 'cases': 0.0},
#  {'house-cost': 726494, 'fip-year-month': '36047-2017-9', 'cases': 0.0},
#  {'house-cost': 732979, 'fip-year-month': '36047-2017-10', 'cases': 0.0},
#  {'house-cost': 738607, 'fip-year-month': '36047-2017-11', 'cases': 0.0},
#  {'house-cost': 743767, 'fip-year-month': '36047-2017-12', 'cases': 0.0},
#  {'house-cost': 747202, 'fip-year-month': '36047-2018-1', 'cases': 0.0},
#  {'house-cost': 751924, 'fip-year-month': '36047-2018-2', 'cases': 0.0},
#  {'house-cost': 754902, 'fip-year-month': '36047-2018-3', 'cases': 0.0},
#  {'house-cost': 757068, 'fip-year-month': '36047-2018-4', 'cases': 0.0},
#  {'house-cost': 758976, 'fip-year-month': '36047-2018-5', 'cases': 0.0},
#  {'house-cost': 762312, 'fip-year-month': '36047-2018-6', 'cases': 0.0},
#  {'house-cost': 766083, 'fip-year-month': '36047-2018-7', 'cases': 0.0},
#  {'house-cost': 769172, 'fip-year-month': '36047-2018-8', 'cases': 0.0},
#  {'house-cost': 769725, 'fip-year-month': '36047-2018-9', 'cases': 0.0},
#  {'house-cost': 771972, 'fip-year-month': '36047-2018-10', 'cases': 0.0},
#  {'house-cost': 776233, 'fip-year-month': '36047-2018-11', 'cases': 0.0},
#  {'house-cost': 781462, 'fip-year-month': '36047-2018-12', 'cases': 0.0},
#  {'house-cost': 784887, 'fip-year-month': '36047-2019-1', 'cases': 0.0},
#  {'house-cost': 787327, 'fip-year-month': '36047-2019-2', 'cases': 0.0},
#  {'house-cost': 789427, 'fip-year-month': '36047-2019-3', 'cases': 0.0},
#  {'house-cost': 791121, 'fip-year-month': '36047-2019-4', 'cases': 0.0},
#  {'house-cost': 791946, 'fip-year-month': '36047-2019-5', 'cases': 0.0},
#  {'house-cost': 792152, 'fip-year-month': '36047-2019-6', 'cases': 0.0},
#  {'house-cost': 792953, 'fip-year-month': '36047-2019-7', 'cases': 0.0},
#  {'house-cost': 790581, 'fip-year-month': '36047-2019-8', 'cases': 0.0},
#  {'house-cost': 788256, 'fip-year-month': '36047-2019-9', 'cases': 0.0},
#  {'house-cost': 784835, 'fip-year-month': '36047-2019-10', 'cases': 0.0},
#  {'house-cost': 782679, 'fip-year-month': '36047-2019-11', 'cases': 0.0},
#  {'house-cost': 781092, 'fip-year-month': '36047-2019-12', 'cases': 0.0},
#  {'house-cost': 780466, 'fip-year-month': '36047-2020-1', 'cases': 0.0},
#  {'house-cost': 780729, 'fip-year-month': '36047-2020-2', 'cases': 0.0},
#  {'house-cost': 783101, 'fip-year-month': '36047-2020-3', 'cases': 0.0},
#  {'house-cost': 785338, 'fip-year-month': '36047-2020-4', 'cases': 0.0},
#  {'house-cost': 786947, 'fip-year-month': '36047-2020-5', 'cases': 0.0},
#  {'house-cost': 787349, 'fip-year-month': '36047-2020-6', 'cases': 0.0},
#  {'house-cost': 789906, 'fip-year-month': '36047-2020-7', 'cases': 0.0},
#  {'house-cost': 793854, 'fip-year-month': '36047-2020-8', 'cases': 0.0},
#  {'house-cost': 797693, 'fip-year-month': '36047-2020-9', 'cases': 0.0},
#  {'house-cost': 800176, 'fip-year-month': '36047-2020-10', 'cases': 0.0},
#  {'house-cost': 804209, 'fip-year-month': '36047-2020-11', 'cases': 0.0},
#  {'house-cost': 806435, 'fip-year-month': '36047-2020-12', 'cases': 0.0},
#  {'house-cost': 807350, 'fip-year-month': '36047-2021-1', 'cases': 0.0},
#  {'house-cost': 807619, 'fip-year-month': '36047-2021-2', 'cases': 0.0},
#  {'house-cost': 808394, 'fip-year-month': '36047-2021-3', 'cases': 0.0},
#  {'house-cost': 810604, 'fip-year-month': '36047-2021-4', 'cases': 0.0},
#  {'house-cost': 810581, 'fip-year-month': '36047-2021-5', 'cases': 0.0},
#  {'house-cost': 812734, 'fip-year-month': '36047-2021-6', 'cases': 0.0},
#  {'house-cost': 816226, 'fip-year-month': '36047-2021-7', 'cases': 0.0},
#  {'house-cost': 824198, 'fip-year-month': '36047-2021-8', 'cases': 0.0},
#  {'house-cost': 831770, 'fip-year-month': '36047-2021-9', 'cases': 0.0},
#  {'house-cost': 836670, 'fip-year-month': '36047-2021-10', 'cases': 0.0},
#  {'house-cost': 838053, 'fip-year-month': '36047-2021-11', 'cases': 0.0},
#  {'house-cost': 839035, 'fip-year-month': '36047-2021-12', 'cases': 0.0},
#  {'house-cost': 338961, 'fip-year-month': '6065-2017-1', 'cases': 0.0},
#  {'house-cost': 339463, 'fip-year-month': '6065-2017-2', 'cases': 0.0},
#  {'house-cost': 341686, 'fip-year-month': '6065-2017-3', 'cases': 0.0},
#  {'house-cost': 344096, 'fip-year-month': '6065-2017-4', 'cases': 0.0},
#  {'house-cost': 346970, 'fip-year-month': '6065-2017-5', 'cases': 0.0},
#  {'house-cost': 349590, 'fip-year-month': '6065-2017-6', 'cases': 0.0},
#  {'house-cost': 351055, 'fip-year-month': '6065-2017-7', 'cases': 0.0},
#  {'house-cost': 353356, 'fip-year-month': '6065-2017-8', 'cases': 0.0},
#  {'house-cost': 355593, 'fip-year-month': '6065-2017-9', 'cases': 0.0},
#  {'house-cost': 358286, 'fip-year-month': '6065-2017-10', 'cases': 0.0},
#  {'house-cost': 359254, 'fip-year-month': '6065-2017-11', 'cases': 0.0},
#  {'house-cost': 360134, 'fip-year-month': '6065-2017-12', 'cases': 0.0},
#  {'house-cost': 361700, 'fip-year-month': '6065-2018-1', 'cases': 0.0},
#  {'house-cost': 365692, 'fip-year-month': '6065-2018-2', 'cases': 0.0},
#  {'house-cost': 369248, 'fip-year-month': '6065-2018-3', 'cases': 0.0},
#  {'house-cost': 372648, 'fip-year-month': '6065-2018-4', 'cases': 0.0},
#  {'house-cost': 375344, 'fip-year-month': '6065-2018-5', 'cases': 0.0},
#  {'house-cost': 377830, 'fip-year-month': '6065-2018-6', 'cases': 0.0},
#  {'house-cost': 379912, 'fip-year-month': '6065-2018-7', 'cases': 0.0},
#  {'house-cost': 381102, 'fip-year-month': '6065-2018-8', 'cases': 0.0},
#  {'house-cost': 381793, 'fip-year-month': '6065-2018-9', 'cases': 0.0},
#  {'house-cost': 381623, 'fip-year-month': '6065-2018-10', 'cases': 0.0},
#  {'house-cost': 382457, 'fip-year-month': '6065-2018-11', 'cases': 0.0},
#  {'house-cost': 382826, 'fip-year-month': '6065-2018-12', 'cases': 0.0},
#  {'house-cost': 384962, 'fip-year-month': '6065-2019-1', 'cases': 0.0},
#  {'house-cost': 386259, 'fip-year-month': '6065-2019-2', 'cases': 0.0},
#  {'house-cost': 388282, 'fip-year-month': '6065-2019-3', 'cases': 0.0},
#  {'house-cost': 389248, 'fip-year-month': '6065-2019-4', 'cases': 0.0},
#  {'house-cost': 389418, 'fip-year-month': '6065-2019-5', 'cases': 0.0},
#  {'house-cost': 389461, 'fip-year-month': '6065-2019-6', 'cases': 0.0},
#  {'house-cost': 390220, 'fip-year-month': '6065-2019-7', 'cases': 0.0},
#  {'house-cost': 390978, 'fip-year-month': '6065-2019-8', 'cases': 0.0},
#  {'house-cost': 391006, 'fip-year-month': '6065-2019-9', 'cases': 0.0},
#  {'house-cost': 392430, 'fip-year-month': '6065-2019-10', 'cases': 0.0},
#  {'house-cost': 392928, 'fip-year-month': '6065-2019-11', 'cases': 0.0},
#  {'house-cost': 395792, 'fip-year-month': '6065-2019-12', 'cases': 0.0},
#  {'house-cost': 395856, 'fip-year-month': '6065-2020-1', 'cases': 0.0},
#  {'house-cost': 396942, 'fip-year-month': '6065-2020-2', 'cases': 0.0},
#  {'house-cost': 397422, 'fip-year-month': '6065-2020-3', 'cases': 1771.0},
#  {'house-cost': 399435, 'fip-year-month': '6065-2020-4', 'cases': 65312.0},
#  {'house-cost': 401823, 'fip-year-month': '6065-2020-5', 'cases': 178720.0},
#  {'house-cost': 403334, 'fip-year-month': '6065-2020-6', 'cases': 356709.0},
#  {'house-cost': 405993, 'fip-year-month': '6065-2020-7', 'cases': 879941.0},
#  {'house-cost': 410303, 'fip-year-month': '6065-2020-8', 'cases': 1423782.0},
#  {'house-cost': 416136, 'fip-year-month': '6065-2020-9', 'cases': 1682397.0},
#  {'house-cost': 421538, 'fip-year-month': '6065-2020-10', 'cases': 1970813.0},
#  {'house-cost': 427698, 'fip-year-month': '6065-2020-11', 'cases': 2297444.0},
#  {'house-cost': 433921, 'fip-year-month': '6065-2020-12', 'cases': 4090231.0},
#  {'house-cost': 439815, 'fip-year-month': '6065-2021-1', 'cases': 7287869.0},
#  {'house-cost': 446444, 'fip-year-month': '6065-2021-2', 'cases': 7973438.0},
#  {'house-cost': 454014, 'fip-year-month': '6065-2021-3', 'cases': 9062653.0},
#  {'house-cost': 464349, 'fip-year-month': '6065-2021-4', 'cases': 8904206.0},
#  {'house-cost': 476145, 'fip-year-month': '6065-2021-5', 'cases': 9291927.0},
#  {'house-cost': 490772, 'fip-year-month': '6065-2021-6', 'cases': 9041993.0},
#  {'house-cost': 507708, 'fip-year-month': '6065-2021-7', 'cases': 9584268.0},
#  {'house-cost': 523561, 'fip-year-month': '6065-2021-8', 'cases': 10230313.0},
#  {'house-cost': 535624, 'fip-year-month': '6065-2021-9', 'cases': 10639595.0},
#  {'house-cost': 543516, 'fip-year-month': '6065-2021-10', 'cases': 11453142.0},
#  {'house-cost': 547888, 'fip-year-month': '6065-2021-11', 'cases': 11447324.0},
#  {'house-cost': 552256, 'fip-year-month': '6065-2021-12', 'cases': 12314586.0},
#  {'house-cost': 561116, 'fip-year-month': '36081-2017-1', 'cases': 0.0},
#  {'house-cost': 563630, 'fip-year-month': '36081-2017-2', 'cases': 0.0},
#  {'house-cost': 566565, 'fip-year-month': '36081-2017-3', 'cases': 0.0},
#  {'house-cost': 568416, 'fip-year-month': '36081-2017-4', 'cases': 0.0},
#  {'house-cost': 571629, 'fip-year-month': '36081-2017-5', 'cases': 0.0},
#  {'house-cost': 574466, 'fip-year-month': '36081-2017-6', 'cases': 0.0},
#  {'house-cost': 577891, 'fip-year-month': '36081-2017-7', 'cases': 0.0},
#  {'house-cost': 581243, 'fip-year-month': '36081-2017-8', 'cases': 0.0},
#  {'house-cost': 584417, 'fip-year-month': '36081-2017-9', 'cases': 0.0},
#  {'house-cost': 588543, 'fip-year-month': '36081-2017-10', 'cases': 0.0},
#  {'house-cost': 591805, 'fip-year-month': '36081-2017-11', 'cases': 0.0},
#  {'house-cost': 594726, 'fip-year-month': '36081-2017-12', 'cases': 0.0},
#  {'house-cost': 597144, 'fip-year-month': '36081-2018-1', 'cases': 0.0},
#  {'house-cost': 600825, 'fip-year-month': '36081-2018-2', 'cases': 0.0},
#  {'house-cost': 605316, 'fip-year-month': '36081-2018-3', 'cases': 0.0},
#  {'house-cost': 610533, 'fip-year-month': '36081-2018-4', 'cases': 0.0},
#  {'house-cost': 615161, 'fip-year-month': '36081-2018-5', 'cases': 0.0},
#  {'house-cost': 620236, 'fip-year-month': '36081-2018-6', 'cases': 0.0},
#  {'house-cost': 625493, 'fip-year-month': '36081-2018-7', 'cases': 0.0},
#  {'house-cost': 629726, 'fip-year-month': '36081-2018-8', 'cases': 0.0},
#  {'house-cost': 633173, 'fip-year-month': '36081-2018-9', 'cases': 0.0},
#  {'house-cost': 634616, 'fip-year-month': '36081-2018-10', 'cases': 0.0},
#  {'house-cost': 637050, 'fip-year-month': '36081-2018-11', 'cases': 0.0},
#  {'house-cost': 640034, 'fip-year-month': '36081-2018-12', 'cases': 0.0},
#  {'house-cost': 643187, 'fip-year-month': '36081-2019-1', 'cases': 0.0},
#  {'house-cost': 646514, 'fip-year-month': '36081-2019-2', 'cases': 0.0},
#  {'house-cost': 649002, 'fip-year-month': '36081-2019-3', 'cases': 0.0},
#  {'house-cost': 650003, 'fip-year-month': '36081-2019-4', 'cases': 0.0},
#  {'house-cost': 650373, 'fip-year-month': '36081-2019-5', 'cases': 0.0},
#  {'house-cost': 649497, 'fip-year-month': '36081-2019-6', 'cases': 0.0},
#  {'house-cost': 648976, 'fip-year-month': '36081-2019-7', 'cases': 0.0},
#  {'house-cost': 648275, 'fip-year-month': '36081-2019-8', 'cases': 0.0},
#  {'house-cost': 647027, 'fip-year-month': '36081-2019-9', 'cases': 0.0},
#  {'house-cost': 646397, 'fip-year-month': '36081-2019-10', 'cases': 0.0},
#  {'house-cost': 645866, 'fip-year-month': '36081-2019-11', 'cases': 0.0},
#  {'house-cost': 646677, 'fip-year-month': '36081-2019-12', 'cases': 0.0},
#  {'house-cost': 648579, 'fip-year-month': '36081-2020-1', 'cases': 0.0},
#  {'house-cost': 651737, 'fip-year-month': '36081-2020-2', 'cases': 0.0},
#  {'house-cost': 653268, 'fip-year-month': '36081-2020-3', 'cases': 0.0},
#  {'house-cost': 654223, 'fip-year-month': '36081-2020-4', 'cases': 0.0},
#  {'house-cost': 652724, 'fip-year-month': '36081-2020-5', 'cases': 0.0},
#  {'house-cost': 652542, 'fip-year-month': '36081-2020-6', 'cases': 0.0},
# ...
#  {'house-cost': 311901, 'fip-year-month': '6071-2017-8', 'cases': 0.0},
#  {'house-cost': 312991, 'fip-year-month': '6071-2017-9', 'cases': 0.0},
#  {'house-cost': 316379, 'fip-year-month': '6071-2017-10', 'cases': 0.0},
#  {'house-cost': 319489, 'fip-year-month': '6071-2017-11', 'cases': 0.0},
#  {'house-cost': 322591, 'fip-year-month': '6071-2017-12', 'cases': 0.0},
#  {'house-cost': 325617, 'fip-year-month': '6071-2018-1', 'cases': 0.0},
#  {'house-cost': 328170, 'fip-year-month': '6071-2018-2', 'cases': 0.0},
#  {'house-cost': 330442, 'fip-year-month': '6071-2018-3', 'cases': 0.0},
#  {'house-cost': 332087, 'fip-year-month': '6071-2018-4', 'cases': 0.0},
#  {'house-cost': 334402, 'fip-year-month': '6071-2018-5', 'cases': 0.0},
#  {'house-cost': 335976, 'fip-year-month': '6071-2018-6', 'cases': 0.0},
#  {'house-cost': 337315, 'fip-year-month': '6071-2018-7', 'cases': 0.0},
#  {'house-cost': 338356, 'fip-year-month': '6071-2018-8', 'cases': 0.0},
#  {'house-cost': 340583, 'fip-year-month': '6071-2018-9', 'cases': 0.0},
#  {'house-cost': 342684, 'fip-year-month': '6071-2018-10', 'cases': 0.0},
#  {'house-cost': 343323, 'fip-year-month': '6071-2018-11', 'cases': 0.0},
#  {'house-cost': 343324, 'fip-year-month': '6071-2018-12', 'cases': 0.0},
#  {'house-cost': 343944, 'fip-year-month': '6071-2019-1', 'cases': 0.0},
#  {'house-cost': 344705, 'fip-year-month': '6071-2019-2', 'cases': 0.0},
#  {'house-cost': 345817, 'fip-year-month': '6071-2019-3', 'cases': 0.0},
#  {'house-cost': 346625, 'fip-year-month': '6071-2019-4', 'cases': 0.0},
#  {'house-cost': 348013, 'fip-year-month': '6071-2019-5', 'cases': 0.0},
#  {'house-cost': 348703, 'fip-year-month': '6071-2019-6', 'cases': 0.0},
#  {'house-cost': 348532, 'fip-year-month': '6071-2019-7', 'cases': 0.0},
#  {'house-cost': 349030, 'fip-year-month': '6071-2019-8', 'cases': 0.0},
#  {'house-cost': 349717, 'fip-year-month': '6071-2019-9', 'cases': 0.0},
#  {'house-cost': 351545, 'fip-year-month': '6071-2019-10', 'cases': 0.0},
#  {'house-cost': 352939, 'fip-year-month': '6071-2019-11', 'cases': 0.0},
#  {'house-cost': 354340, 'fip-year-month': '6071-2019-12', 'cases': 0.0},
#  {'house-cost': 355536, 'fip-year-month': '6071-2020-1', 'cases': 0.0},
#  {'house-cost': 357563, 'fip-year-month': '6071-2020-2', 'cases': 0.0},
#  {'house-cost': 360216, 'fip-year-month': '6071-2020-3', 'cases': 748.0},
#  {'house-cost': 362848, 'fip-year-month': '6071-2020-4', 'cases': 32855.0},
#  {'house-cost': 362585, 'fip-year-month': '6071-2020-5', 'cases': 109214.0},
#  {'house-cost': 362690, 'fip-year-month': '6071-2020-6', 'cases': 245387.0},
#  {'house-cost': 364776, 'fip-year-month': '6071-2020-7', 'cases': 684747.0},
#  {'house-cost': 369995, 'fip-year-month': '6071-2020-8', 'cases': 1256409.0},
#  {'house-cost': 375537, 'fip-year-month': '6071-2020-9', 'cases': 1543111.0},
#  {'house-cost': 381034, 'fip-year-month': '6071-2020-10', 'cases': 1850228.0},
#  {'house-cost': 386308, 'fip-year-month': '6071-2020-11', 'cases': 2317346.0},
#  {'house-cost': 392502, 'fip-year-month': '6071-2020-12', 'cases': 4410994.0},
#  {'house-cost': 398699, 'fip-year-month': '6071-2021-1', 'cases': 7538585.0},
#  {'house-cost': 404605, 'fip-year-month': '6071-2021-2', 'cases': 7882481.0},
#  {'house-cost': 410892, 'fip-year-month': '6071-2021-3', 'cases': 8958035.0},
#  {'house-cost': 418477, 'fip-year-month': '6071-2021-4', 'cases': 8816671.0},
#  {'house-cost': 429185, 'fip-year-month': '6071-2021-5', 'cases': 9211057.0},
#  {'house-cost': 439231, 'fip-year-month': '6071-2021-6', 'cases': 8972738.0},
#  {'house-cost': 450929, 'fip-year-month': '6071-2021-7', 'cases': 9457568.0},
#  {'house-cost': 461355, 'fip-year-month': '6071-2021-8', 'cases': 10009981.0},
#  {'house-cost': 472422, 'fip-year-month': '6071-2021-9', 'cases': 10330179.0},
#  {'house-cost': 477985, 'fip-year-month': '6071-2021-10', 'cases': 11054424.0},
#  {'house-cost': 482322, 'fip-year-month': '6071-2021-11', 'cases': 11052222.0},
#  {'house-cost': 487649, 'fip-year-month': '6071-2021-12', 'cases': 11901404.0},
#  {'house-cost': 186214, 'fip-year-month': '48439-2017-1', 'cases': 0.0},
#  {'house-cost': 188310, 'fip-year-month': '48439-2017-2', 'cases': 0.0},
#  {'house-cost': 189446, 'fip-year-month': '48439-2017-3', 'cases': 0.0},
#  {'house-cost': 190785, 'fip-year-month': '48439-2017-4', 'cases': 0.0},
#  {'house-cost': 191860, 'fip-year-month': '48439-2017-5', 'cases': 0.0},
#  {'house-cost': 193425, 'fip-year-month': '48439-2017-6', 'cases': 0.0},
#  {'house-cost': 194963, 'fip-year-month': '48439-2017-7', 'cases': 0.0},
#  {'house-cost': 196513, 'fip-year-month': '48439-2017-8', 'cases': 0.0},
#  {'house-cost': 198247, 'fip-year-month': '48439-2017-9', 'cases': 0.0},
#  {'house-cost': 200318, 'fip-year-month': '48439-2017-10', 'cases': 0.0},
#  {'house-cost': 202409, 'fip-year-month': '48439-2017-11', 'cases': 0.0},
#  {'house-cost': 203999, 'fip-year-month': '48439-2017-12', 'cases': 0.0},
#  {'house-cost': 205444, 'fip-year-month': '48439-2018-1', 'cases': 0.0},
#  {'house-cost': 207047, 'fip-year-month': '48439-2018-2', 'cases': 0.0},
#  {'house-cost': 208763, 'fip-year-month': '48439-2018-3', 'cases': 0.0},
#  {'house-cost': 210213, 'fip-year-month': '48439-2018-4', 'cases': 0.0},
#  {'house-cost': 211120, 'fip-year-month': '48439-2018-5', 'cases': 0.0},
#  {'house-cost': 212350, 'fip-year-month': '48439-2018-6', 'cases': 0.0},
#  {'house-cost': 213419, 'fip-year-month': '48439-2018-7', 'cases': 0.0},
#  {'house-cost': 213903, 'fip-year-month': '48439-2018-8', 'cases': 0.0},
#  {'house-cost': 214429, 'fip-year-month': '48439-2018-9', 'cases': 0.0},
#  {'house-cost': 215011, 'fip-year-month': '48439-2018-10', 'cases': 0.0},
#  {'house-cost': 216455, 'fip-year-month': '48439-2018-11', 'cases': 0.0},
#  {'house-cost': 218073, 'fip-year-month': '48439-2018-12', 'cases': 0.0},
#  {'house-cost': 219724, 'fip-year-month': '48439-2019-1', 'cases': 0.0},
#  {'house-cost': 220782, 'fip-year-month': '48439-2019-2', 'cases': 0.0},
#  {'house-cost': 221230, 'fip-year-month': '48439-2019-3', 'cases': 0.0},
#  {'house-cost': 221516, 'fip-year-month': '48439-2019-4', 'cases': 0.0},
#  {'house-cost': 222020, 'fip-year-month': '48439-2019-5', 'cases': 0.0},
#  {'house-cost': 222182, 'fip-year-month': '48439-2019-6', 'cases': 0.0},
#  {'house-cost': 222353, 'fip-year-month': '48439-2019-7', 'cases': 0.0},
#  {'house-cost': 222967, 'fip-year-month': '48439-2019-8', 'cases': 0.0},
#  {'house-cost': 224113, 'fip-year-month': '48439-2019-9', 'cases': 0.0},
#  {'house-cost': 225292, 'fip-year-month': '48439-2019-10', 'cases': 0.0},
#  {'house-cost': 226125, 'fip-year-month': '48439-2019-11', 'cases': 0.0},
#  {'house-cost': 226791, 'fip-year-month': '48439-2019-12', 'cases': 0.0},
#  {'house-cost': 227425, 'fip-year-month': '48439-2020-1', 'cases': 0.0},
#  {'house-cost': 228347, 'fip-year-month': '48439-2020-2', 'cases': 0.0},
#  {'house-cost': 229302, 'fip-year-month': '48439-2020-3', 'cases': 1128.0},
#  {'house-cost': 230017, 'fip-year-month': '48439-2020-4', 'cases': 33121.0},
#  {'house-cost': 230157, 'fip-year-month': '48439-2020-5', 'cases': 127889.0},
#  {'house-cost': 230841, 'fip-year-month': '48439-2020-6', 'cases': 241848.0},
#  {'house-cost': 231839, 'fip-year-month': '48439-2020-7', 'cases': 628107.0},
#  {'house-cost': 234343, 'fip-year-month': '48439-2020-8', 'cases': 1130325.0},
#  {'house-cost': 236654, 'fip-year-month': '48439-2020-9', 'cases': 1369498.0},
#  {'house-cost': 239386, 'fip-year-month': '48439-2020-10', 'cases': 1810125.0},
#  {'house-cost': 241599, 'fip-year-month': '48439-2020-11', 'cases': 2495473.0},
#  {'house-cost': 243901, 'fip-year-month': '48439-2020-12', 'cases': 3861596.0},
#  {'house-cost': 245816, 'fip-year-month': '48439-2021-1', 'cases': 5812294.0},
#  {'house-cost': 248112, 'fip-year-month': '48439-2021-2', 'cases': 6545418.0},
#  {'house-cost': 251704, 'fip-year-month': '48439-2021-3', 'cases': 7670003.0},
#  {'house-cost': 257615, 'fip-year-month': '48439-2021-4', 'cases': 7615933.0},
#  {'house-cost': 264671, 'fip-year-month': '48439-2021-5', 'cases': 8032894.0},
#  {'house-cost': 271636, 'fip-year-month': '48439-2021-6', 'cases': 7863383.0},
#  {'house-cost': 278307, 'fip-year-month': '48439-2021-7', 'cases': 8271307.0},
#  {'house-cost': 284414, 'fip-year-month': '48439-2021-8', 'cases': 8914149.0},
#  {'house-cost': 290161, 'fip-year-month': '48439-2021-9', 'cases': 9815358.0},
#  {'house-cost': 295148,
#   'fip-year-month': '48439-2021-10',
#   'cases': 11020543.0},
#  {'house-cost': 299365,
#   'fip-year-month': '48439-2021-11',
#   'cases': 11021992.0},
#  {'house-cost': 304226,
#   'fip-year-month': '48439-2021-12',
#   'cases': 11699771.0},
#  {'house-cost': 183298, 'fip-year-month': '48029-2017-1', 'cases': 0.0},
#  {'house-cost': 185300, 'fip-year-month': '48029-2017-2', 'cases': 0.0},
#  {'house-cost': 186504, 'fip-year-month': '48029-2017-3', 'cases': 0.0},
#  {'house-cost': 186861, 'fip-year-month': '48029-2017-4', 'cases': 0.0},
#  {'house-cost': 186988, 'fip-year-month': '48029-2017-5', 'cases': 0.0},
#  {'house-cost': 187556, 'fip-year-month': '48029-2017-6', 'cases': 0.0},
#  {'house-cost': 188431, 'fip-year-month': '48029-2017-7', 'cases': 0.0},
#  {'house-cost': 189597, 'fip-year-month': '48029-2017-8', 'cases': 0.0},
#  {'house-cost': 190555, 'fip-year-month': '48029-2017-9', 'cases': 0.0},
#  {'house-cost': 191663, 'fip-year-month': '48029-2017-10', 'cases': 0.0},
#  {'house-cost': 192643, 'fip-year-month': '48029-2017-11', 'cases': 0.0},
#  {'house-cost': 193155, 'fip-year-month': '48029-2017-12', 'cases': 0.0},
#  {'house-cost': 193208, 'fip-year-month': '48029-2018-1', 'cases': 0.0},
#  {'house-cost': 193320, 'fip-year-month': '48029-2018-2', 'cases': 0.0},
#  {'house-cost': 194438, 'fip-year-month': '48029-2018-3', 'cases': 0.0},
#  {'house-cost': 195660, 'fip-year-month': '48029-2018-4', 'cases': 0.0},
#  {'house-cost': 196924, 'fip-year-month': '48029-2018-5', 'cases': 0.0},
#  {'house-cost': 197819, 'fip-year-month': '48029-2018-6', 'cases': 0.0},
#  {'house-cost': 198768, 'fip-year-month': '48029-2018-7', 'cases': 0.0},
#  {'house-cost': 199702, 'fip-year-month': '48029-2018-8', 'cases': 0.0},
#  {'house-cost': 200049, 'fip-year-month': '48029-2018-9', 'cases': 0.0},
#  {'house-cost': 200745, 'fip-year-month': '48029-2018-10', 'cases': 0.0},
#  {'house-cost': 201133, 'fip-year-month': '48029-2018-11', 'cases': 0.0},
#  {'house-cost': 202633, 'fip-year-month': '48029-2018-12', 'cases': 0.0},
#  {'house-cost': 203831, 'fip-year-month': '48029-2019-1', 'cases': 0.0},
#  {'house-cost': 205546, 'fip-year-month': '48029-2019-2', 'cases': 0.0},
#  {'house-cost': 206231, 'fip-year-month': '48029-2019-3', 'cases': 0.0},
#  {'house-cost': 207023, 'fip-year-month': '48029-2019-4', 'cases': 0.0},
#  {'house-cost': 207486, 'fip-year-month': '48029-2019-5', 'cases': 0.0},
#  {'house-cost': 208127, 'fip-year-month': '48029-2019-6', 'cases': 0.0},
#  {'house-cost': 208745, 'fip-year-month': '48029-2019-7', 'cases': 0.0},
#  {'house-cost': 209406, 'fip-year-month': '48029-2019-8', 'cases': 0.0},
#  {'house-cost': 210481, 'fip-year-month': '48029-2019-9', 'cases': 0.0},
#  {'house-cost': 211230, 'fip-year-month': '48029-2019-10', 'cases': 0.0},
#  {'house-cost': 211954, 'fip-year-month': '48029-2019-11', 'cases': 0.0},
#  {'house-cost': 211895, 'fip-year-month': '48029-2019-12', 'cases': 0.0},
#  {'house-cost': 212366, 'fip-year-month': '48029-2020-1', 'cases': 0.0},
#  {'house-cost': 212500, 'fip-year-month': '48029-2020-2', 'cases': 91.0},
#  {'house-cost': 213417, 'fip-year-month': '48029-2020-3', 'cases': 1376.0},
#  {'house-cost': 213386, 'fip-year-month': '48029-2020-4', 'cases': 25694.0},
#  {'house-cost': 213489, 'fip-year-month': '48029-2020-5', 'cases': 66319.0},
#  {'house-cost': 213388, 'fip-year-month': '48029-2020-6', 'cases': 170377.0},
#  {'house-cost': 214331, 'fip-year-month': '48029-2020-7', 'cases': 801393.0},
#  {'house-cost': 215744, 'fip-year-month': '48029-2020-8', 'cases': 1360969.0},
#  {'house-cost': 217981, 'fip-year-month': '48029-2020-9', 'cases': 1528970.0},
#  {'house-cost': 220514, 'fip-year-month': '48029-2020-10', 'cases': 1912425.0},
#  {'house-cost': 222787, 'fip-year-month': '48029-2020-11', 'cases': 2138545.0},
#  {'house-cost': 224699, 'fip-year-month': '48029-2020-12', 'cases': 3043189.0},
#  {'house-cost': 226571, 'fip-year-month': '48029-2021-1', 'cases': 4496692.0},
#  {'house-cost': 229082, 'fip-year-month': '48029-2021-2', 'cases': 5242640.0},
#  {'house-cost': 231662, 'fip-year-month': '48029-2021-3', 'cases': 6229338.0},
#  {'house-cost': 235218, 'fip-year-month': '48029-2021-4', 'cases': 6347318.0},
#  {'house-cost': 239616, 'fip-year-month': '48029-2021-5', 'cases': 6842929.0},
#  {'house-cost': 245590, 'fip-year-month': '48029-2021-6', 'cases': 6754965.0},
#  {'house-cost': 251057, 'fip-year-month': '48029-2021-7', 'cases': 7169559.0},
#  {'house-cost': 256792, 'fip-year-month': '48029-2021-8', 'cases': 8151079.0},
#  {'house-cost': 260644, 'fip-year-month': '48029-2021-9', 'cases': 8993845.0},
#  {'house-cost': 264806, 'fip-year-month': '48029-2021-10', 'cases': 9825000.0},
#  {'house-cost': 268541, 'fip-year-month': '48029-2021-11', 'cases': 9738627.0},
#  {'house-cost': 273304,
#   'fip-year-month': '48029-2021-12',
#   'cases': 10309052.0},
#  {'house-cost': 1012307, 'fip-year-month': '6085-2017-1', 'cases': 0.0},
#  {'house-cost': 1022159, 'fip-year-month': '6085-2017-2', 'cases': 0.0},
#  {'house-cost': 1026809, 'fip-year-month': '6085-2017-3', 'cases': 0.0},
#  {'house-cost': 1032616, 'fip-year-month': '6085-2017-4', 'cases': 0.0},
#  {'house-cost': 1036266, 'fip-year-month': '6085-2017-5', 'cases': 0.0},
#  {'house-cost': 1044508, 'fip-year-month': '6085-2017-6', 'cases': 0.0},
#  {'house-cost': 1052748, 'fip-year-month': '6085-2017-7', 'cases': 0.0},
#  {'house-cost': 1067843, 'fip-year-month': '6085-2017-8', 'cases': 0.0},
#  {'house-cost': 1091200, 'fip-year-month': '6085-2017-9', 'cases': 0.0},
#  {'house-cost': 1116664, 'fip-year-month': '6085-2017-10', 'cases': 0.0},
#  {'house-cost': 1141707, 'fip-year-month': '6085-2017-11', 'cases': 0.0},
#  {'house-cost': 1166568, 'fip-year-month': '6085-2017-12', 'cases': 0.0},
#  {'house-cost': 1192789, 'fip-year-month': '6085-2018-1', 'cases': 0.0},
#  {'house-cost': 1221692, 'fip-year-month': '6085-2018-2', 'cases': 0.0},
#  {'house-cost': 1247404, 'fip-year-month': '6085-2018-3', 'cases': 0.0},
#  {'house-cost': 1266513, 'fip-year-month': '6085-2018-4', 'cases': 0.0},
#  {'house-cost': 1288887, 'fip-year-month': '6085-2018-5', 'cases': 0.0},
#  {'house-cost': 1307325, 'fip-year-month': '6085-2018-6', 'cases': 0.0},
#  {'house-cost': 1327407, 'fip-year-month': '6085-2018-7', 'cases': 0.0},
#  {'house-cost': 1322694, 'fip-year-month': '6085-2018-8', 'cases': 0.0},
#  {'house-cost': 1312403, 'fip-year-month': '6085-2018-9', 'cases': 0.0},
#  {'house-cost': 1296546, 'fip-year-month': '6085-2018-10', 'cases': 0.0},
#  {'house-cost': 1285926, 'fip-year-month': '6085-2018-11', 'cases': 0.0},
#  {'house-cost': 1267211, 'fip-year-month': '6085-2018-12', 'cases': 0.0},
#  {'house-cost': 1244643, 'fip-year-month': '6085-2019-1', 'cases': 0.0},
#  {'house-cost': 1224652, 'fip-year-month': '6085-2019-2', 'cases': 0.0},
#  {'house-cost': 1210176, 'fip-year-month': '6085-2019-3', 'cases': 0.0},
#  {'house-cost': 1204258, 'fip-year-month': '6085-2019-4', 'cases': 0.0},
#  {'house-cost': 1197506, 'fip-year-month': '6085-2019-5', 'cases': 0.0},
#  {'house-cost': 1186746, 'fip-year-month': '6085-2019-6', 'cases': 0.0},
#  {'house-cost': 1175700, 'fip-year-month': '6085-2019-7', 'cases': 0.0},
#  {'house-cost': 1167161, 'fip-year-month': '6085-2019-8', 'cases': 0.0},
#  {'house-cost': 1171151, 'fip-year-month': '6085-2019-9', 'cases': 0.0},
#  {'house-cost': 1170810, 'fip-year-month': '6085-2019-10', 'cases': 0.0},
#  {'house-cost': 1174426, 'fip-year-month': '6085-2019-11', 'cases': 0.0},
#  {'house-cost': 1176432, 'fip-year-month': '6085-2019-12', 'cases': 0.0},
#  {'house-cost': 1191352, 'fip-year-month': '6085-2020-1', 'cases': 1.0},
#  {'house-cost': 1206328, 'fip-year-month': '6085-2020-2', 'cases': 60.0},
#  {'house-cost': 1226165, 'fip-year-month': '6085-2020-3', 'cases': 7305.0},
#  {'house-cost': 1231319, 'fip-year-month': '6085-2020-4', 'cases': 50477.0},
#  ...]

# %%
db=myclient['COVID_Housing']

# %%
print(db)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'COVID_Housing')

# %%
db.Caseshousing.insert_many(data)
